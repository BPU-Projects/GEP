# %% [markdown]
# (Insert general project/codebase description)

# %%
############
##
##  Temporarily stop colab session from disconnecting
##
############

while True:pass

# %% [markdown]
# Code chapters:
#
#
# ### 1) GEP
# >#### 	initialize
# >#### 	Create and Run GEP Model
# >#### 	Store and Plot Results
#
# ### 2) Initial Dispatch
# >#### 	Initialize
# >#### 	Parameter Resetter
# >#### 	Functions
# 		Parameter Resetter
# 		Flag Setter
# 		Plotter
# 		Initial Dispatcher Master Function
# >#### 	Chosen Example
# 		Store unmet demand vector
#
# ### 3) Dispatch with Removed Load
# >#### 	Removed Demand Plotter
# >#### 	Removed Demand Dispatcher Master Function
# >#### 	Run to Show with Unmet Demand Removed
#
# ### 4) Dispatch with Reallocation of Load
# >#### 	Shifted Demand Plotter
# >#### 	Shifted Demand Dispatcher Master Function
# >#### 	Run to Show with Unmet Demand Shifted

# %% [markdown]
# # **1) GEP**

# %% [markdown]
# ### Initialize

# %%
GEP_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/Jing_1/Jing_1_GEP_2035.xlsx'
initial_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/Jing_1/Jing_1_Initial_Dispatch_2035.xlsx'
shifted_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/Jing_1/Jing_1_Shifted_Dispatch_2035.xlsx'

# %%
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP

############
##
##  Reset imports and remount if needed
##
############

#del xl_name
del wb
del df_sheet_dic
del array_sheet_dic
del dic
drive.mount("/content/drive", force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-65077558084a> in <cell line: 12>()
#      10
#      11 #del xl_name
# ---> 12 del wb
#      13 del df_sheet_dic
#      14 del array_sheet_dic
#
# NameError: name 'wb' is not defined

# %%
############
##
##  Mount the drive
##
############

from google.colab import drive
drive.mount('/content/drive')

############
##
##  pip installs
##
############

# !apt-get install -y -qq glpk-utils  #for the GLPK solver in pulp, used to make "prettier" dispatch results if needed
# !pip install pulp
# !pip install pandas openpyxl
# !pip install xlsxwriter

############
##
##  Import initial libraries. Not all are needed.
##
############

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import *
import time
import random
from numpy import linalg as LA
import pickle
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import scipy
from scipy import optimize as opt
import csv
import os
import pulp

def dfer(thing):
  return pd.DataFrame(thing)

# %%
FC_flag = False
FC_lifespan = 10

# %%
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP

############
##
##  Parameter import and initial setup
##
############

# Import Excel file

#shifted_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/2/2_Shifted_Dispatch_2035.xlsx'
#initial_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/2/2_Initial_Dispatch_2035.xlsx'
#GEP_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/2/2_GEP_2035.xlsx'

wb = pd.ExcelFile(GEP_xl_name)
sheet_name_list = wb.sheet_names  # see all sheet names

#Turn into a dictionary of Pandas Dataframes
df_sheet_dic = {}
for sheet_name in sheet_name_list:
    df_sheet_dic[sheet_name] = pd.read_excel(GEP_xl_name, sheet_name = sheet_name)


# Keep the dataframes around for legibility, but create a dictionary of them as numpy arrays for functionality within the minimizer
array_sheet_dic = {}
for sheet_name in sheet_name_list:
  array_sheet_dic[sheet_name] = pd.DataFrame.to_numpy(df_sheet_dic[sheet_name])[:,1:]


N = array_sheet_dic['c'].shape[0]       #list of years
I = array_sheet_dic['q'].shape[1]       #q is an array with regions as rows and generating technologies as columns
#L = I                                   #IMPORTANT: THIS SETUP ASSUMES IDENTICAL LIST OF TECHS FOR LOCALIZED AND SHARED. WILL NEED TO BE GENERALIZED LATER. WON'T BE THAT HARD, JUST GOING TO HAVE TO SEPARATE LIKE "nki" vs "nks"
#K = array_sheet_dic['q'].shape[0]
P=1

#V = 6 #number of variables: w, w_loc, x, x_loc, y, curt

#r = 0.3 #interest rate. We could have pulled this from the array but it would really just overcomplicate the code
h = 8760 #hours per year, simplified since we removed seasons/periods

# Just calling dic for convenience in later referencing
dic = array_sheet_dic.copy()

if FC_flag:
  dic['delta'][0][8] = 0.73
  #lifespan is defined in earlier cell with FC_flag
  temp_alpha = dic['alpha'].copy() #proxy is not necessary, but as a caution...
  for i in range(N):
    # only do the multiplier if we will have to reup before the end of the planning horizon
    if (2050-2021-i)>FC_lifespan:
      multiplier = (2050-2021-i+1)/FC_lifespan
      dic['alpha'][i,8] = temp_alpha[i,8]*multiplier
    #for posterity, the previous 5 lines of code took an hour and a half to figure out and implement
else:
    dic['delta'][0][8] = 0

# %% [markdown]
# ### Create and Run GEP

# %%
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP

############
##
##  Setup and run the GEP
##
############

#############################
############################# Problem Initialization
#############################

GEP = pulp.LpProblem("GEP_Problem", pulp.LpMinimize)

#This implementation currently ignores localized generations

#############################
############################# Variable creation
#############################

x = [[pulp.LpVariable(f"x_{{{n},{i}}}", lowBound = 0) for i in range(I)] for n in range(N)]         #Generation in year n of shared unit i in region k (MWh)
y = [pulp.LpVariable(f"y_{{{n}}}", lowBound = 0) for n in range(N)]                                 #Electricity purchased in year n in region k from source p (MWh)
w = [[pulp.LpVariable(f"w_{{{n},{i}}}", lowBound = 0) for i in range(I)] for n in range(N)]         #Shared capacity investment in year n in region k of unit i (MW)


#############################
############################# Objective function
#############################


#(1) Overnight Capital Investment Cost
obj_1 = pulp.lpSum(dic['alpha'][n][i]*w[n][i] for i in range(I) for n in range(N))

#(2) Fixed Operating and Maintenance Costs
obj_2 = pulp.lpSum(dic['beta'][n][i]*dic['q'][0][i] + pulp.lpSum(dic['beta'][u][i]*w[u][i] for u in range(n))  for i in range(I) for n in range(N))

#(3) Variable Operating and Maintenance Costs
obj_3 = pulp.lpSum(dic['v'][n][i]*x[n][i] for i in range(I) for n in range(N))

#(4) Electricity Purchasing Costs
obj_4 = pulp.lpSum(dic['c'][n]*y[n] for n in range(N))

#OVERALL
#(5) Objective Function
GEP += obj_1 + obj_2 + obj_3 + obj_4





########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP
########### GEP GEP GEP GEP GEP GEP


#############################
############################# Constraints
#############################

#(6) Energy Balance
reserve_proportion = 0.2
for n in range(N):
  sub_constraint = \
  pulp.lpSum(x[n][i] for i in range(I)) + y[n] == dic['d'][n][0]*(1+reserve_proportion)
  GEP += sub_constraint


#(7) Generation Capacity Limits
for i in range(I):
  for n in range(N):
    sub_constraint = \
    x[n][i] <= (dic['q'][0][i] + pulp.lpSum(w[u][i] for u in range(n))  )*h*dic['delta'][0][i]
    GEP += sub_constraint


#(8) Generation Construction Limits (sum over all 50 years)
for i in range(I):
  GEP += pulp.lpSum(w[n][i] for n in range(N)) <= dic['GCONS'][0][i]


#(9) Generation Construction Minimums (target within each year)

for i in range(I):
  for n in range(N):
    GEP += w[n][i] >= dic['GCONMINS'][n][i]

#(10) Aggregate Generation Construction Minimums (cumulative target up to each year)

for i in range(I):
  for n in range(N):
    sub_constraint = \
    dic['q'][0][i] + pulp.lpSum(w[u][i] for u in range(n)) >= dic['GCONMINSAGG'][n][i]
    GEP += sub_constraint


#(11) Annual Purchase Transmission Limits

for n in range(N):
  GEP += y[n] <= dic['TRANSMAX'][n][0]*h


#(12) Meet the peak

peak_indices = [0, 1, 2, 3, 4, 6, 7, 8]

for n in range(2,N):
  sub_constraint = \
  pulp.lpSum(dic['q'][0][i]*dic['delta'][0][i] + pulp.lpSum(w[u][i] for u in range(n))*dic['delta'][0][i]  for i in peak_indices) + (1/365)*y[n] >= dic['peak'][n][0]
  GEP += sub_constraint


#(13) Constant Nuclear

for n in range(N):
  if 2021+n<2050:
    sub_constraint = \
    x[n][2] == dic['q'][0][2]*h*dic['delta'][0][2]
    GEP += sub_constraint
  else:
    sub_constraint = \
    x[n][2] <= 0.25*dic['d']*(1+reserve_proportion)
    GEP += sub_constraint


# EMP2035 Emissions Constraints

#(EMP2019.1) RPS Requirements (remember to update RPSMIN)

#class 1 and class 2 put together for now
renewable_indices = [0,3,5,6,7,8]
for n in range(N):
  sub_constraint = pulp.lpSum(x[n][i] for i in renewable_indices) >= dic['RPSMIN'][n]*dic['d'][n][0]*(1+reserve_proportion)
  GEP += sub_constraint


#(EMP2019.2) CLEAN Requirements (remember to update CLEANMIN)

clean_indices = [0,2,3,5,6,7,8]
for n in range(N):
  sub_constraint = pulp.lpSum(x[n][i] for i in clean_indices) >= dic['CLEANMIN'][n]*dic['d'][n][0]*(1+reserve_proportion)
  GEP += sub_constraint


#(EMP2019.3) CARBONFREE Requirements (remember to update CLEANMIN)

carbonfree_indices = [0,5,6,7,8]
for n in range(N):
  sub_constraint = pulp.lpSum(x[n][i] for i in carbonfree_indices) >= dic['CARBONFREEMIN'][n]*dic['d'][n][0]*(1+reserve_proportion)
  GEP += sub_constraint
  if 2021+n>=2050:
    sub_constraint = x[n][2] <= 0.25*dic['d'][n][0]*(1+reserve_proportion)
    GEP+=sub_constraint


'''
#(EMP2019.4) Solar Expansion Requirements
#aggregate
sub_constraint = dic['q'][0][5] + pulp.lpSum(pulp.lpSum(w[n][k][5] for k in range(K)) for n in range(10)) >= 3500
GEP += sub_constraint
#annual
#hard code, giving up on gconmins


#(EMP2019.5) Offshore Wind Expansion Requirements
sub_constraint = dic['q'][0][7] + pulp.lpSum(pulp.lpSum(w[n][k][7] for k in range(K)) for n in range(15)) >= 17000
GEP += sub_constraint

'''




GEP.solve()
print("Objective =", pulp.value(GEP.objective))
print("Solution status =", GEP.status)
#[0HYD,1NAT,2NUC,3BIO,4PET,5SOL,6WINON,7WINOFF]

# %% [markdown]
# ### Store and Plot Results

# %%
# obtain results from solved GEP PuLP variables

x_mat = np.zeros((N,I))
for n in range(N):
  for i in range(I):
    x_mat[n][i] = x[n][i].varValue

w_mat = np.zeros((N,I))
for n in range(N):
  for i in range(I):
    w_mat[n][i] = w[n][i].varValue

y_mat = np.zeros((N))
for n in range(N):
  y_mat[n] = y[n].varValue

#investment_mat = np.zeros((N,I+1))
#investment_mat[:,0:I] = w_mat
#investment_mat[:,I] = y_mat

investment_mat = np.zeros((N,I))
investment_mat[:,0:I] = w_mat

capacity_mat = np.zeros((N,I+1))
capacity_mat[:,0:I] = w_mat
capacity_mat[0,0:I] = capacity_mat[0,0:I] + dic['q'][0][:]
cum_capacity_mat = capacity_mat.cumsum(axis = 0)
cum_capacity_mat[:,I] = y_mat*(1/365)

'''
capacity_mat = np.zeros((N,I))
capacity_mat[:,0:I] = w_mat
capacity_mat[0,0:I] = capacity_mat[0,0:I] + dic['q'][0][:]
#capacity_mat[:,I] = y_mat
cum_capacity_mat = capacity_mat.cumsum(axis = 0)
'''


generation_mat = np.zeros((N,I+1))
generation_mat[:,0:I] = x_mat
generation_mat[:,I] = y_mat

# %%
############
##
##  Plot the generation timeline
##
############


# Plot the column sums over time
plt.figure(figsize=(10, 6))

tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC", "PJM", 'Demand', '50% Generation']
color_list = ["darkblue","sandybrown","maroon","green","snow","orange","skyblue", "steelblue", "pink", "gray"]
plt.stackplot(range(30), generation_mat[:-5][:].T, labels=tech_list, colors = color_list)

# Plot the total demand and half demand
plt.plot(dic['d'][0:N-5], label = 'Demand', color='black')
plt.plot(0.5*1.2*dic['d'][0:N-5], label = '50% Generation', color='black', linestyle='dashed', linewidth=0.75)



plt.title('Electrical Generation By Year')
plt.xlabel('Year')
plt.ylabel('MWh Generated')
#plt.xticks(range(0, 36, 5), [f'{2021 + year}' for year in range(0, 36, 5)])
#ticks = [f'{2021 + year}' if 2021+year % 5 == 0 else '' for year in range(0, 36)]
ticks = [f'{2021 + year}' if (2021+year) % 5 == 0 or year == 0 else '' for year in range(0, 36)]
plt.xticks(range(0, 30), ticks[:-6])

#tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "PJM", "PJMG", 'Demand', '50% Generation']
#plt.legend(tech_list)
plt.legend(tech_list, loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
############
##
##  Plot the cumulative investments
##
############


# Plot the column sums over time
plt.figure(figsize=(10, 6))

tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC", "PJM", 'Demand', '50% Generation']
color_list = ["darkblue","sandybrown","maroon","green","snow","orange","skyblue", "steelblue", "pink", "gray"]

#tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM"]
#color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray"]

plt.stackplot(range(30), cum_capacity_mat[:-5][:].T, labels=tech_list, colors = color_list)

# Plot the total demand and half demand
#plt.plot(dic['d'][0:N-5], label = 'Demand', color='black')
#plt.plot(0.5*1.2*dic['d'][0:N-5], label = '50% Generation', color='black', linestyle='dashed', linewidth=0.75)



plt.title('Cumulative Electrical Capacity By Year')
plt.xlabel('Year')
plt.ylabel('MW Available')
#plt.xticks(range(0, 36, 5), [f'{2021 + year}' for year in range(0, 36, 5)])
#ticks = [f'{2021 + year}' if 2021+year % 5 == 0 else '' for year in range(0, 36)]
ticks = [f'{2021 + year}' if (2021+year) % 5 == 0 or year == 0 else '' for year in range(0, 36)]
plt.xticks(range(0, 30), ticks[:-6])

plt.ylim(0,80000)
#tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "PJM", "PJMG", 'Demand', '50% Generation']
#plt.legend(tech_list)
plt.legend(tech_list, loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
############
##
##  Plot the cumulative investments
##
############


# Plot the column sums over time
plt.figure(figsize=(10, 6))

#tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC", "PJM", 'Demand', '50% Generation']
#color_list = ["darkblue","sandybrown","maroon","green","snow","orange","skyblue", "steelblue", "pink", "gray"]

tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM"]
color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray"]


w_cum = w_mat.copy()
w_cum[0,:] = w_cum[0,:] + dic['q']
w_cum = w_cum.cumsum(axis = 0)

num_columns = w_cum.shape[1]
temp = np.concatenate((w_cum[:, :1], w_cum[:, 2:], w_cum[:, 1:2]), axis=1)
w_cum = temp.copy()

plt.stackplot(range(30), w_cum[:-5][:].T, labels=tech_list, colors = color_list)

# Plot the total demand and half demand
#plt.plot(dic['d'][0:N-5], label = 'Demand', color='black')
#plt.plot(0.5*1.2*dic['d'][0:N-5], label = '50% Generation', color='black', linestyle='dashed', linewidth=0.75)



plt.title('Cumulative Electrical Capacity By Year')
plt.xlabel('Year')
plt.ylabel('MW Available')
#plt.xticks(range(0, 36, 5), [f'{2021 + year}' for year in range(0, 36, 5)])
#ticks = [f'{2021 + year}' if 2021+year % 5 == 0 else '' for year in range(0, 36)]
ticks = [f'{2021 + year}' if (2021+year) % 5 == 0 or year == 0 else '' for year in range(0, 36)]
plt.xticks(range(0, 30), ticks[:-6])

plt.ylim(0,80000)
#tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "PJM", "PJMG", 'Demand', '50% Generation']
#plt.legend(tech_list)
#plt.legend(tech_list, loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
############
##
##  Plot the cumulative investments
##
############


# Plot the column sums over time
plt.figure(figsize=(6, 6))

#tech_list = ["HYD","NAT","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC", "PJM", 'Demand', '50% Generation']
#color_list = ["darkblue","sandybrown","maroon","green","snow","orange","skyblue", "steelblue", "pink", "gray"]

tech_list = ["HYD", "NAT", "NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM"]
color_list = ["darkblue", "olive", "maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "gray"]


#w_cum = w_mat.copy()
#w_cum[0,:] = w_cum[0,:] + dic['q']
#w_cum = w_cum.cumsum(axis = 0)

#num_columns = w_cum.shape[1]
#temp = np.concatenate((w_cum[:, :1], w_cum[:, 2:], w_cum[:, 1:2]), axis=1)
#w_cum = temp.copy()

temp = cum_capacity_mat[:,0:9]

plt.stackplot(range(30), temp[:-5][:].T, labels=tech_list, colors = color_list)

# Plot the total demand and half demand
#plt.plot(dic['d'][0:N-5], label = 'Demand', color='black')
#plt.plot(0.5*1.2*dic['d'][0:N-5], label = '50% Generation', color='black', linestyle='dashed', linewidth=0.75)



plt.title('Cumulative Electrical Capacity By Year')
plt.xlabel('Year')
plt.ylabel('MW Available')
#plt.xticks(range(0, 36, 5), [f'{2021 + year}' for year in range(0, 36, 5)])
#ticks = [f'{2021 + year}' if 2021+year % 5 == 0 else '' for year in range(0, 36)]
ticks = [f'{2021 + year}' if (2021+year) % 5 == 0 or year == 0 else '' for year in range(0, 36)]
plt.xticks(range(0, 30), ticks[:-6])

plt.ylim(0,80000)
tech_list = ["Hydroelectric","Natural Gas","Nuclear","Biomass","Petroleum","Solar","Wind (Onshore)", "Wind (Offshore)", "Fuel Cell"]
#plt.legend(tech_list)
plt.legend(tech_list, loc='upper left', bbox_to_anchor=(1, 1), ncol = 3, prop = {'size': 24})
plt.show()

# %%
sum(dic['alpha'][n][i]*w[n][i].varValue for i in range(I) for n in range(N))

# %%
# Obtain and store proportion of demand recommended to be met by external purchases


dfer(cum_capacity_mat)
#cum_capacity_mat[0][:].sum()

pd.set_option('display.float_format', lambda x: '%.3f' % x)
purchase_capacity_proportion = [cum_capacity_mat[index][-1]/cum_capacity_mat[index][:].sum() for index in range(len(cum_capacity_mat))]
purchase_generation_proportion = [generation_mat[index][-1]/generation_mat[index][:].sum() for index in range(len(generation_mat))]
data = {'generation': purchase_generation_proportion, 'capacity': purchase_capacity_proportion}
dfer(data).T

# %% [markdown]
# # **2) Initial Dispatch**

# %% [markdown]
# ### Initialize

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

############
##
##  Reset imports and remount
##
############
drive.mount("/content/drive", force_remount=True)
#del xl_name
del wb
del df_sheet_dic
del array_sheet_dic
del dic
del y
del x
# Out:
# Mounted at /content/drive

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

############
##
##  Parameter import and initial setup
##
############

# Import Excel file

# BPU_Project_2_Parameters_2019EMP.xlsx
# BPU_Project_2_Parameters_2035EMP_Extended.xlsx
# BPU_Project_2_Parameters_2019EMP_Winter.xlsx

#shifted_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/2/2_Shifted_Dispatch_2035.xlsx'
#initial_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/2/2_Initial_Dispatch_2035.xlsx'

wb = pd.ExcelFile(initial_dispatch_xl_name)
sheet_name_list = wb.sheet_names  # see all sheet names

#Turn into a dictionary of Pandas Dataframes
df_sheet_dic = {}
for sheet_name in sheet_name_list:
    df_sheet_dic[sheet_name] = pd.read_excel(initial_dispatch_xl_name, sheet_name = sheet_name)

# Change to numpy arrays and shave off the indexing/row titles
# Keep the dataframes around for legibility, but create a dictionary of them as numpy arrays for functionality within the minimizer
array_sheet_dic = {}
for sheet_name in sheet_name_list:
  array_sheet_dic[sheet_name] = pd.DataFrame.to_numpy(df_sheet_dic[sheet_name])[:,1:]

# Set constants
H = array_sheet_dic['v'].shape[0]
I = array_sheet_dic['v'].shape[1]
S = array_sheet_dic['qstor'].shape[1]
P = array_sheet_dic['c'].shape[1]

# Just calling dic for convenience in later referencing
dic = array_sheet_dic.copy()

if FC_flag:
  dic['delta'][0][8] = 0.73
else:
    dic['delta'][0][8] = 0


dic['wCUM'] = w_mat.cumsum(axis = 0)

investments_flag = True
if investments_flag == False:
  dic['wCUM'] = dic['wCUM']*0

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Parameter Resetter

# %%
def dispatch_parameter_resetter():

  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Parameter import and initial setup
  ##
  ############

  drive.mount("/content/drive", force_remount=True)

  # Import Excel file

  # BPU_Project_2_Parameters_2019EMP.xlsx
  # BPU_Project_2_Parameters_2035EMP_Extended.xlsx
  # BPU_Project_2_Parameters_2019EMP_Winter.xlsx

  xl_name = '/content/drive/MyDrive/Rutgers/BPU/Project_3/Project_3_Dispatch_2035.xlsx'

  wb = pd.ExcelFile(xl_name)
  sheet_name_list = wb.sheet_names  # see all sheet names

  #Turn into a dictionary of Pandas Dataframes
  df_sheet_dic = {}
  for sheet_name in sheet_name_list:
      df_sheet_dic[sheet_name] = pd.read_excel(xl_name, sheet_name = sheet_name)

  # Change to numpy arrays and shave off the indexing/row titles
  # Keep the dataframes around for legibility, but create a dictionary of them as numpy arrays for functionality within the minimizer
  array_sheet_dic = {}
  for sheet_name in sheet_name_list:
    array_sheet_dic[sheet_name] = pd.DataFrame.to_numpy(df_sheet_dic[sheet_name])[:,1:]

  # Set constants
  H = array_sheet_dic['v'].shape[0]
  I = array_sheet_dic['v'].shape[1]
  S = array_sheet_dic['qstor'].shape[1]
  P = array_sheet_dic['c'].shape[1]

  # Just calling dic for convenience in later referencing
  dic = array_sheet_dic.copy()

  if FC_flag:
    dic['delta'][0][8] = 0.73
  else:
      dic['delta'][0][8] = 0

  dic['wCUM'] = w_mat.cumsum(axis = 0)

  investments_flag = True
  if investments_flag == False:
    dic['wCUM'] = dic['wCUM']*0

# %% [markdown]
# #### Flag Setter

# %%
battery_multiplier = 1
def flag_setter(winter_flag, average_flag, high_flag, max_flag, sunny_flag, windy_flag):
  if winter_flag + average_flag + high_flag + max_flag != 1:
    raise ValueError("multiple demand settings set")


  if winter_flag:
    dic['delta'] = dic['winter_delta'].copy()
    dic['d'] = dic['winter_d'].copy()
    dic['dchgeff'] = dic['winter_dchgeff'].copy()

  if average_flag:
    dic['delta'] = dic['average_delta'].copy()
    dic['d'] = dic['average_d'].copy()
    dic['dchgeff'] = dic['average_dchgeff'].copy()

  if high_flag:
    dic['delta'] = dic['high_delta'].copy()
    dic['d'] = dic['high_d'].copy()
    dic['dchgeff'] = dic['high_dchgeff'].copy()

  battery_multiplier = 1
  investments_flag = True


  if sunny_flag == False:
    dic['delta'][:,5] = dic['delta'][:,5]*0.15

  if windy_flag == False:
    dic['delta'][:,6] = dic['delta'][:,6]*0.15
    dic['delta'][:,7] = dic['delta'][:,7]*0.15

# %% [markdown]
# #### Plotter

# %%
def plotter_2(x, y, dchg, SOC, year):
  #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
  H = 24
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Compile results
  ##
  ############
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index)

  x_mat = np.zeros((H,I))
  for h in range(H):
    for i in range(I):
      x_mat[h][i] = x[h][i].varValue

  num_columns = x_mat.shape[1]
  temp = np.concatenate((x_mat[:, :1], x_mat[:, 2:], x_mat[:, 1:2]), axis=1)
  x_mat = temp.copy()




  y_mat = np.zeros((H,P))
  for h in range(H):
    for p in range(P):
      y_mat[h][p] = y[h][p].varValue

  dchg_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      dchg_mat[h][s] = dchg[h][s].varValue*dic['dchgeff'][0][s]
      #if sum(x[h][i].varValue for i in range(I)) + sum(y[h][p].varValue for p in range(P)) + sum(dchg[h][s].varValue*dic['dchgeff'][0][s] for s in range(S)) >= demand[h][0] + 1:
      #  dchg_mat[h][s] = 0 #can't work out the logic for why this is necessary, but it is

  SOC_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      SOC_mat[h][s] = SOC[h][s].varValue

  generation_mat = np.zeros((H,I+P+S))
  generation_mat[:,0:I] = x_mat
  generation_mat[:,I:I+P] = y_mat
  generation_mat[:,I+P:I+P+S] = dchg_mat


  ############
  ##
  ##  Plot the dispatch results
  ##
  ############

  plt.figure(figsize=(6, 6))

  tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM", "Backup", "Unmet", "BAT2", "BAT4", 'Demand', 'BAT2 SOC', 'BAT4 SOC']
  color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray", "rosybrown", "red", "darkseagreen", 'purple']

  plt.stackplot(range(H), generation_mat.T, colors = color_list)
  plt.plot(demand[:H], color = 'k')

  plt.plot(range(H),SOC_mat[:,0].T, color = 'gray', linestyle='dashed')
  #plt.plot(range(24),SOC_mat[:,0].T+SOC_mat[:,1].T, color = 'gray', linestyle='dashed')

  plt.plot(range(H),SOC_mat[:,1].T, color = 'black', linestyle='dashed')
  #plt.title(f'Hourly Dispatch: Year = {year}, Solver = {solver_choice}')
  #plt.title(f'Hourly Dispatch: Year = {year}, Winter')
  plt.title(f'Hourly Dispatch: Year = {year}')
  #plt.title(f'Hourly Dispatch: B3')
  #plt.title(f'Hourly Dispatch: F1')

  plt.ylabel('MW Generated')
  plt.xlabel('Hour')

  #plt.legend(tech_list, loc = 'upper right', bbox_to_anchor = (2.4,1), ncol = 3, prop={'size': 16})
  plt.xticks(range(H))
  plt.ylim(0,25000)

  plt.show()
  #plt.legend()
  return generation_mat, SOC_mat

# %% [markdown]
# #### Initial Dispatcher Master Function

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

def dispatcher(year, limit_emissions_flag, limit_transmissions_flag):

  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Set the year
  ##
  ############

  #year = 2035
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index)

  '''###### STORAGE CAPACITY LIMITS'''
  dic['qstor'][0][0] = 0*battery_multiplier
  dic['qstor'][0][1] = 2000*battery_multiplier
  #115445

  for s in range(S): # generation capability is based on capacity and battery length
    dic['SOCMAX'][0][s] = dic['qstor'].copy()[0][s]*dic['length'][0][s]
  dic['PCMAX'] = dic['SOCMAX']
  dic['PDMAX'] = dic['SOCMAX']



  ############
  ##
  ##  Setup and run the dispatcher
  ##
  ############

  H = 24

  GEP = pulp.LpProblem("GEP_Problem", pulp.LpMinimize)

  x = [[pulp.LpVariable(f"x_{{{h},{i}}}", lowBound = 0) for i in range(I)] for h in range(H)]
  y = [[pulp.LpVariable(f"y_{{{h},{p}}}", lowBound = 0) for p in range(P)] for h in range(H)]
  chg = [[pulp.LpVariable(f"chg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
  dchg = [[pulp.LpVariable(f"dchg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
  SOC = [[pulp.LpVariable(f"SOC_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]

  z_chg = [[pulp.LpVariable(f"z_chg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
  z_dchg = [[pulp.LpVariable(f"z_dchg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
  z_unmet = [pulp.LpVariable(f"z_dchg_{h}", cat="Binary") for h in range(H)]

  #(1) Variable Operating and Maintenance Costs
  obj_1 = pulp.lpSum(
      pulp.lpSum(
          dic['v'][h][i]*x[h][i] for i in range(I)
      )
      for h in range(H)
  )

  #(2) Electricity Purchase Costs
  obj_2 = pulp.lpSum(
      dic['c'][h][p]*y[h][p] for h in range(H) for p in range(P)
  )

  # OVERALL
  GEP += obj_1 + obj_2



  #(3) Energy Balance
  for h in range(H):
    sub_constraint = \
    pulp.lpSum(x[h][i] for i in range(I)) + pulp.lpSum(y[h][p] for p in range(P)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S)) - pulp.lpSum(chg[h][s] for s in range(S)) == demand[h][0]
    GEP += sub_constraint

  #(4) Generation Capacity Limits
  for i in range(I):
    for h in range(H):
      sub_constraint = \
      x[h][i] <= capacities[i]*dic['delta'][h][i]
      GEP += sub_constraint

  #(5) State of Charge Requirements
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      SOC[h][s] == pulp.lpSum(chg[u][s] for u in range(h+1))*dic['chgeff'][0][s] - pulp.lpSum(dchg[u][s] for u in range(h+1))
      GEP += sub_constraint

  for s in range(S):
    sub_constraint = \
    SOC[0][s] == 0 #dic['qstor'][0][0]
    GEP+= sub_constraint
    sub_constraint = \
    chg[0][s] == 0
    GEP+= sub_constraint
    sub_constraint = \
    dchg[0][s] == 0
    GEP+= sub_constraint

  for h in range(2,H):
    for s in range(S):
      GEP += dchg[h][s] <= SOC[h-1][s]


  #(6) Charge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['PCMIN'][0][s] <= chg[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['PCMAX'][0][s] >= chg[h][s]
      GEP += sub_constraint

  #(7) Discharge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['PDMIN'][0][s] <= dchg[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['PDMAX'][0][s] >= dchg[h][s]
      GEP += sub_constraint

  #(8) Single Daily Battery Cycle (Charge)
  for s in range(S):
    sub_constraint = \
    pulp.lpSum(chg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
    GEP += sub_constraint

  #(9) Single Daily Battery Cycle (Discharge)
  for s in range(S):
    sub_constraint = \
    pulp.lpSum(dchg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
    GEP += sub_constraint

  #(10) State of Charge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['SOCMIN'][0][s] <= SOC[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['SOCMAX'][0][s] >= SOC[h][s]
      GEP += sub_constraint

  #(11) No Simultaneous Charging/Discharging
  M = 100000
  for s in range(S):
    for h in range(H):
      GEP += chg[h][s] <= M*z_chg[h][s]
      GEP += dchg[h][s] <= M*z_dchg[h][s]
      GEP += z_chg[h][s] + z_dchg[h][s] <= 1

  #(12) No Charging during Unmet Generation
  M = 100000
  for s in range(S):
    for h in range(H):
      GEP += chg[h][s] <= M*z_chg[h][s]
      GEP += y[h][2] <= M*z_unmet[h]
      GEP += z_chg[h][s] + z_unmet[h] <= 1

  #(13) Utilization Limits
  for h in range(H):
    for i in range(I):
      sub_constraint = \
      x[h][i] <= dic['UTIL'][h][i]
      GEP += sub_constraint

  #(14) Charge Rate Limits
  for h in range(H-1):
    for s in range(S):
      sub_constraint = \
      (SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
      GEP += sub_constraint

  #(15) Discharge Rate Limits
  for h in range(H-1):
    for s in range(S):
      sub_constraint = \
      -1*(SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
      GEP += sub_constraint

  #(16) Purchase Recommendation Limit

  for h in range(H):
    sub_constraint = \
    pulp.lpSum(y[h][0] for h in range(H)) <= sum(demand[h][0] for h in range(H))*purchase_generation_proportion[year_index]
    GEP += sub_constraint


  #(17) Transmission Limit

  for h in range(H):
    sub_constraint = \
    y[h][0] + y[h][1] <= dic['TRANSMAX'][0][0]
    GEP += sub_constraint

  if limit_transmissions_flag == True:
    for h in range(H):
      GEP += y[h][1] == 0




  #(19.1) Dispatch Ramp Up Rate Limits
  for h in range(H-1):
    for i in range(I):
      sub_constraint = \
      x[h+1][i] - x[h][i] <= dic['RAMPUPRATEMAX'][h][i]
      GEP += sub_constraint

  #(19.2) Dispatch Ramp Up Rate Limits
  for h in range(H-1):
    for i in range(I):
      sub_constraint = \
      x[h+1][i] - x[h][i] >= -dic['RAMPDOWNRATEMAX'][h][i]
      GEP += sub_constraint



  #      --------------------------------------------------------------------------------------------------------------------------------------------------

  if limit_emissions_flag == True:
    H = 24

    renewable_indices = [0, 3, 5, 6, 7, 8]
    clean_indices = [0, 2, 3, 5, 6, 7, 8]
    carbonfree_indices = [0, 5, 6, 7, 8]


    # Renewable Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in renewable_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['RPSMIN'][year_index][0]*sum(demand[h][0] for h in range(H))
    GEP += sub_constraint


    # Clean Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['CLEANMIN'][year_index][0]*sum(demand[h][0] for h in range(H))
    GEP += sub_constraint


    # Carbonfree Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['CARBONFREEMIN'][year_index][0]*sum(demand[h][0] for h in range(H))
    GEP += sub_constraint




    # Nuclear Maximums

    sub_constraint = \
    pulp.lpSum(x[h][2] for h in range(H)) <= \
    dic['NUCLEARMAX'][year_index][0]*pulp.lpSum(demand[h][0] for h in range(H))
    GEP += sub_constraint

    #turning nuc maxes off for now so that I can more easily request full nuclear utilization without running into an error


    #H = 30
    # force no natural gas (2035emp for 2035 onward, 2019emp for 2050 onward)

    if year >= 2035:
      for h in range(H):
        sub_constraint = \
        x[h][1] == 0
        GEP += sub_constraint


  # No Nuclear Ramping
  for h in range(H):
    sub_constraint = \
    x[h][2] == capacities[2]*dic['delta'][h][2]
    GEP += sub_constraint

  #(16) Non-Negativity
  # Already forced by variable creation "lowBound = 0"



  #GEP += pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) == purchase_generation_proportion[year_index]*sum(demand[:H])[0]

  #GEP.solve(solver = pulp.GLPK())
  GLPK_flag = True

  if GLPK_flag:
    GEP.solve(solver = pulp.GLPK())
    solver_choice = 'GLPK'
  else:
    GEP.solve()
    solver_choice = 'CBC'

  print("Objective =", pulp.value(GEP.objective))
  print("Solution status =", GEP.status)


  return x, y, dchg, SOC

# %% [markdown]
# ### Chosen example

# %%
winter_flag = False
average_flag = False
high_flag = True
max_flag = False

sunny_flag = True
windy_flag = False

limit_emissions_flag = True
limit_transmissions_flag = False
#dispatch_parameter_resetter()
flag_setter(winter_flag, average_flag, high_flag, max_flag, sunny_flag, windy_flag)

year = 2035
x, y, dchg, SOC = dispatcher(year, limit_emissions_flag, limit_transmissions_flag)
generation_mat, SOC_mat = plotter_2(x, y, dchg, SOC, year)
# Out:
# Objective = 9206566.74048
# Solution status = 1

# %% [markdown]
# #### Store unmet demand vector

# %%
# get the umet demand vector
unmet_demand = np.zeros((30,1))
#unmet_demand[:24] = generation_mat[:,11].reshape(24,1)
#total_unmet_demand = sum(unmet_demand)[0]

# %% [markdown]
# # **3) Dispatch with removed load**
# > We are pretending there is no unmet demand, this file is to test shadow prices. But there was the whole thing about how the 3rd dispatch is the one that incorporates an actual decision for load shedding. But how do we represent shifting?
#
# > So I guess shedding is a decision variable in form of generation, but shifting would just be based on shadow pricing. I guess we'll see...

# %% [markdown]
# ### Removed Demand Plotter

# %%
def removed_demand_plotter(x, y, dchg, SOC, year, unmet_demand):
  #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
  H = 24
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Compile results
  ##
  ############
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index) - unmet_demand

  x_mat = np.zeros((H,I))
  for h in range(H):
    for i in range(I):
      x_mat[h][i] = x[h][i].varValue

  num_columns = x_mat.shape[1]
  temp = np.concatenate((x_mat[:, :1], x_mat[:, 2:], x_mat[:, 1:2]), axis=1)
  x_mat = temp.copy()




  y_mat = np.zeros((H,P))
  for h in range(H):
    for p in range(P):
      y_mat[h][p] = y[h][p].varValue

  dchg_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      dchg_mat[h][s] = dchg[h][s].varValue*dic['dchgeff'][0][s]
      #if sum(x[h][i].varValue for i in range(I)) + sum(y[h][p].varValue for p in range(P)) + sum(dchg[h][s].varValue*dic['dchgeff'][0][s] for s in range(S)) >= demand[h][0] + 1:
      #  dchg_mat[h][s] = 0 #can't work out the logic for why this is necessary, but it is

  SOC_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      SOC_mat[h][s] = SOC[h][s].varValue

  generation_mat = np.zeros((H,I+P+S))
  generation_mat[:,0:I] = x_mat
  generation_mat[:,I:I+P] = y_mat
  generation_mat[:,I+P:I+P+S] = dchg_mat


  ############
  ##
  ##  Plot the dispatch results
  ##
  ############

  plt.figure(figsize=(6, 6))

  tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM", "Backup", "Unmet", "BAT2", "BAT4", 'Demand', 'BAT2 SOC', 'BAT4 SOC']
  color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray", "rosybrown", "red", "darkseagreen", 'purple']

  plt.stackplot(range(H), generation_mat.T, colors = color_list)
  plt.plot(demand[:H], color = 'k')

  plt.plot(range(H),SOC_mat[:,0].T, color = 'gray', linestyle='dashed')
  #plt.plot(range(24),SOC_mat[:,0].T+SOC_mat[:,1].T, color = 'gray', linestyle='dashed')

  plt.plot(range(H),SOC_mat[:,1].T, color = 'black', linestyle='dashed')
  #plt.title(f'Hourly Dispatch: Year = {year}, Solver = {solver_choice}')
  #plt.title(f'Hourly Dispatch: Year = {year}, Winter')
  plt.title(f'Hourly Dispatch: Year = {year}')
  #plt.title(f'Hourly Dispatch: B3')
  #plt.title(f'Hourly Dispatch: F1')

  plt.ylabel('MW Generated')
  plt.xlabel('Hour')

  #plt.legend(tech_list, loc = 'upper right', bbox_to_anchor = (2.4,1), ncol = 3, prop={'size': 16})
  plt.xticks(range(H))
  plt.ylim(0,25000)

  plt.show()
  #plt.legend()
  return generation_mat, SOC_mat

# %% [markdown]
# ### Removed Demand Dispatcher Master Function

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

def removed_demand_dispatcher(year, limit_emissions_flag, limit_transmissions_flag, unmet_demand):

  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Set the year
  ##
  ############

  #year = 2035
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index) - unmet_demand


  '''###### STORAGE CAPACITY LIMITS'''
  dic['qstor'][0][0] = 0*battery_multiplier
  dic['qstor'][0][1] = 2000*battery_multiplier
  #115445

  for s in range(S): # generation capability is based on capacity and battery length
    dic['SOCMAX'][0][s] = dic['qstor'].copy()[0][s]*dic['length'][0][s]
  dic['PCMAX'] = dic['SOCMAX']
  dic['PDMAX'] = dic['SOCMAX']



  ############
  ##
  ##  Setup and run the dispatcher
  ##
  ############

  H = 24

  GEP = pulp.LpProblem("GEP_Problem", pulp.LpMinimize)

  x = [[pulp.LpVariable(f"x_{{{h},{i}}}", lowBound = 0) for i in range(I)] for h in range(H)]
  y = [[pulp.LpVariable(f"y_{{{h},{p}}}", lowBound = 0) for p in range(P)] for h in range(H)]
  chg = [[pulp.LpVariable(f"chg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
  dchg = [[pulp.LpVariable(f"dchg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
  SOC = [[pulp.LpVariable(f"SOC_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]

  z_chg = [[pulp.LpVariable(f"z_chg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
  z_dchg = [[pulp.LpVariable(f"z_dchg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
  z_unmet = [pulp.LpVariable(f"z_dchg_{h}", cat="Binary") for h in range(H)]

  #(1) Variable Operating and Maintenance Costs
  obj_1 = pulp.lpSum(
      pulp.lpSum(
          dic['v'][h][i]*x[h][i] for i in range(I)
      )
      for h in range(H)
  )

  #(2) Electricity Purchase Costs
  obj_2 = pulp.lpSum(
      dic['c'][h][p]*y[h][p] for h in range(H) for p in range(P)
  )

  # OVERALL
  GEP += obj_1 + obj_2



  #(3) Energy Balance
  for h in range(H):
    sub_constraint = \
    pulp.lpSum(x[h][i] for i in range(I)) + pulp.lpSum(y[h][p] for p in range(P)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S)) - pulp.lpSum(chg[h][s] for s in range(S)) == demand[h][0]
    GEP += sub_constraint

  #(4) Generation Capacity Limits
  for i in range(I):
    for h in range(H):
      sub_constraint = \
      x[h][i] <= capacities[i]*dic['delta'][h][i]
      GEP += sub_constraint

  #(5) State of Charge Requirements
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      SOC[h][s] == pulp.lpSum(chg[u][s] for u in range(h+1))*dic['chgeff'][0][s] - pulp.lpSum(dchg[u][s] for u in range(h+1))
      GEP += sub_constraint

  for s in range(S):
    sub_constraint = \
    SOC[0][s] == 0 #dic['qstor'][0][0]
    GEP+= sub_constraint
    sub_constraint = \
    chg[0][s] == 0
    GEP+= sub_constraint
    sub_constraint = \
    dchg[0][s] == 0
    GEP+= sub_constraint

  for h in range(2,H):
    for s in range(S):
      GEP += dchg[h][s] <= SOC[h-1][s]


  #(6) Charge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['PCMIN'][0][s] <= chg[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['PCMAX'][0][s] >= chg[h][s]
      GEP += sub_constraint

  #(7) Discharge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['PDMIN'][0][s] <= dchg[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['PDMAX'][0][s] >= dchg[h][s]
      GEP += sub_constraint

  #(8) Single Daily Battery Cycle (Charge)
  for s in range(S):
    sub_constraint = \
    pulp.lpSum(chg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
    GEP += sub_constraint

  #(9) Single Daily Battery Cycle (Discharge)
  for s in range(S):
    sub_constraint = \
    pulp.lpSum(dchg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
    GEP += sub_constraint

  #(10) State of Charge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['SOCMIN'][0][s] <= SOC[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['SOCMAX'][0][s] >= SOC[h][s]
      GEP += sub_constraint

  #(11) No Simultaneous Charging/Discharging
  M = 100000
  for s in range(S):
    for h in range(H):
      GEP += chg[h][s] <= M*z_chg[h][s]
      GEP += dchg[h][s] <= M*z_dchg[h][s]
      GEP += z_chg[h][s] + z_dchg[h][s] <= 1

  #(12) No Charging during Unmet Generation
  M = 100000
  for s in range(S):
    for h in range(H):
      GEP += chg[h][s] <= M*z_chg[h][s]
      GEP += y[h][2] <= M*z_unmet[h]
      GEP += z_chg[h][s] + z_unmet[h] <= 1

  #(13) Utilization Limits
  for h in range(H):
    for i in range(I):
      sub_constraint = \
      x[h][i] <= dic['UTIL'][h][i]
      GEP += sub_constraint

  #(14) Charge Rate Limits
  for h in range(H-1):
    for s in range(S):
      sub_constraint = \
      (SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
      GEP += sub_constraint

  #(15) Discharge Rate Limits
  for h in range(H-1):
    for s in range(S):
      sub_constraint = \
      -1*(SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
      GEP += sub_constraint

  #(16) Purchase Recommendation Limit

  for h in range(H):
    sub_constraint = \
    pulp.lpSum(y[h][0] for h in range(H)) <= sum(demand[h][0] for h in range(H))*purchase_generation_proportion[year_index]
    GEP += sub_constraint


  #(17) Transmission Limit

  for h in range(H):
    sub_constraint = \
    y[h][0] + y[h][1] <= dic['TRANSMAX'][0][0]
    GEP += sub_constraint

  if limit_transmissions_flag == True:
    for h in range(H):
      GEP += y[h][1] == 0




  #(19.1) Dispatch Ramp Up Rate Limits
  for h in range(H-1):
    for i in range(I):
      sub_constraint = \
      x[h+1][i] - x[h][i] <= dic['RAMPUPRATEMAX'][h][i]
      GEP += sub_constraint

  #(19.2) Dispatch Ramp Up Rate Limits
  for h in range(H-1):
    for i in range(I):
      sub_constraint = \
      x[h+1][i] - x[h][i] >= -dic['RAMPDOWNRATEMAX'][h][i]
      GEP += sub_constraint



  #      --------------------------------------------------------------------------------------------------------------------------------------------------

  if limit_emissions_flag == True:
    H = 24

    renewable_indices = [0, 3, 5, 6, 7, 8]
    clean_indices = [0, 2, 3, 5, 6, 7, 8]
    carbonfree_indices = [0, 5, 6, 7, 8]


    # Renewable Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in renewable_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['RPSMIN'][year_index][0]*sum(demand[h][0] for h in range(H))
    GEP += sub_constraint


    # Clean Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['CLEANMIN'][year_index][0]*sum(demand[h][0] for h in range(H))
    GEP += sub_constraint


    # Carbonfree Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['CARBONFREEMIN'][year_index][0]*sum(demand[h][0] for h in range(H))
    GEP += sub_constraint




    # Nuclear Maximums

    sub_constraint = \
    pulp.lpSum(x[h][2] for h in range(H)) <= \
    dic['NUCLEARMAX'][year_index][0]*pulp.lpSum(demand[h][0] for h in range(H))
    GEP += sub_constraint

    #turning nuc maxes off for now so that I can more easily request full nuclear utilization without running into an error


    #H = 30
    # force no natural gas (2035emp for 2035 onward, 2019emp for 2050 onward)

    if year >= 2035:
      for h in range(H):
        sub_constraint = \
        x[h][1] == 0
        GEP += sub_constraint


  # No Nuclear Ramping
  for h in range(H):
    sub_constraint = \
    x[h][2] == capacities[2]*dic['delta'][h][2]
    GEP += sub_constraint

  #(16) Non-Negativity
  # Already forced by variable creation "lowBound = 0"



  #GEP += pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) == purchase_generation_proportion[year_index]*sum(demand[:H])[0]

  #GEP.solve(solver = pulp.GLPK())
  GLPK_flag = True

  if GLPK_flag:
    GEP.solve(solver = pulp.GLPK())
    solver_choice = 'GLPK'
  else:
    GEP.solve()
    solver_choice = 'CBC'

  print("Objective =", pulp.value(GEP.objective))
  print("Solution status =", GEP.status)


  return x, y, dchg, SOC, GEP

# %% [markdown]
# ### Run to show with unmet demand removed

# %%
x, y, dchg, SOC, model = removed_demand_dispatcher(year, limit_emissions_flag, limit_transmissions_flag, unmet_demand)
generation_mat, SOC_mat = removed_demand_plotter(x, y, dchg, SOC, year, unmet_demand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cd114592f4b4> in <cell line: 1>()
# ----> 1 x, y, dchg, SOC, model = removed_demand_dispatcher(year, limit_emissions_flag, limit_transmissions_flag, unmet_demand)
#       2 generation_mat, SOC_mat = removed_demand_plotter(x, y, dchg, SOC, year, unmet_demand)
#
# NameError: name 'year' is not defined

# %% [markdown]
# # **4) Dispatch with reallocation of load**

# %% [markdown]
# ### Initialize

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

############
##
##  Reset imports and remount
##
############
drive.mount("/content/drive", force_remount=True)
#del xl_name
del wb
del df_sheet_dic
del array_sheet_dic
del dic
del y
del x
# Out:
# Mounted at /content/drive

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

############
##
##  Parameter import and initial setup
##
############

# Import Excel file

# BPU_Project_2_Parameters_2019EMP.xlsx
# BPU_Project_2_Parameters_2035EMP_Extended.xlsx
# BPU_Project_2_Parameters_2019EMP_Winter.xlsx

#shifted_dispatch_xl_name = '/content/drive/MyDrive/Rutgers/BPU/2024_Fall/2/2_Shifted_Dispatch_2035.xlsx'

wb = pd.ExcelFile(shifted_dispatch_xl_name)
sheet_name_list = wb.sheet_names  # see all sheet names

#Turn into a dictionary of Pandas Dataframes
df_sheet_dic = {}
for sheet_name in sheet_name_list:
    df_sheet_dic[sheet_name] = pd.read_excel(shifted_dispatch_xl_name, sheet_name = sheet_name)

# Change to numpy arrays and shave off the indexing/row titles
# Keep the dataframes around for legibility, but create a dictionary of them as numpy arrays for functionality within the minimizer
array_sheet_dic = {}
for sheet_name in sheet_name_list:
  array_sheet_dic[sheet_name] = pd.DataFrame.to_numpy(df_sheet_dic[sheet_name])[:,1:]

# Set constants
H = array_sheet_dic['v'].shape[0]
I = array_sheet_dic['v'].shape[1]
S = array_sheet_dic['qstor'].shape[1]
P = array_sheet_dic['c'].shape[1]

# Just calling dic for convenience in later referencing
dic = array_sheet_dic.copy()

if FC_flag:
  dic['delta'][0][8] = 0.73
else:
    dic['delta'][0][8] = 0


dic['wCUM'] = w_mat.cumsum(axis = 0)

investments_flag = True
if investments_flag == False:
  dic['wCUM'] = dic['wCUM']*0

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Shifted Demand Plotter

# %%
'''TO DO'''


def shifted_demand_plotter(x, y, dchg, SOC, year, unmet_demand, shed_left, shed_now):
  #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
  H = 24
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Compile results
  ##
  ############
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index) - unmet_demand

  x_mat = np.zeros((H,I))
  for h in range(H):
    for i in range(I):
      x_mat[h][i] = x[h][i].varValue

  num_columns = x_mat.shape[1]
  temp = np.concatenate((x_mat[:, :1], x_mat[:, 2:], x_mat[:, 1:2]), axis=1)
  x_mat = temp.copy()




  y_mat = np.zeros((H,P))
  for h in range(H):
    for p in range(P):
      y_mat[h][p] = y[h][p].varValue

  dchg_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      dchg_mat[h][s] = dchg[h][s].varValue*dic['dchgeff'][0][s]
      #if sum(x[h][i].varValue for i in range(I)) + sum(y[h][p].varValue for p in range(P)) + sum(dchg[h][s].varValue*dic['dchgeff'][0][s] for s in range(S)) >= demand[h][0] + 1:
      #  dchg_mat[h][s] = 0 #can't work out the logic for why this is necessary, but it is

  SOC_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      SOC_mat[h][s] = SOC[h][s].varValue

  generation_mat = np.zeros((H,I+P+S))
  generation_mat[:,0:I] = x_mat
  generation_mat[:,I:I+P] = y_mat
  generation_mat[:,I+P:I+P+S] = dchg_mat

  shedding_mat = np.zeros((H,2))
  for h in range(24):
    shedding_mat[h][0] = shed_left[h].varValue
    shedding_mat[h][1] = shed_now[h].varValue

  ############
  ##
  ##  Plot the dispatch results
  ##
  ############

  plt.figure(figsize=(6, 6))

  tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM", "Backup", "Unmet", "BAT2", "BAT4", 'Demand', 'BAT2 SOC', 'BAT4 SOC']
  color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray", "rosybrown", "red", "darkseagreen", 'purple']

  plt.stackplot(range(H), generation_mat.T, colors = color_list)
  plt.plot(demand[:H], color = 'k')

  plt.plot(range(H),SOC_mat[:,0].T, color = 'gray', linestyle='dashed')
  #plt.plot(range(24),SOC_mat[:,0].T+SOC_mat[:,1].T, color = 'gray', linestyle='dashed')

  plt.plot(range(H),SOC_mat[:,1].T, color = 'black', linestyle='dashed')
  #plt.title(f'Hourly Dispatch: Year = {year}, Solver = {solver_choice}')
  #plt.title(f'Hourly Dispatch: Year = {year}, Winter')
  plt.title(f'Hourly Dispatch: Year = {year}')
  #plt.title(f'Hourly Dispatch: B3')
  #plt.title(f'Hourly Dispatch: F1')

  plt.plot(range(H),shedding_mat[:,0].T, color = 'red', linestyle='dashed')

  plt.ylabel('MW Generated')
  plt.xlabel('Hour')

  #plt.legend(tech_list, loc = 'upper right', bbox_to_anchor = (2.4,1), ncol = 3, prop={'size': 16})
  plt.xticks(range(H))
  plt.ylim(0,25000)

  plt.show()
  #plt.legend()
  return generation_mat, SOC_mat

# %%
'''TO DO'''


def shifted_demand_plotter_2(x, y, dchg, SOC, year, unmet_demand, shed_left, shed_now):
  #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
  H = 24
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Compile results
  ##
  ############
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index) - unmet_demand

  x_mat = np.zeros((H,I))
  for h in range(H):
    for i in range(I):
      x_mat[h][i] = x[h][i].varValue

  num_columns = x_mat.shape[1]
  temp = np.concatenate((x_mat[:, :1], x_mat[:, 2:], x_mat[:, 1:2]), axis=1)
  x_mat = temp.copy()




  y_mat = np.zeros((H,P))
  for h in range(H):
    for p in range(P):
      y_mat[h][p] = y[h][p].varValue

  dchg_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      dchg_mat[h][s] = dchg[h][s].varValue*dic['dchgeff'][0][s]
      #if sum(x[h][i].varValue for i in range(I)) + sum(y[h][p].varValue for p in range(P)) + sum(dchg[h][s].varValue*dic['dchgeff'][0][s] for s in range(S)) >= demand[h][0] + 1:
      #  dchg_mat[h][s] = 0 #can't work out the logic for why this is necessary, but it is

  SOC_mat = np.zeros((H,S))
  for h in range(H):
    for s in range(S):
      SOC_mat[h][s] = SOC[h][s].varValue

  generation_mat = np.zeros((H,I+P+S))
  generation_mat[:,0:I] = x_mat
  generation_mat[:,I:I+P] = y_mat
  generation_mat[:,I+P:I+P+S] = dchg_mat

  shedding_mat = np.zeros((30,2))
  for h in range(24):
    shedding_mat[h][0] = shed_left[h].varValue
    shedding_mat[h][1] = shed_now[h].varValue


  for h in range(24):
    demand[h][0] = demand[h][0] + shed_now[h].varValue

  ############
  ##
  ##  Plot the dispatch results
  ##
  ############

  plt.figure(figsize=(6, 6))

  tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM", "Backup", "Unmet", "BAT2", "BAT4", 'Demand', 'BAT2 SOC', 'BAT4 SOC']
  color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray", "rosybrown", "red", "darkseagreen", 'purple']

  plt.stackplot(range(H), generation_mat.T, colors = color_list)
  plt.plot(demand[:H], color = 'k')

  plt.plot(range(H),SOC_mat[:,0].T, color = 'gray', linestyle='dashed')
  #plt.plot(range(24),SOC_mat[:,0].T+SOC_mat[:,1].T, color = 'gray', linestyle='dashed')

  plt.plot(range(H),SOC_mat[:,1].T, color = 'black', linestyle='dashed')
  #plt.title(f'Hourly Dispatch: Year = {year}, Solver = {solver_choice}')
  #plt.title(f'Hourly Dispatch: Year = {year}, Winter')
  plt.title(f'Hourly Dispatch: Year = {year}')
  #plt.title(f'Hourly Dispatch: B3')
  #plt.title(f'Hourly Dispatch: F1')

  plt.plot(range(H),shedding_mat[:24,0].T, color = 'red', linestyle='dashed')

  plt.ylabel('MW Generated')
  plt.xlabel('Hour')

  #plt.legend(tech_list, loc = 'upper right', bbox_to_anchor = (2.4,1), ncol = 3, prop={'size': 16})
  plt.xticks(range(H))
  plt.ylim(0,25000)

  plt.show()
  #plt.legend()
  return generation_mat, SOC_mat

# %% [markdown]
# #### Shifted Demand Dispatcher Master Function

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

def shifted_demand_dispatcher(year, limit_emissions_flag, limit_transmissions_flag, unmet_demand):

  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch
  ########### dispatch dispatch dispatch

  ############
  ##
  ##  Set the year
  ##
  ############

  #year = 2035
  year_index = year - 2021
  capacities = dic['q'][0] + dic['wCUM'][year_index]
  demand = dic['d']*(1.007**year_index) - unmet_demand
  total_unmet_demand = sum(unmet_demand)[0]

  '''###### STORAGE CAPACITY LIMITS'''
  dic['qstor'][0][0] = 0*battery_multiplier
  dic['qstor'][0][1] = 2000*battery_multiplier
  #115445

  for s in range(S): # generation capability is based on capacity and battery length
    dic['SOCMAX'][0][s] = dic['qstor'].copy()[0][s]*dic['length'][0][s]
  dic['PCMAX'] = dic['SOCMAX']
  dic['PDMAX'] = dic['SOCMAX']



  ############
  ##
  ##  Setup and run the dispatcher
  ##
  ############

  H = 24

  GEP = pulp.LpProblem("GEP_Problem", pulp.LpMinimize)

  x = [[pulp.LpVariable(f"x_{{{h},{i}}}", lowBound = 0) for i in range(I)] for h in range(H)]
  y = [[pulp.LpVariable(f"y_{{{h},{p}}}", lowBound = 0) for p in range(P)] for h in range(H)]
  chg = [[pulp.LpVariable(f"chg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
  dchg = [[pulp.LpVariable(f"dchg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
  SOC = [[pulp.LpVariable(f"SOC_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]

  z_chg = [[pulp.LpVariable(f"z_chg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
  z_dchg = [[pulp.LpVariable(f"z_dchg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
  z_unmet = [pulp.LpVariable(f"z_dchg_{h}", cat="Binary") for h in range(H)]

  shed_left = [pulp.LpVariable(f"shed_left_{h}", lowBound = 0) for h in range(H)]
  shed_now = [pulp.LpVariable(f"shed_now_{h}", lowBound = 0) for h in range(H)]

  #(1) Variable Operating and Maintenance Costs
  obj_1 = pulp.lpSum(
      pulp.lpSum(
          dic['v'][h][i]*x[h][i] for i in range(I)
      )
      for h in range(H)
  )

  #(2) Electricity Purchase Costs
  obj_2 = pulp.lpSum(
      dic['c'][h][p]*y[h][p] for h in range(H) for p in range(P)
  )

  #(3) Load Shifting Cost
  obj_3 = pulp.lpSum(
      dic['shift_cost'][h][0]*shed_now[h] for h in range(H)
  )
  # OVERALL
  GEP += obj_1 + obj_2 + obj_3



  #(3) Energy Balance ************
  for h in range(H):
    sub_constraint = \
    pulp.lpSum(x[h][i] for i in range(I)) + pulp.lpSum(y[h][p] for p in range(P)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S)) - pulp.lpSum(chg[h][s] for s in range(S)) == demand[h][0] + shed_now[h]
    GEP += sub_constraint, f'balance_{h}'

  #(4) Generation Capacity Limits
  for i in range(I):
    for h in range(H):
      sub_constraint = \
      x[h][i] <= capacities[i]*dic['delta'][h][i]
      GEP += sub_constraint

  #(5) State of Charge Requirements
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      SOC[h][s] == pulp.lpSum(chg[u][s] for u in range(h+1))*dic['chgeff'][0][s] - pulp.lpSum(dchg[u][s] for u in range(h+1))
      GEP += sub_constraint

  for s in range(S):
    sub_constraint = \
    SOC[0][s] == 0 #dic['qstor'][0][0]
    GEP+= sub_constraint
    sub_constraint = \
    chg[0][s] == 0
    GEP+= sub_constraint
    sub_constraint = \
    dchg[0][s] == 0
    GEP+= sub_constraint

  for h in range(2,H):
    for s in range(S):
      GEP += dchg[h][s] <= SOC[h-1][s]


  #(6) Charge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['PCMIN'][0][s] <= chg[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['PCMAX'][0][s] >= chg[h][s]
      GEP += sub_constraint

  #(7) Discharge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['PDMIN'][0][s] <= dchg[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['PDMAX'][0][s] >= dchg[h][s]
      GEP += sub_constraint

  #(8) Single Daily Battery Cycle (Charge)
  for s in range(S):
    sub_constraint = \
    pulp.lpSum(chg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
    GEP += sub_constraint

  #(9) Single Daily Battery Cycle (Discharge)
  for s in range(S):
    sub_constraint = \
    pulp.lpSum(dchg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
    GEP += sub_constraint

  #(10) State of Charge Limits
  for s in range(S):
    for h in range(H):
      sub_constraint = \
      dic['SOCMIN'][0][s] <= SOC[h][s]
      GEP += sub_constraint

      sub_constraint = \
      dic['SOCMAX'][0][s] >= SOC[h][s]
      GEP += sub_constraint

  #(11) No Simultaneous Charging/Discharging
  M = 100000
  for s in range(S):
    for h in range(H):
      GEP += chg[h][s] <= M*z_chg[h][s]
      GEP += dchg[h][s] <= M*z_dchg[h][s]
      GEP += z_chg[h][s] + z_dchg[h][s] <= 1

  #(12) No Charging during Unmet Generation
  M = 100000
  for s in range(S):
    for h in range(H):
      GEP += chg[h][s] <= M*z_chg[h][s]
      GEP += y[h][2] <= M*z_unmet[h]
      GEP += z_chg[h][s] + z_unmet[h] <= 1

  #(13) Utilization Limits
  for h in range(H):
    for i in range(I):
      sub_constraint = \
      x[h][i] <= dic['UTIL'][h][i]
      GEP += sub_constraint

  #(14) Charge Rate Limits
  for h in range(H-1):
    for s in range(S):
      sub_constraint = \
      (SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
      GEP += sub_constraint

  #(15) Discharge Rate Limits
  for h in range(H-1):
    for s in range(S):
      sub_constraint = \
      -1*(SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
      GEP += sub_constraint

  #(16) Purchase Recommendation Limit

  for h in range(H):
    sub_constraint = \
    pulp.lpSum(y[h][0] for h in range(H)) <= (sum(demand[h][0] for h in range(H)) + total_unmet_demand)*purchase_generation_proportion[year_index]
    GEP += sub_constraint


  #(17) Transmission Limit

  for h in range(H):
    sub_constraint = \
    y[h][0] + y[h][1] <= dic['TRANSMAX'][0][0]
    GEP += sub_constraint

  if limit_transmissions_flag == True:
    for h in range(H):
      GEP += y[h][1] == 0

  #(18) Shedding Functionalities

  #(18.1) Must shed all demand
  GEP += shed_left[0] == total_unmet_demand
  GEP += shed_left[23] == 0

  #(18.2) Can never 'Unshed'
  for h in range(H-1):
    sub_constraint = \
    shed_left[h+1] <= shed_left[h]
    GEP += sub_constraint

  #(18.3) Shedding lowers amount needing to still be shed

  for h in range(H-1):
    sub_constraint = \
    shed_left[h+1] == shed_left[h] - shed_now[h]
    GEP += sub_constraint

  #(18.4) Shedding has hourly limits

  for h in range(H):
    sub_constraint = \
    shed_left[h] <= dic['SHIFTMAX'][h][0]
    GEP += sub_constraint









  #(19.1) Dispatch Ramp Up Rate Limits
  for h in range(H-1):
    for i in range(I):
      sub_constraint = \
      x[h+1][i] - x[h][i] <= dic['RAMPUPRATEMAX'][h][i]
      GEP += sub_constraint

  #(19.2) Dispatch Ramp Up Rate Limits
  for h in range(H-1):
    for i in range(I):
      sub_constraint = \
      x[h+1][i] - x[h][i] >= -dic['RAMPDOWNRATEMAX'][h][i]
      GEP += sub_constraint



  #      --------------------------------------------------------------------------------------------------------------------------------------------------

  if limit_emissions_flag == True:
    H = 24

    renewable_indices = [0, 3, 5, 6, 7, 8]
    clean_indices = [0, 2, 3, 5, 6, 7, 8]
    carbonfree_indices = [0, 5, 6, 7, 8]


    # Renewable Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in renewable_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['RPSMIN'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
    GEP += sub_constraint


    # Clean Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['CLEANMIN'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
    GEP += sub_constraint


    # Carbonfree Minimums
    sub_constraint = \
    pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
    dic['CARBONFREEMIN'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
    GEP += sub_constraint




    # Nuclear Maximums

    sub_constraint = \
    pulp.lpSum(x[h][2] for h in range(H)) <= \
    dic['NUCLEARMAX'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
    GEP += sub_constraint

    #turning nuc maxes off for now so that I can more easily request full nuclear utilization without running into an error


    #H = 30
    # force no natural gas (2035emp for 2035 onward, 2019emp for 2050 onward)

    if year >= 2035:
      for h in range(H):
        sub_constraint = \
        x[h][1] == 0
        GEP += sub_constraint


  # No Nuclear Ramping
  for h in range(H):
    sub_constraint = \
    x[h][2] == capacities[2]*dic['delta'][h][2]
    GEP += sub_constraint

  #(16) Non-Negativity
  # Already forced by variable creation "lowBound = 0"



  #GEP += pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) == purchase_generation_proportion[year_index]*sum(demand[:H])[0]

  #GEP.solve(solver = pulp.GLPK())
  GLPK_flag = True

  if GLPK_flag:
    GEP.solve(solver = pulp.GLPK())
    solver_choice = 'GLPK'
  else:
    GEP.solve()
    solver_choice = 'CBC'

  print("Objective =", pulp.value(GEP.objective))
  print("Solution status =", GEP.status)


  return x, y, dchg, SOC, shed_left, shed_now, GEP

# %% [markdown]
# ### Run to show with unmet demand shifted

# %%
flag_setter(winter_flag, average_flag, high_flag, max_flag, sunny_flag, windy_flag)
x, y, dchg, SOC, shed_left, shed_now, model = shifted_demand_dispatcher(year, limit_emissions_flag, limit_transmissions_flag, unmet_demand)
generation_mat, SOC_mat = shifted_demand_plotter(x, y, dchg, SOC, year, unmet_demand, shed_left, shed_now)
generation_mat, SOC_mat = shifted_demand_plotter_2(x, y, dchg, SOC, year, unmet_demand, shed_left, shed_now)
# Out:
# Objective = 10225166.857797999
# Solution status = 1

# %% [markdown]
# # **5) Explicit model to return shadow prices with labels**

# %% [markdown]
# ### Explicit model

# %%
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch


########### dispatch dispatch dispatch
########### dispatch dispatch dispatch
########### dispatch dispatch dispatch

############
##
##  Set the year
##
############

#year = 2035
year_index = year - 2021
capacities = dic['q'][0] + dic['wCUM'][year_index]
demand = dic['d']*(1.007**year_index) - unmet_demand
total_unmet_demand = sum(unmet_demand)[0]

'''###### STORAGE CAPACITY LIMITS'''
dic['qstor'][0][0] = 0*battery_multiplier
dic['qstor'][0][1] = 2000*battery_multiplier
#115445

for s in range(S): # generation capability is based on capacity and battery length
  dic['SOCMAX'][0][s] = dic['qstor'].copy()[0][s]*dic['length'][0][s]
dic['PCMAX'] = dic['SOCMAX']
dic['PDMAX'] = dic['SOCMAX']



############
##
##  Setup and run the dispatcher
##
############

H = 24

dispatch_model = pulp.LpProblem("dispatch_model_Problem", pulp.LpMinimize)

x = [[pulp.LpVariable(f"x_{{{h},{i}}}", lowBound = 0) for i in range(I)] for h in range(H)]
y = [[pulp.LpVariable(f"y_{{{h},{p}}}", lowBound = 0) for p in range(P)] for h in range(H)]
chg = [[pulp.LpVariable(f"chg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
dchg = [[pulp.LpVariable(f"dchg_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]
SOC = [[pulp.LpVariable(f"SOC_{{{h},{s}}}", lowBound = 0) for s in range(S)] for h in range(H)]

z_chg = [[pulp.LpVariable(f"z_chg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
z_dchg = [[pulp.LpVariable(f"z_dchg_{{{h},{s}}}", cat="Binary") for s in range(S)] for h in range(H)]
z_unmet = [pulp.LpVariable(f"z_dchg_{h}", cat="Binary") for h in range(H)]

shed_left = [pulp.LpVariable(f"shed_left_{h}", lowBound = 0) for h in range(H)]
shed_now = [pulp.LpVariable(f"shed_now_{h}", lowBound = 0) for h in range(H)]

#(1) Variable Operating and Maintenance Costs
obj_1 = pulp.lpSum(
    pulp.lpSum(
        dic['v'][h][i]*x[h][i] for i in range(I)
    )
    for h in range(H)
)

#(2) Electricity Purchase Costs
obj_2 = pulp.lpSum(
    dic['c'][h][p]*y[h][p] for h in range(H) for p in range(P)
)

#(3) Load Shifting Cost
obj_3 = pulp.lpSum(
    dic['shift_cost'][h][0]*shed_now[h] for h in range(H)
)
# OVERALL
dispatch_model += obj_1 + obj_2 + obj_3



#(3) Energy Balance ************
for h in range(H):
  sub_constraint = \
  pulp.lpSum(x[h][i] for i in range(I)) + pulp.lpSum(y[h][p] for p in range(P)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S)) - pulp.lpSum(chg[h][s] for s in range(S)) == demand[h][0] + shed_now[h]
  dispatch_model += sub_constraint, f'balance_{h}'

#(4) Generation Capacity Limits
for i in range(I):
  for h in range(H):
    sub_constraint = \
    x[h][i] <= capacities[i]*dic['delta'][h][i]
    dispatch_model += sub_constraint, f'generation_capacity_{h}_{i}'

#(5) State of Charge Requirements
for s in range(S):
  for h in range(H):
    sub_constraint = \
    SOC[h][s] == pulp.lpSum(chg[u][s] for u in range(h+1))*dic['chgeff'][0][s] - pulp.lpSum(dchg[u][s] for u in range(h+1))
    dispatch_model += sub_constraint

for s in range(S):
  sub_constraint = \
  SOC[0][s] == 0 #dic['qstor'][0][0]
  dispatch_model+= sub_constraint
  sub_constraint = \
  chg[0][s] == 0
  dispatch_model+= sub_constraint
  sub_constraint = \
  dchg[0][s] == 0
  dispatch_model+= sub_constraint

for h in range(2,H):
  for s in range(S):
    dispatch_model += dchg[h][s] <= SOC[h-1][s]


#(6) Charge Limits
for s in range(S):
  for h in range(H):
    sub_constraint = \
    dic['PCMIN'][0][s] <= chg[h][s]
    dispatch_model += sub_constraint

    sub_constraint = \
    dic['PCMAX'][0][s] >= chg[h][s]
    dispatch_model += sub_constraint

#(7) Discharge Limits
for s in range(S):
  for h in range(H):
    sub_constraint = \
    dic['PDMIN'][0][s] <= dchg[h][s]
    dispatch_model += sub_constraint

    sub_constraint = \
    dic['PDMAX'][0][s] >= dchg[h][s]
    dispatch_model += sub_constraint

#(8) Single Daily Battery Cycle (Charge)
for s in range(S):
  sub_constraint = \
  pulp.lpSum(chg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
  dispatch_model += sub_constraint

#(9) Single Daily Battery Cycle (Discharge)
for s in range(S):
  sub_constraint = \
  pulp.lpSum(dchg[h][s] for h in range(H)) <= dic['qstor'][0][s]*dic['length'][0][s]
  dispatch_model += sub_constraint

#(10) State of Charge Limits
for s in range(S):
  for h in range(H):
    sub_constraint = \
    dic['SOCMIN'][0][s] <= SOC[h][s]
    dispatch_model += sub_constraint

    sub_constraint = \
    dic['SOCMAX'][0][s] >= SOC[h][s]
    dispatch_model += sub_constraint

#(11) No Simultaneous Charging/Discharging
M = 100000
for s in range(S):
  for h in range(H):
    dispatch_model += chg[h][s] <= M*z_chg[h][s]
    dispatch_model += dchg[h][s] <= M*z_dchg[h][s]
    dispatch_model += z_chg[h][s] + z_dchg[h][s] <= 1

#(12) No Charging during Unmet Generation
M = 100000
for s in range(S):
  for h in range(H):
    dispatch_model += chg[h][s] <= M*z_chg[h][s]
    dispatch_model += y[h][2] <= M*z_unmet[h]
    dispatch_model += z_chg[h][s] + z_unmet[h] <= 1

#(13) Utilization Limits
for h in range(H):
  for i in range(I):
    sub_constraint = \
    x[h][i] <= dic['UTIL'][h][i]
    dispatch_model += sub_constraint

#(14) Charge Rate Limits
for h in range(H-1):
  for s in range(S):
    sub_constraint = \
    (SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
    dispatch_model += sub_constraint

#(15) Discharge Rate Limits
for h in range(H-1):
  for s in range(S):
    sub_constraint = \
    -1*(SOC[h+1][s] - SOC[h][s]) <= dic['qstor'][0][s]
    dispatch_model += sub_constraint

#(16) Purchase Recommendation Limit

for h in range(H):
  sub_constraint = \
  pulp.lpSum(y[h][0] for h in range(H)) <= (sum(demand[h][0] for h in range(H)) + total_unmet_demand)*purchase_generation_proportion[year_index]
  dispatch_model += sub_constraint, f'purchase_recommendation_{h}'


#(17) Transmission Limit

for h in range(H):
  sub_constraint = \
  y[h][0] + y[h][1] <= dic['TRANSMAX'][0][0]
  dispatch_model += sub_constraint, f'transmission_limit_{h}'

if limit_transmissions_flag == True:
  for h in range(H):
    dispatch_model += y[h][1] == 0


####### THIS SHOULD NOT BE NECESSARY AS total_unmet_demand SHOULD BE SET TO ZERO UNDER THIS EDITION OF THE MODEL
#(18) Shedding Functionalities

#(18.1) Must shed all demand
dispatch_model += shed_left[0] == total_unmet_demand
dispatch_model += shed_left[23] == 0

#(18.2) Can never 'Unshed'
for h in range(H-1):
  sub_constraint = \
  shed_left[h+1] <= shed_left[h]
  dispatch_model += sub_constraint

#(18.3) Shedding lowers amount needing to still be shed

for h in range(H-1):
  sub_constraint = \
  shed_left[h+1] == shed_left[h] - shed_now[h]
  dispatch_model += sub_constraint

#(18.4) Shedding has hourly limits

for h in range(H):
  sub_constraint = \
  shed_left[h] <= dic['SHIFTMAX'][h][0]
  dispatch_model += sub_constraint, f'shedding_limits_{h}'









#(19.1) Dispatch Ramp Up Rate Limits
for h in range(H-1):
  for i in range(I):
    sub_constraint = \
    x[h+1][i] - x[h][i] <= dic['RAMPUPRATEMAX'][h][i]
    dispatch_model += sub_constraint, f'ramp_up_rate_max_{h}_{i}'

#(19.2) Dispatch Ramp Up Rate Limits
for h in range(H-1):
  for i in range(I):
    sub_constraint = \
    x[h+1][i] - x[h][i] >= -dic['RAMPDOWNRATEMAX'][h][i]
    dispatch_model += sub_constraint, f'ramp_down_rate_max_{h}_{i}'











#(20) Shifting Functionalities

# Need to add shift cost to the objective
# Create variable representing how much to shift from hour i to hour j. Consider issue of simultaneous shifting i to j and j to i. If this occurs maybe just set upper triangle of shift cost matrix to Infinity
# Need to create constraint where amount MW shifted from i to j == 0, allowing us to see shadow price (potential benefit) of shifting load

#      --------------------------------------------------------------------------------------------------------------------------------------------------

if limit_emissions_flag == True:
  H = 24

  renewable_indices = [0, 3, 5, 6, 7, 8]
  clean_indices = [0, 2, 3, 5, 6, 7, 8]
  carbonfree_indices = [0, 5, 6, 7, 8]


  # Renewable Minimums
  sub_constraint = \
  pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in renewable_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
  dic['RPSMIN'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
  dispatch_model += sub_constraint


  # Clean Minimums
  sub_constraint = \
  pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
  dic['CLEANMIN'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
  dispatch_model += sub_constraint


  # Carbonfree Minimums
  sub_constraint = \
  pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) + pulp.lpSum(pulp.lpSum(x[h][i] for i in clean_indices) for h in range(H)) + pulp.lpSum(dchg[h][s]*dic['dchgeff'][0][s] for s in range(S) for h in range(H)) >= \
  dic['CARBONFREEMIN'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
  dispatch_model += sub_constraint




  # Nuclear Maximums

  sub_constraint = \
  pulp.lpSum(x[h][2] for h in range(H)) <= \
  dic['NUCLEARMAX'][year_index][0]*(sum(demand[h][0] for h in range(H)) + total_unmet_demand)
  dispatch_model += sub_constraint

  #turning nuc maxes off for now so that I can more easily request full nuclear utilization without running into an error


  #H = 30
  # force no natural gas (2035emp for 2035 onward, 2019emp for 2050 onward)

  if year >= 2035:
    for h in range(H):
      sub_constraint = \
      x[h][1] == 0
      dispatch_model += sub_constraint


# No Nuclear Ramping
for h in range(H):
  sub_constraint = \
  x[h][2] == capacities[2]*dic['delta'][h][2]
  dispatch_model += sub_constraint, f'nuclear_ramping_{h}'

#(16) Non-Negativity
# Already forced by variable creation "lowBound = 0"



#dispatch_model += pulp.lpSum(y[h][p] for p in range(P) for h in range(H)) == purchase_generation_proportion[year_index]*sum(demand[:H])[0]

#dispatch_model.solve(solver = pulp.GLPK())
GLPK_flag = False

if GLPK_flag:
  dispatch_model.solve(solver = pulp.GLPK())
  solver_choice = 'GLPK'
else:
  dispatch_model.solve()
  solver_choice = 'CBC'

print("Objective =", pulp.value(dispatch_model.objective))
print("Solution status =", dispatch_model.status)


#return x, y, dchg, SOC, shed_left, shed_now, dispatch_model

generation_mat, SOC_mat = shifted_demand_plotter(x, y, dchg, SOC, year, unmet_demand, shed_left, shed_now)
generation_mat, SOC_mat = shifted_demand_plotter_2(x, y, dchg, SOC, year, unmet_demand, shed_left, shed_now)
# Out:
# Objective = 9206562.41956
# Solution status = 1

# %%
for constraint in dispatch_model.constraints.values():
    print(f"{constraint.name}: Shadow price = {constraint.pi}")
# Out:
# balance_0: Shadow price = 100.0
# balance_1: Shadow price = 100.0
# balance_2: Shadow price = 100.0
# balance_3: Shadow price = 70.0
# balance_4: Shadow price = 0.0
# balance_5: Shadow price = 0.0
# balance_6: Shadow price = 0.0
# balance_7: Shadow price = 0.0
# balance_8: Shadow price = 0.0
# balance_9: Shadow price = 0.0
# balance_10: Shadow price = 0.0
# balance_11: Shadow price = 0.0
# balance_12: Shadow price = 100.0
# balance_13: Shadow price = 100.0
# balance_14: Shadow price = 100.0
# balance_15: Shadow price = 100.0
# balance_16: Shadow price = 100.0
# balance_17: Shadow price = 100.0
# balance_18: Shadow price = 100.0
# balance_19: Shadow price = 100.0
# balance_20: Shadow price = 1000.0
# balance_21: Shadow price = 1000.0
# balance_22: Shadow price = 100.0
# balance_23: Shadow price = 100.0
# generation_capacity_0_0: Shadow price = -98.54
# generation_capacity_1_0: Shadow price = -98.54
# generation_capacity_2_0: Shadow price = -98.54
# generation_capacity_3_0: Shadow price = -68.54
# generation_capacity_4_0: Shadow price = 0.0
# generation_capacity_5_0: Shadow price = 0.0
# generation_capacity_6_0: Shadow price = 0.0
# generation_capacity_7_0: Shadow price = 0.0
# generation_capacity_8_0: Shadow price = 0.0
# generation_capacity_9_0: Shadow price = 0.0
# generation_capacity_10_0: Shadow price = 0.0
# generation_capacity_11_0: Shadow price = 0.0
# generation_capacity_12_0: Shadow price = -98.54
# generation_capacity_13_0: Shadow price = -98.54
# generation_capacity_14_0: Shadow price = -98.54
# generation_capacity_15_0: Shadow price = -98.54
# generation_capacity_16_0: Shadow price = -98.54
# generation_capacity_17_0: Shadow price = -98.54
# generation_capacity_18_0: Shadow price = -98.54
# generation_capacity_19_0: Shadow price = -98.54
# generation_capacity_20_0: Shadow price = -998.54
# generation_capacity_21_0: Shadow price = -998.54
# generation_capacity_22_0: Shadow price = -98.54
# generation_capacity_23_0: Shadow price = -98.54
# generation_capacity_0_1: Shadow price = 0.0
# generation_capacity_1_1: Shadow price = 0.0
# generation_capacity_2_1: Shadow price = 0.0
# generation_capacity_3_1: Shadow price = 0.0
# generation_capacity_4_1: Shadow price = 0.0
# generation_capacity_5_1: Shadow price = 0.0
# generation_capacity_6_1: Shadow price = 0.0
# generation_capacity_7_1: Shadow price = 0.0
# generation_capacity_8_1: Shadow price = 0.0
# generation_capacity_9_1: Shadow price = 0.0
# generation_capacity_10_1: Shadow price = 0.0
# generation_capacity_11_1: Shadow price = 0.0
# generation_capacity_12_1: Shadow price = 0.0
# generation_capacity_13_1: Shadow price = 0.0
# generation_capacity_14_1: Shadow price = 0.0
# generation_capacity_15_1: Shadow price = 0.0
# generation_capacity_16_1: Shadow price = 0.0
# generation_capacity_17_1: Shadow price = 0.0
# generation_capacity_18_1: Shadow price = 0.0
# generation_capacity_19_1: Shadow price = 0.0
# generation_capacity_20_1: Shadow price = 0.0
# generation_capacity_21_1: Shadow price = 0.0
# generation_capacity_22_1: Shadow price = 0.0
# generation_capacity_23_1: Shadow price = 0.0
# generation_capacity_0_2: Shadow price = -97.52
# generation_capacity_1_2: Shadow price = -97.52
# generation_capacity_2_2: Shadow price = -97.52
# generation_capacity_3_2: Shadow price = -67.52
# generation_capacity_4_2: Shadow price = 0.0
# generation_capacity_5_2: Shadow price = 0.0
# generation_capacity_6_2: Shadow price = 0.0
# generation_capacity_7_2: Shadow price = 0.0
# generation_capacity_8_2: Shadow price = 0.0
# generation_capacity_9_2: Shadow price = 0.0
# generation_capacity_10_2: Shadow price = 0.0
# generation_capacity_11_2: Shadow price = 0.0
# generation_capacity_12_2: Shadow price = -97.52
# generation_capacity_13_2: Shadow price = -97.52
# generation_capacity_14_2: Shadow price = -97.52
# generation_capacity_15_2: Shadow price = -97.52
# generation_capacity_16_2: Shadow price = -97.52
# generation_capacity_17_2: Shadow price = -97.52
# generation_capacity_18_2: Shadow price = -97.52
# generation_capacity_19_2: Shadow price = -97.52
# generation_capacity_20_2: Shadow price = -997.52
# generation_capacity_21_2: Shadow price = -997.52
# generation_capacity_22_2: Shadow price = -97.52
# generation_capacity_23_2: Shadow price = -97.52
# generation_capacity_0_3: Shadow price = -94.94
# generation_capacity_1_3: Shadow price = -94.94
# generation_capacity_2_3: Shadow price = -94.94
# generation_capacity_3_3: Shadow price = -64.94
# generation_capacity_4_3: Shadow price = 0.0
# generation_capacity_5_3: Shadow price = 0.0
# generation_capacity_6_3: Shadow price = 0.0
# generation_capacity_7_3: Shadow price = 0.0
# generation_capacity_8_3: Shadow price = 0.0
# generation_capacity_9_3: Shadow price = 0.0
# generation_capacity_10_3: Shadow price = 0.0
# generation_capacity_11_3: Shadow price = 0.0
# generation_capacity_12_3: Shadow price = -94.94
# generation_capacity_13_3: Shadow price = -94.94
# generation_capacity_14_3: Shadow price = -94.94
# generation_capacity_15_3: Shadow price = -94.94
# generation_capacity_16_3: Shadow price = -94.94
# generation_capacity_17_3: Shadow price = -94.94
# generation_capacity_18_3: Shadow price = -94.94
# generation_capacity_19_3: Shadow price = -94.94
# generation_capacity_20_3: Shadow price = -994.94
# generation_capacity_21_3: Shadow price = -994.94
# generation_capacity_22_3: Shadow price = -94.94
# generation_capacity_23_3: Shadow price = -94.94
# generation_capacity_0_4: Shadow price = -95.08
# generation_capacity_1_4: Shadow price = -95.08
# generation_capacity_2_4: Shadow price = -95.08
# generation_capacity_3_4: Shadow price = -65.08
# generation_capacity_4_4: Shadow price = 0.0
# generation_capacity_5_4: Shadow price = 0.0
# generation_capacity_6_4: Shadow price = 0.0
# generation_capacity_7_4: Shadow price = 0.0
# generation_capacity_8_4: Shadow price = 0.0
# generation_capacity_9_4: Shadow price = 0.0
# generation_capacity_10_4: Shadow price = 0.0
# generation_capacity_11_4: Shadow price = 0.0
# generation_capacity_12_4: Shadow price = -95.08
# generation_capacity_13_4: Shadow price = -95.08
# generation_capacity_14_4: Shadow price = -95.08
# generation_capacity_15_4: Shadow price = -95.08
# generation_capacity_16_4: Shadow price = -95.08
# generation_capacity_17_4: Shadow price = -95.08
# generation_capacity_18_4: Shadow price = -95.08
# generation_capacity_19_4: Shadow price = -95.08
# generation_capacity_20_4: Shadow price = -995.08
# generation_capacity_21_4: Shadow price = -995.08
# generation_capacity_22_4: Shadow price = -95.08
# generation_capacity_23_4: Shadow price = -95.08
# generation_capacity_0_5: Shadow price = -100.0
# generation_capacity_1_5: Shadow price = -100.0
# generation_capacity_2_5: Shadow price = -100.0
# generation_capacity_3_5: Shadow price = -70.0
# generation_capacity_4_5: Shadow price = 0.0
# generation_capacity_5_5: Shadow price = 0.0
# generation_capacity_6_5: Shadow price = 0.0
# generation_capacity_7_5: Shadow price = 0.0
# generation_capacity_8_5: Shadow price = 0.0
# generation_capacity_9_5: Shadow price = 0.0
# generation_capacity_10_5: Shadow price = 0.0
# generation_capacity_11_5: Shadow price = 0.0
# generation_capacity_12_5: Shadow price = -100.0
# generation_capacity_13_5: Shadow price = -100.0
# generation_capacity_14_5: Shadow price = -100.0
# generation_capacity_15_5: Shadow price = -100.0
# generation_capacity_16_5: Shadow price = -100.0
# generation_capacity_17_5: Shadow price = -100.0
# generation_capacity_18_5: Shadow price = -100.0
# generation_capacity_19_5: Shadow price = -100.0
# generation_capacity_20_5: Shadow price = -1000.0
# generation_capacity_21_5: Shadow price = -1000.0
# generation_capacity_22_5: Shadow price = -100.0
# generation_capacity_23_5: Shadow price = -100.0
# generation_capacity_0_6: Shadow price = -100.0
# generation_capacity_1_6: Shadow price = -100.0
# generation_capacity_2_6: Shadow price = -100.0
# generation_capacity_3_6: Shadow price = -70.0
# generation_capacity_4_6: Shadow price = 0.0
# generation_capacity_5_6: Shadow price = 0.0
# generation_capacity_6_6: Shadow price = 0.0
# generation_capacity_7_6: Shadow price = 0.0
# generation_capacity_8_6: Shadow price = 0.0
# generation_capacity_9_6: Shadow price = 0.0
# generation_capacity_10_6: Shadow price = 0.0
# generation_capacity_11_6: Shadow price = 0.0
# generation_capacity_12_6: Shadow price = -100.0
# generation_capacity_13_6: Shadow price = -100.0
# generation_capacity_14_6: Shadow price = -100.0
# generation_capacity_15_6: Shadow price = -100.0
# generation_capacity_16_6: Shadow price = -100.0
# generation_capacity_17_6: Shadow price = -100.0
# generation_capacity_18_6: Shadow price = -100.0
# generation_capacity_19_6: Shadow price = -100.0
# generation_capacity_20_6: Shadow price = -1000.0
# generation_capacity_21_6: Shadow price = -1000.0
# generation_capacity_22_6: Shadow price = -100.0
# generation_capacity_23_6: Shadow price = -100.0
# generation_capacity_0_7: Shadow price = -100.0
# generation_capacity_1_7: Shadow price = -100.0
# generation_capacity_2_7: Shadow price = -100.0
# generation_capacity_3_7: Shadow price = -70.0
# generation_capacity_4_7: Shadow price = 0.0
# generation_capacity_5_7: Shadow price = 0.0
# generation_capacity_6_7: Shadow price = 0.0
# generation_capacity_7_7: Shadow price = 0.0
# generation_capacity_8_7: Shadow price = 0.0
# generation_capacity_9_7: Shadow price = 0.0
# generation_capacity_10_7: Shadow price = 0.0
# generation_capacity_11_7: Shadow price = 0.0
# generation_capacity_12_7: Shadow price = -100.0
# generation_capacity_13_7: Shadow price = -100.0
# generation_capacity_14_7: Shadow price = -100.0
# generation_capacity_15_7: Shadow price = -100.0
# generation_capacity_16_7: Shadow price = -100.0
# generation_capacity_17_7: Shadow price = -100.0
# generation_capacity_18_7: Shadow price = -100.0
# generation_capacity_19_7: Shadow price = -100.0
# generation_capacity_20_7: Shadow price = -1000.0
# generation_capacity_21_7: Shadow price = -1000.0
# generation_capacity_22_7: Shadow price = -100.0
# generation_capacity_23_7: Shadow price = -100.0
# generation_capacity_0_8: Shadow price = -99.38
# generation_capacity_1_8: Shadow price = -99.38
# generation_capacity_2_8: Shadow price = -99.38
# generation_capacity_3_8: Shadow price = -69.38
# generation_capacity_4_8: Shadow price = 0.0
# generation_capacity_5_8: Shadow price = 0.0
# generation_capacity_6_8: Shadow price = 0.0
# generation_capacity_7_8: Shadow price = 0.0
# generation_capacity_8_8: Shadow price = 0.0
# generation_capacity_9_8: Shadow price = 0.0
# generation_capacity_10_8: Shadow price = 0.0
# generation_capacity_11_8: Shadow price = 0.0
# generation_capacity_12_8: Shadow price = -99.38
# generation_capacity_13_8: Shadow price = -99.38
# generation_capacity_14_8: Shadow price = -99.38
# generation_capacity_15_8: Shadow price = -99.38
# generation_capacity_16_8: Shadow price = -99.38
# generation_capacity_17_8: Shadow price = -99.38
# generation_capacity_18_8: Shadow price = -99.38
# generation_capacity_19_8: Shadow price = -99.38
# generation_capacity_20_8: Shadow price = -999.38
# generation_capacity_21_8: Shadow price = -999.38
# generation_capacity_22_8: Shadow price = -99.38
# generation_capacity_23_8: Shadow price = -99.38
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 1.4210855e-14
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 765.0
# None: Shadow price = 0.0
# None: Shadow price = -765.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -59.5
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -850.0
# None: Shadow price = 0.0
# None: Shadow price = -850.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -85.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -1.4210855e-14
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -1.4210855e-14
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -765.0
# None: Shadow price = 0.0
# None: Shadow price = -765.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# purchase_recommendation_0: Shadow price = -40.0
# purchase_recommendation_1: Shadow price = 0.0
# purchase_recommendation_2: Shadow price = 0.0
# purchase_recommendation_3: Shadow price = 0.0
# purchase_recommendation_4: Shadow price = 0.0
# purchase_recommendation_5: Shadow price = 0.0
# purchase_recommendation_6: Shadow price = 0.0
# purchase_recommendation_7: Shadow price = 0.0
# purchase_recommendation_8: Shadow price = 0.0
# purchase_recommendation_9: Shadow price = 0.0
# purchase_recommendation_10: Shadow price = 0.0
# purchase_recommendation_11: Shadow price = 0.0
# purchase_recommendation_12: Shadow price = 0.0
# purchase_recommendation_13: Shadow price = 0.0
# purchase_recommendation_14: Shadow price = 0.0
# purchase_recommendation_15: Shadow price = 0.0
# purchase_recommendation_16: Shadow price = 0.0
# purchase_recommendation_17: Shadow price = 0.0
# purchase_recommendation_18: Shadow price = 0.0
# purchase_recommendation_19: Shadow price = 0.0
# purchase_recommendation_20: Shadow price = 0.0
# purchase_recommendation_21: Shadow price = 0.0
# purchase_recommendation_22: Shadow price = 0.0
# purchase_recommendation_23: Shadow price = 0.0
# transmission_limit_0: Shadow price = 0.0
# transmission_limit_1: Shadow price = 0.0
# transmission_limit_2: Shadow price = 0.0
# transmission_limit_3: Shadow price = 0.0
# transmission_limit_4: Shadow price = 0.0
# transmission_limit_5: Shadow price = 0.0
# transmission_limit_6: Shadow price = 0.0
# transmission_limit_7: Shadow price = 0.0
# transmission_limit_8: Shadow price = 0.0
# transmission_limit_9: Shadow price = 0.0
# transmission_limit_10: Shadow price = 0.0
# transmission_limit_11: Shadow price = 0.0
# transmission_limit_12: Shadow price = 0.0
# transmission_limit_13: Shadow price = 0.0
# transmission_limit_14: Shadow price = 0.0
# transmission_limit_15: Shadow price = 0.0
# transmission_limit_16: Shadow price = 0.0
# transmission_limit_17: Shadow price = 0.0
# transmission_limit_18: Shadow price = 0.0
# transmission_limit_19: Shadow price = 0.0
# transmission_limit_20: Shadow price = -900.0
# transmission_limit_21: Shadow price = -900.0
# transmission_limit_22: Shadow price = 0.0
# transmission_limit_23: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -0.0
# None: Shadow price = -0.0
# None: Shadow price = -0.0
# shedding_limits_0: Shadow price = 0.0
# shedding_limits_1: Shadow price = 0.0
# shedding_limits_2: Shadow price = 0.0
# shedding_limits_3: Shadow price = 0.0
# shedding_limits_4: Shadow price = 0.0
# shedding_limits_5: Shadow price = 0.0
# shedding_limits_6: Shadow price = 0.0
# shedding_limits_7: Shadow price = 0.0
# shedding_limits_8: Shadow price = 0.0
# shedding_limits_9: Shadow price = 0.0
# shedding_limits_10: Shadow price = 0.0
# shedding_limits_11: Shadow price = 0.0
# shedding_limits_12: Shadow price = 0.0
# shedding_limits_13: Shadow price = 0.0
# shedding_limits_14: Shadow price = 0.0
# shedding_limits_15: Shadow price = 0.0
# shedding_limits_16: Shadow price = 0.0
# shedding_limits_17: Shadow price = 0.0
# shedding_limits_18: Shadow price = 0.0
# shedding_limits_19: Shadow price = 0.0
# shedding_limits_20: Shadow price = 0.0
# shedding_limits_21: Shadow price = 0.0
# shedding_limits_22: Shadow price = 0.0
# shedding_limits_23: Shadow price = 0.0
# ramp_up_rate_max_0_0: Shadow price = 0.0
# ramp_up_rate_max_0_1: Shadow price = 0.0
# ramp_up_rate_max_0_2: Shadow price = 0.0
# ramp_up_rate_max_0_3: Shadow price = 0.0
# ramp_up_rate_max_0_4: Shadow price = 0.0
# ramp_up_rate_max_0_5: Shadow price = 0.0
# ramp_up_rate_max_0_6: Shadow price = 0.0
# ramp_up_rate_max_0_7: Shadow price = 0.0
# ramp_up_rate_max_0_8: Shadow price = 0.0
# ramp_up_rate_max_1_0: Shadow price = 0.0
# ramp_up_rate_max_1_1: Shadow price = 0.0
# ramp_up_rate_max_1_2: Shadow price = 0.0
# ramp_up_rate_max_1_3: Shadow price = 0.0
# ramp_up_rate_max_1_4: Shadow price = 0.0
# ramp_up_rate_max_1_5: Shadow price = 0.0
# ramp_up_rate_max_1_6: Shadow price = 0.0
# ramp_up_rate_max_1_7: Shadow price = 0.0
# ramp_up_rate_max_1_8: Shadow price = 0.0
# ramp_up_rate_max_2_0: Shadow price = 0.0
# ramp_up_rate_max_2_1: Shadow price = 0.0
# ramp_up_rate_max_2_2: Shadow price = 0.0
# ramp_up_rate_max_2_3: Shadow price = 0.0
# ramp_up_rate_max_2_4: Shadow price = 0.0
# ramp_up_rate_max_2_5: Shadow price = 0.0
# ramp_up_rate_max_2_6: Shadow price = 0.0
# ramp_up_rate_max_2_7: Shadow price = 0.0
# ramp_up_rate_max_2_8: Shadow price = 0.0
# ramp_up_rate_max_3_0: Shadow price = 0.0
# ramp_up_rate_max_3_1: Shadow price = 0.0
# ramp_up_rate_max_3_2: Shadow price = 0.0
# ramp_up_rate_max_3_3: Shadow price = 0.0
# ramp_up_rate_max_3_4: Shadow price = 0.0
# ramp_up_rate_max_3_5: Shadow price = 0.0
# ramp_up_rate_max_3_6: Shadow price = 0.0
# ramp_up_rate_max_3_7: Shadow price = 0.0
# ramp_up_rate_max_3_8: Shadow price = 0.0
# ramp_up_rate_max_4_0: Shadow price = 0.0
# ramp_up_rate_max_4_1: Shadow price = 0.0
# ramp_up_rate_max_4_2: Shadow price = 0.0
# ramp_up_rate_max_4_3: Shadow price = 0.0
# ramp_up_rate_max_4_4: Shadow price = 0.0
# ramp_up_rate_max_4_5: Shadow price = 0.0
# ramp_up_rate_max_4_6: Shadow price = 0.0
# ramp_up_rate_max_4_7: Shadow price = 0.0
# ramp_up_rate_max_4_8: Shadow price = 0.0
# ramp_up_rate_max_5_0: Shadow price = 0.0
# ramp_up_rate_max_5_1: Shadow price = 0.0
# ramp_up_rate_max_5_2: Shadow price = 0.0
# ramp_up_rate_max_5_3: Shadow price = 0.0
# ramp_up_rate_max_5_4: Shadow price = 0.0
# ramp_up_rate_max_5_5: Shadow price = 0.0
# ramp_up_rate_max_5_6: Shadow price = 0.0
# ramp_up_rate_max_5_7: Shadow price = 0.0
# ramp_up_rate_max_5_8: Shadow price = 0.0
# ramp_up_rate_max_6_0: Shadow price = 0.0
# ramp_up_rate_max_6_1: Shadow price = 0.0
# ramp_up_rate_max_6_2: Shadow price = 0.0
# ramp_up_rate_max_6_3: Shadow price = 0.0
# ramp_up_rate_max_6_4: Shadow price = 0.0
# ramp_up_rate_max_6_5: Shadow price = 0.0
# ramp_up_rate_max_6_6: Shadow price = 0.0
# ramp_up_rate_max_6_7: Shadow price = 0.0
# ramp_up_rate_max_6_8: Shadow price = 0.0
# ramp_up_rate_max_7_0: Shadow price = 0.0
# ramp_up_rate_max_7_1: Shadow price = 0.0
# ramp_up_rate_max_7_2: Shadow price = 0.0
# ramp_up_rate_max_7_3: Shadow price = 0.0
# ramp_up_rate_max_7_4: Shadow price = 0.0
# ramp_up_rate_max_7_5: Shadow price = 0.0
# ramp_up_rate_max_7_6: Shadow price = 0.0
# ramp_up_rate_max_7_7: Shadow price = 0.0
# ramp_up_rate_max_7_8: Shadow price = 0.0
# ramp_up_rate_max_8_0: Shadow price = 0.0
# ramp_up_rate_max_8_1: Shadow price = 0.0
# ramp_up_rate_max_8_2: Shadow price = 0.0
# ramp_up_rate_max_8_3: Shadow price = 0.0
# ramp_up_rate_max_8_4: Shadow price = 0.0
# ramp_up_rate_max_8_5: Shadow price = 0.0
# ramp_up_rate_max_8_6: Shadow price = 0.0
# ramp_up_rate_max_8_7: Shadow price = 0.0
# ramp_up_rate_max_8_8: Shadow price = 0.0
# ramp_up_rate_max_9_0: Shadow price = 0.0
# ramp_up_rate_max_9_1: Shadow price = 0.0
# ramp_up_rate_max_9_2: Shadow price = 0.0
# ramp_up_rate_max_9_3: Shadow price = 0.0
# ramp_up_rate_max_9_4: Shadow price = 0.0
# ramp_up_rate_max_9_5: Shadow price = 0.0
# ramp_up_rate_max_9_6: Shadow price = 0.0
# ramp_up_rate_max_9_7: Shadow price = 0.0
# ramp_up_rate_max_9_8: Shadow price = 0.0
# ramp_up_rate_max_10_0: Shadow price = 0.0
# ramp_up_rate_max_10_1: Shadow price = 0.0
# ramp_up_rate_max_10_2: Shadow price = 0.0
# ramp_up_rate_max_10_3: Shadow price = 0.0
# ramp_up_rate_max_10_4: Shadow price = 0.0
# ramp_up_rate_max_10_5: Shadow price = 0.0
# ramp_up_rate_max_10_6: Shadow price = 0.0
# ramp_up_rate_max_10_7: Shadow price = 0.0
# ramp_up_rate_max_10_8: Shadow price = 0.0
# ramp_up_rate_max_11_0: Shadow price = 0.0
# ramp_up_rate_max_11_1: Shadow price = 0.0
# ramp_up_rate_max_11_2: Shadow price = 0.0
# ramp_up_rate_max_11_3: Shadow price = 0.0
# ramp_up_rate_max_11_4: Shadow price = 0.0
# ramp_up_rate_max_11_5: Shadow price = 0.0
# ramp_up_rate_max_11_6: Shadow price = 0.0
# ramp_up_rate_max_11_7: Shadow price = 0.0
# ramp_up_rate_max_11_8: Shadow price = 0.0
# ramp_up_rate_max_12_0: Shadow price = 0.0
# ramp_up_rate_max_12_1: Shadow price = 0.0
# ramp_up_rate_max_12_2: Shadow price = 0.0
# ramp_up_rate_max_12_3: Shadow price = 0.0
# ramp_up_rate_max_12_4: Shadow price = 0.0
# ramp_up_rate_max_12_5: Shadow price = 0.0
# ramp_up_rate_max_12_6: Shadow price = 0.0
# ramp_up_rate_max_12_7: Shadow price = 0.0
# ramp_up_rate_max_12_8: Shadow price = 0.0
# ramp_up_rate_max_13_0: Shadow price = 0.0
# ramp_up_rate_max_13_1: Shadow price = 0.0
# ramp_up_rate_max_13_2: Shadow price = 0.0
# ramp_up_rate_max_13_3: Shadow price = 0.0
# ramp_up_rate_max_13_4: Shadow price = 0.0
# ramp_up_rate_max_13_5: Shadow price = 0.0
# ramp_up_rate_max_13_6: Shadow price = 0.0
# ramp_up_rate_max_13_7: Shadow price = 0.0
# ramp_up_rate_max_13_8: Shadow price = 0.0
# ramp_up_rate_max_14_0: Shadow price = 0.0
# ramp_up_rate_max_14_1: Shadow price = 0.0
# ramp_up_rate_max_14_2: Shadow price = 0.0
# ramp_up_rate_max_14_3: Shadow price = 0.0
# ramp_up_rate_max_14_4: Shadow price = 0.0
# ramp_up_rate_max_14_5: Shadow price = 0.0
# ramp_up_rate_max_14_6: Shadow price = 0.0
# ramp_up_rate_max_14_7: Shadow price = 0.0
# ramp_up_rate_max_14_8: Shadow price = 0.0
# ramp_up_rate_max_15_0: Shadow price = 0.0
# ramp_up_rate_max_15_1: Shadow price = 0.0
# ramp_up_rate_max_15_2: Shadow price = 0.0
# ramp_up_rate_max_15_3: Shadow price = 0.0
# ramp_up_rate_max_15_4: Shadow price = 0.0
# ramp_up_rate_max_15_5: Shadow price = 0.0
# ramp_up_rate_max_15_6: Shadow price = 0.0
# ramp_up_rate_max_15_7: Shadow price = 0.0
# ramp_up_rate_max_15_8: Shadow price = 0.0
# ramp_up_rate_max_16_0: Shadow price = 0.0
# ramp_up_rate_max_16_1: Shadow price = 0.0
# ramp_up_rate_max_16_2: Shadow price = 0.0
# ramp_up_rate_max_16_3: Shadow price = 0.0
# ramp_up_rate_max_16_4: Shadow price = 0.0
# ramp_up_rate_max_16_5: Shadow price = 0.0
# ramp_up_rate_max_16_6: Shadow price = 0.0
# ramp_up_rate_max_16_7: Shadow price = 0.0
# ramp_up_rate_max_16_8: Shadow price = 0.0
# ramp_up_rate_max_17_0: Shadow price = 0.0
# ramp_up_rate_max_17_1: Shadow price = 0.0
# ramp_up_rate_max_17_2: Shadow price = 0.0
# ramp_up_rate_max_17_3: Shadow price = 0.0
# ramp_up_rate_max_17_4: Shadow price = 0.0
# ramp_up_rate_max_17_5: Shadow price = 0.0
# ramp_up_rate_max_17_6: Shadow price = 0.0
# ramp_up_rate_max_17_7: Shadow price = 0.0
# ramp_up_rate_max_17_8: Shadow price = 0.0
# ramp_up_rate_max_18_0: Shadow price = 0.0
# ramp_up_rate_max_18_1: Shadow price = 0.0
# ramp_up_rate_max_18_2: Shadow price = 0.0
# ramp_up_rate_max_18_3: Shadow price = 0.0
# ramp_up_rate_max_18_4: Shadow price = 0.0
# ramp_up_rate_max_18_5: Shadow price = 0.0
# ramp_up_rate_max_18_6: Shadow price = 0.0
# ramp_up_rate_max_18_7: Shadow price = 0.0
# ramp_up_rate_max_18_8: Shadow price = 0.0
# ramp_up_rate_max_19_0: Shadow price = 0.0
# ramp_up_rate_max_19_1: Shadow price = 0.0
# ramp_up_rate_max_19_2: Shadow price = 0.0
# ramp_up_rate_max_19_3: Shadow price = 0.0
# ramp_up_rate_max_19_4: Shadow price = 0.0
# ramp_up_rate_max_19_5: Shadow price = 0.0
# ramp_up_rate_max_19_6: Shadow price = 0.0
# ramp_up_rate_max_19_7: Shadow price = 0.0
# ramp_up_rate_max_19_8: Shadow price = 0.0
# ramp_up_rate_max_20_0: Shadow price = 0.0
# ramp_up_rate_max_20_1: Shadow price = 0.0
# ramp_up_rate_max_20_2: Shadow price = 0.0
# ramp_up_rate_max_20_3: Shadow price = 0.0
# ramp_up_rate_max_20_4: Shadow price = 0.0
# ramp_up_rate_max_20_5: Shadow price = 0.0
# ramp_up_rate_max_20_6: Shadow price = 0.0
# ramp_up_rate_max_20_7: Shadow price = 0.0
# ramp_up_rate_max_20_8: Shadow price = 0.0
# ramp_up_rate_max_21_0: Shadow price = 0.0
# ramp_up_rate_max_21_1: Shadow price = 0.0
# ramp_up_rate_max_21_2: Shadow price = 0.0
# ramp_up_rate_max_21_3: Shadow price = 0.0
# ramp_up_rate_max_21_4: Shadow price = 0.0
# ramp_up_rate_max_21_5: Shadow price = 0.0
# ramp_up_rate_max_21_6: Shadow price = 0.0
# ramp_up_rate_max_21_7: Shadow price = 0.0
# ramp_up_rate_max_21_8: Shadow price = 0.0
# ramp_up_rate_max_22_0: Shadow price = 0.0
# ramp_up_rate_max_22_1: Shadow price = 0.0
# ramp_up_rate_max_22_2: Shadow price = 0.0
# ramp_up_rate_max_22_3: Shadow price = 0.0
# ramp_up_rate_max_22_4: Shadow price = 0.0
# ramp_up_rate_max_22_5: Shadow price = 0.0
# ramp_up_rate_max_22_6: Shadow price = 0.0
# ramp_up_rate_max_22_7: Shadow price = 0.0
# ramp_up_rate_max_22_8: Shadow price = 0.0
# ramp_down_rate_max_0_0: Shadow price = 0.0
# ramp_down_rate_max_0_1: Shadow price = 0.0
# ramp_down_rate_max_0_2: Shadow price = 0.0
# ramp_down_rate_max_0_3: Shadow price = 0.0
# ramp_down_rate_max_0_4: Shadow price = 0.0
# ramp_down_rate_max_0_5: Shadow price = 0.0
# ramp_down_rate_max_0_6: Shadow price = 0.0
# ramp_down_rate_max_0_7: Shadow price = 0.0
# ramp_down_rate_max_0_8: Shadow price = 0.0
# ramp_down_rate_max_1_0: Shadow price = 0.0
# ramp_down_rate_max_1_1: Shadow price = 0.0
# ramp_down_rate_max_1_2: Shadow price = 0.0
# ramp_down_rate_max_1_3: Shadow price = 0.0
# ramp_down_rate_max_1_4: Shadow price = 0.0
# ramp_down_rate_max_1_5: Shadow price = 0.0
# ramp_down_rate_max_1_6: Shadow price = 0.0
# ramp_down_rate_max_1_7: Shadow price = 0.0
# ramp_down_rate_max_1_8: Shadow price = 0.0
# ramp_down_rate_max_2_0: Shadow price = 0.0
# ramp_down_rate_max_2_1: Shadow price = 0.0
# ramp_down_rate_max_2_2: Shadow price = 0.0
# ramp_down_rate_max_2_3: Shadow price = 0.0
# ramp_down_rate_max_2_4: Shadow price = 0.0
# ramp_down_rate_max_2_5: Shadow price = 0.0
# ramp_down_rate_max_2_6: Shadow price = 0.0
# ramp_down_rate_max_2_7: Shadow price = 0.0
# ramp_down_rate_max_2_8: Shadow price = 0.0
# ramp_down_rate_max_3_0: Shadow price = 0.0
# ramp_down_rate_max_3_1: Shadow price = 0.0
# ramp_down_rate_max_3_2: Shadow price = 0.0
# ramp_down_rate_max_3_3: Shadow price = 0.0
# ramp_down_rate_max_3_4: Shadow price = 0.0
# ramp_down_rate_max_3_5: Shadow price = 0.0
# ramp_down_rate_max_3_6: Shadow price = 0.0
# ramp_down_rate_max_3_7: Shadow price = 0.0
# ramp_down_rate_max_3_8: Shadow price = 0.0
# ramp_down_rate_max_4_0: Shadow price = 0.0
# ramp_down_rate_max_4_1: Shadow price = 0.0
# ramp_down_rate_max_4_2: Shadow price = 0.0
# ramp_down_rate_max_4_3: Shadow price = 0.0
# ramp_down_rate_max_4_4: Shadow price = 0.0
# ramp_down_rate_max_4_5: Shadow price = 0.0
# ramp_down_rate_max_4_6: Shadow price = 0.0
# ramp_down_rate_max_4_7: Shadow price = 0.0
# ramp_down_rate_max_4_8: Shadow price = 0.0
# ramp_down_rate_max_5_0: Shadow price = 0.0
# ramp_down_rate_max_5_1: Shadow price = 0.0
# ramp_down_rate_max_5_2: Shadow price = 0.0
# ramp_down_rate_max_5_3: Shadow price = 0.0
# ramp_down_rate_max_5_4: Shadow price = 0.0
# ramp_down_rate_max_5_5: Shadow price = 0.0
# ramp_down_rate_max_5_6: Shadow price = 0.0
# ramp_down_rate_max_5_7: Shadow price = 0.0
# ramp_down_rate_max_5_8: Shadow price = 0.0
# ramp_down_rate_max_6_0: Shadow price = 0.0
# ramp_down_rate_max_6_1: Shadow price = 0.0
# ramp_down_rate_max_6_2: Shadow price = 0.0
# ramp_down_rate_max_6_3: Shadow price = 0.0
# ramp_down_rate_max_6_4: Shadow price = 0.0
# ramp_down_rate_max_6_5: Shadow price = 0.0
# ramp_down_rate_max_6_6: Shadow price = 0.0
# ramp_down_rate_max_6_7: Shadow price = 0.0
# ramp_down_rate_max_6_8: Shadow price = 0.0
# ramp_down_rate_max_7_0: Shadow price = 0.0
# ramp_down_rate_max_7_1: Shadow price = 0.0
# ramp_down_rate_max_7_2: Shadow price = 0.0
# ramp_down_rate_max_7_3: Shadow price = 0.0
# ramp_down_rate_max_7_4: Shadow price = 0.0
# ramp_down_rate_max_7_5: Shadow price = 0.0
# ramp_down_rate_max_7_6: Shadow price = 0.0
# ramp_down_rate_max_7_7: Shadow price = 0.0
# ramp_down_rate_max_7_8: Shadow price = 0.0
# ramp_down_rate_max_8_0: Shadow price = 0.0
# ramp_down_rate_max_8_1: Shadow price = 0.0
# ramp_down_rate_max_8_2: Shadow price = 0.0
# ramp_down_rate_max_8_3: Shadow price = 0.0
# ramp_down_rate_max_8_4: Shadow price = 0.0
# ramp_down_rate_max_8_5: Shadow price = 0.0
# ramp_down_rate_max_8_6: Shadow price = 0.0
# ramp_down_rate_max_8_7: Shadow price = 0.0
# ramp_down_rate_max_8_8: Shadow price = 0.0
# ramp_down_rate_max_9_0: Shadow price = 0.0
# ramp_down_rate_max_9_1: Shadow price = 0.0
# ramp_down_rate_max_9_2: Shadow price = 0.0
# ramp_down_rate_max_9_3: Shadow price = 0.0
# ramp_down_rate_max_9_4: Shadow price = 0.0
# ramp_down_rate_max_9_5: Shadow price = 0.0
# ramp_down_rate_max_9_6: Shadow price = 0.0
# ramp_down_rate_max_9_7: Shadow price = 0.0
# ramp_down_rate_max_9_8: Shadow price = 0.0
# ramp_down_rate_max_10_0: Shadow price = 0.0
# ramp_down_rate_max_10_1: Shadow price = 0.0
# ramp_down_rate_max_10_2: Shadow price = 0.0
# ramp_down_rate_max_10_3: Shadow price = 0.0
# ramp_down_rate_max_10_4: Shadow price = 0.0
# ramp_down_rate_max_10_5: Shadow price = 0.0
# ramp_down_rate_max_10_6: Shadow price = 0.0
# ramp_down_rate_max_10_7: Shadow price = 0.0
# ramp_down_rate_max_10_8: Shadow price = 0.0
# ramp_down_rate_max_11_0: Shadow price = 0.0
# ramp_down_rate_max_11_1: Shadow price = 0.0
# ramp_down_rate_max_11_2: Shadow price = 0.0
# ramp_down_rate_max_11_3: Shadow price = 0.0
# ramp_down_rate_max_11_4: Shadow price = 0.0
# ramp_down_rate_max_11_5: Shadow price = 0.0
# ramp_down_rate_max_11_6: Shadow price = 0.0
# ramp_down_rate_max_11_7: Shadow price = 0.0
# ramp_down_rate_max_11_8: Shadow price = 0.0
# ramp_down_rate_max_12_0: Shadow price = 0.0
# ramp_down_rate_max_12_1: Shadow price = 0.0
# ramp_down_rate_max_12_2: Shadow price = 0.0
# ramp_down_rate_max_12_3: Shadow price = 0.0
# ramp_down_rate_max_12_4: Shadow price = 0.0
# ramp_down_rate_max_12_5: Shadow price = 0.0
# ramp_down_rate_max_12_6: Shadow price = 0.0
# ramp_down_rate_max_12_7: Shadow price = 0.0
# ramp_down_rate_max_12_8: Shadow price = 0.0
# ramp_down_rate_max_13_0: Shadow price = 0.0
# ramp_down_rate_max_13_1: Shadow price = 0.0
# ramp_down_rate_max_13_2: Shadow price = 0.0
# ramp_down_rate_max_13_3: Shadow price = 0.0
# ramp_down_rate_max_13_4: Shadow price = 0.0
# ramp_down_rate_max_13_5: Shadow price = 0.0
# ramp_down_rate_max_13_6: Shadow price = 0.0
# ramp_down_rate_max_13_7: Shadow price = 0.0
# ramp_down_rate_max_13_8: Shadow price = 0.0
# ramp_down_rate_max_14_0: Shadow price = 0.0
# ramp_down_rate_max_14_1: Shadow price = 0.0
# ramp_down_rate_max_14_2: Shadow price = 0.0
# ramp_down_rate_max_14_3: Shadow price = 0.0
# ramp_down_rate_max_14_4: Shadow price = 0.0
# ramp_down_rate_max_14_5: Shadow price = 0.0
# ramp_down_rate_max_14_6: Shadow price = 0.0
# ramp_down_rate_max_14_7: Shadow price = 0.0
# ramp_down_rate_max_14_8: Shadow price = 0.0
# ramp_down_rate_max_15_0: Shadow price = 0.0
# ramp_down_rate_max_15_1: Shadow price = 0.0
# ramp_down_rate_max_15_2: Shadow price = 0.0
# ramp_down_rate_max_15_3: Shadow price = 0.0
# ramp_down_rate_max_15_4: Shadow price = 0.0
# ramp_down_rate_max_15_5: Shadow price = 0.0
# ramp_down_rate_max_15_6: Shadow price = 0.0
# ramp_down_rate_max_15_7: Shadow price = 0.0
# ramp_down_rate_max_15_8: Shadow price = 0.0
# ramp_down_rate_max_16_0: Shadow price = 0.0
# ramp_down_rate_max_16_1: Shadow price = 0.0
# ramp_down_rate_max_16_2: Shadow price = 0.0
# ramp_down_rate_max_16_3: Shadow price = 0.0
# ramp_down_rate_max_16_4: Shadow price = 0.0
# ramp_down_rate_max_16_5: Shadow price = 0.0
# ramp_down_rate_max_16_6: Shadow price = 0.0
# ramp_down_rate_max_16_7: Shadow price = 0.0
# ramp_down_rate_max_16_8: Shadow price = 0.0
# ramp_down_rate_max_17_0: Shadow price = 0.0
# ramp_down_rate_max_17_1: Shadow price = 0.0
# ramp_down_rate_max_17_2: Shadow price = 0.0
# ramp_down_rate_max_17_3: Shadow price = 0.0
# ramp_down_rate_max_17_4: Shadow price = 0.0
# ramp_down_rate_max_17_5: Shadow price = 0.0
# ramp_down_rate_max_17_6: Shadow price = 0.0
# ramp_down_rate_max_17_7: Shadow price = 0.0
# ramp_down_rate_max_17_8: Shadow price = 0.0
# ramp_down_rate_max_18_0: Shadow price = 0.0
# ramp_down_rate_max_18_1: Shadow price = 0.0
# ramp_down_rate_max_18_2: Shadow price = 0.0
# ramp_down_rate_max_18_3: Shadow price = 0.0
# ramp_down_rate_max_18_4: Shadow price = 0.0
# ramp_down_rate_max_18_5: Shadow price = 0.0
# ramp_down_rate_max_18_6: Shadow price = 0.0
# ramp_down_rate_max_18_7: Shadow price = 0.0
# ramp_down_rate_max_18_8: Shadow price = 0.0
# ramp_down_rate_max_19_0: Shadow price = 0.0
# ramp_down_rate_max_19_1: Shadow price = 0.0
# ramp_down_rate_max_19_2: Shadow price = 0.0
# ramp_down_rate_max_19_3: Shadow price = 0.0
# ramp_down_rate_max_19_4: Shadow price = 0.0
# ramp_down_rate_max_19_5: Shadow price = 0.0
# ramp_down_rate_max_19_6: Shadow price = 0.0
# ramp_down_rate_max_19_7: Shadow price = 0.0
# ramp_down_rate_max_19_8: Shadow price = 0.0
# ramp_down_rate_max_20_0: Shadow price = 0.0
# ramp_down_rate_max_20_1: Shadow price = 0.0
# ramp_down_rate_max_20_2: Shadow price = 0.0
# ramp_down_rate_max_20_3: Shadow price = 0.0
# ramp_down_rate_max_20_4: Shadow price = 0.0
# ramp_down_rate_max_20_5: Shadow price = 0.0
# ramp_down_rate_max_20_6: Shadow price = 0.0
# ramp_down_rate_max_20_7: Shadow price = 0.0
# ramp_down_rate_max_20_8: Shadow price = 0.0
# ramp_down_rate_max_21_0: Shadow price = 0.0
# ramp_down_rate_max_21_1: Shadow price = 0.0
# ramp_down_rate_max_21_2: Shadow price = 0.0
# ramp_down_rate_max_21_3: Shadow price = 0.0
# ramp_down_rate_max_21_4: Shadow price = 0.0
# ramp_down_rate_max_21_5: Shadow price = 0.0
# ramp_down_rate_max_21_6: Shadow price = 0.0
# ramp_down_rate_max_21_7: Shadow price = 0.0
# ramp_down_rate_max_21_8: Shadow price = 0.0
# ramp_down_rate_max_22_0: Shadow price = 0.0
# ramp_down_rate_max_22_1: Shadow price = 0.0
# ramp_down_rate_max_22_2: Shadow price = 0.0
# ramp_down_rate_max_22_3: Shadow price = 0.0
# ramp_down_rate_max_22_4: Shadow price = 0.0
# ramp_down_rate_max_22_5: Shadow price = 0.0
# ramp_down_rate_max_22_6: Shadow price = 0.0
# ramp_down_rate_max_22_7: Shadow price = 0.0
# ramp_down_rate_max_22_8: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -68.04
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = 0.0
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# None: Shadow price = -998.04
# None: Shadow price = -998.04
# None: Shadow price = -98.04
# None: Shadow price = -98.04
# nuclear_ramping_0: Shadow price = 0.0
# nuclear_ramping_1: Shadow price = 0.0
# nuclear_ramping_2: Shadow price = 0.0
# nuclear_ramping_3: Shadow price = 0.0
# nuclear_ramping_4: Shadow price = 2.48
# nuclear_ramping_5: Shadow price = 2.48
# nuclear_ramping_6: Shadow price = 2.48
# nuclear_ramping_7: Shadow price = 2.48
# nuclear_ramping_8: Shadow price = 2.48
# nuclear_ramping_9: Shadow price = 2.48
# nuclear_ramping_10: Shadow price = 2.48
# nuclear_ramping_11: Shadow price = 2.48
# nuclear_ramping_12: Shadow price = 0.0
# nuclear_ramping_13: Shadow price = 0.0
# nuclear_ramping_14: Shadow price = 0.0
# nuclear_ramping_15: Shadow price = 0.0
# nuclear_ramping_16: Shadow price = 0.0
# nuclear_ramping_17: Shadow price = 0.0
# nuclear_ramping_18: Shadow price = 0.0
# nuclear_ramping_19: Shadow price = 0.0
# nuclear_ramping_20: Shadow price = 0.0
# nuclear_ramping_21: Shadow price = 0.0
# nuclear_ramping_22: Shadow price = 0.0
# nuclear_ramping_23: Shadow price = 0.0

# %%
tech_list = ["HYD","NUC","BIO","PET","SOL","WINON", "WINOFF", "FC","NAT", "PJM", "Backup", "Unmet", "BAT2", "BAT4", 'Demand', 'BAT2 SOC', 'BAT4 SOC']
color_list = ["darkblue","maroon","darkgreen","snow","orange","skyblue", "steelblue", "pink", "olive", "gray", "rosybrown", "red", "darkseagreen", 'purple']

# %%
dispatch_model
# Out:
# dispatch_model_Problem:
# MINIMIZE
# 2*shed_now_0 + 2*shed_now_1 + 2*shed_now_10 + 2*shed_now_11 + 2*shed_now_12 + 2*shed_now_13 + 2*shed_now_14 + 2*shed_now_15 + 2*shed_now_16 + 2*shed_now_17 + 2*shed_now_18 + 2*shed_now_19 + 2*shed_now_2 + 2*shed_now_20 + 2*shed_now_21 + 2*shed_now_22 + 2*shed_now_23 + 2*shed_now_3 + 2*shed_now_4 + 2*shed_now_5 + 2*shed_now_6 + 2*shed_now_7 + 2*shed_now_8 + 2*shed_now_9 + 1.46*x_{0,0} + 1.96*x_{0,1} + 2.48*x_{0,2} + 5.06*x_{0,3} + 4.92*x_{0,4} + 0.62*x_{0,8} + 1.46*x_{1,0} + 1.96*x_{1,1} + 2.48*x_{1,2} + 5.06*x_{1,3} + 4.92*x_{1,4} + 0.62*x_{1,8} + 1.46*x_{10,0} + 1.96*x_{10,1} + 2.48*x_{10,2} + 5.06*x_{10,3} + 4.92*x_{10,4} + 0.62*x_{10,8} + 1.46*x_{11,0} + 1.96*x_{11,1} + 2.48*x_{11,2} + 5.06*x_{11,3} + 4.92*x_{11,4} + 0.62*x_{11,8} + 1.46*x_{12,0} + 1.96*x_{12,1} + 2.48*x_{12,2} + 5.06*x_{12,3} + 4.92*x_{12,4} + 0.62*x_{12,8} + 1.46*x_{13,0} + 1.96*x_{13,1} + 2.48*x_{13,2} + 5.06*x_{13,3} + 4.92*x_{13,4} + 0.62*x_{13,8} + 1.46*x_{14,0} + 1.96*x_{14,1} + 2.48*x_{14,2} + 5.06*x_{14,3} + 4.92*x_{14,4} + 0.62*x_{14,8} + 1.46*x_{15,0} + 1.96*x_{15,1} + 2.48*x_{15,2} + 5.06*x_{15,3} + 4.92*x_{15,4} + 0.62*x_{15,8} + 1.46*x_{16,0} + 1.96*x_{16,1} + 2.48*x_{16,2} + 5.06*x_{16,3} + 4.92*x_{16,4} + 0.62*x_{16,8} + 1.46*x_{17,0} + 1.96*x_{17,1} + 2.48*x_{17,2} + 5.06*x_{17,3} + 4.92*x_{17,4} + 0.62*x_{17,8} + 1.46*x_{18,0} + 1.96*x_{18,1} + 2.48*x_{18,2} + 5.06*x_{18,3} + 4.92*x_{18,4} + 0.62*x_{18,8} + 1.46*x_{19,0} + 1.96*x_{19,1} + 2.48*x_{19,2} + 5.06*x_{19,3} + 4.92*x_{19,4} + 0.62*x_{19,8} + 1.46*x_{2,0} + 1.96*x_{2,1} + 2.48*x_{2,2} + 5.06*x_{2,3} + 4.92*x_{2,4} + 0.62*x_{2,8} + 1.46*x_{20,0} + 1.96*x_{20,1} + 2.48*x_{20,2} + 5.06*x_{20,3} + 4.92*x_{20,4} + 0.62*x_{20,8} + 1.46*x_{21,0} + 1.96*x_{21,1} + 2.48*x_{21,2} + 5.06*x_{21,3} + 4.92*x_{21,4} + 0.62*x_{21,8} + 1.46*x_{22,0} + 1.96*x_{22,1} + 2.48*x_{22,2} + 5.06*x_{22,3} + 4.92*x_{22,4} + 0.62*x_{22,8} + 1.46*x_{23,0} + 1.96*x_{23,1} + 2.48*x_{23,2} + 5.06*x_{23,3} + 4.92*x_{23,4} + 0.62*x_{23,8} + 1.46*x_{3,0} + 1.96*x_{3,1} + 2.48*x_{3,2} + 5.06*x_{3,3} + 4.92*x_{3,4} + 0.62*x_{3,8} + 1.46*x_{4,0} + 1.96*x_{4,1} + 2.48*x_{4,2} + 5.06*x_{4,3} + 4.92*x_{4,4} + 0.62*x_{4,8} + 1.46*x_{5,0} + 1.96*x_{5,1} + 2.48*x_{5,2} + 5.06*x_{5,3} + 4.92*x_{5,4} + 0.62*x_{5,8} + 1.46*x_{6,0} + 1.96*x_{6,1} + 2.48*x_{6,2} + 5.06*x_{6,3} + 4.92*x_{6,4} + 0.62*x_{6,8} + 1.46*x_{7,0} + 1.96*x_{7,1} + 2.48*x_{7,2} + 5.06*x_{7,3} + 4.92*x_{7,4} + 0.62*x_{7,8} + 1.46*x_{8,0} + 1.96*x_{8,1} + 2.48*x_{8,2} + 5.06*x_{8,3} + 4.92*x_{8,4} + 0.62*x_{8,8} + 1.46*x_{9,0} + 1.96*x_{9,1} + 2.48*x_{9,2} + 5.06*x_{9,3} + 4.92*x_{9,4} + 0.62*x_{9,8} + 60*y_{0,0} + 100*y_{0,1} + 1000*y_{0,2} + 60*y_{1,0} + 100*y_{1,1} + 1000*y_{1,2} + 60*y_{10,0} + 100*y_{10,1} + 1000*y_{10,2} + 60*y_{11,0} + 100*y_{11,1} + 1000*y_{11,2} + 60*y_{12,0} + 100*y_{12,1} + 1000*y_{12,2} + 60*y_{13,0} + 100*y_{13,1} + 1000*y_{13,2} + 60*y_{14,0} + 100*y_{14,1} + 1000*y_{14,2} + 60*y_{15,0} + 100*y_{15,1} + 1000*y_{15,2} + 60*y_{16,0} + 100*y_{16,1} + 1000*y_{16,2} + 60*y_{17,0} + 100*y_{17,1} + 1000*y_{17,2} + 60*y_{18,0} + 100*y_{18,1} + 1000*y_{18,2} + 60*y_{19,0} + 100*y_{19,1} + 1000*y_{19,2} + 60*y_{2,0} + 100*y_{2,1} + 1000*y_{2,2} + 60*y_{20,0} + 100*y_{20,1} + 1000*y_{20,2} + 60*y_{21,0} + 100*y_{21,1} + 1000*y_{21,2} + 60*y_{22,0} + 100*y_{22,1} + 1000*y_{22,2} + 60*y_{23,0} + 100*y_{23,1} + 1000*y_{23,2} + 60*y_{3,0} + 70*y_{3,1} + 1000*y_{3,2} + 60*y_{4,0} + 100*y_{4,1} + 1000*y_{4,2} + 60*y_{5,0} + 100*y_{5,1} + 1000*y_{5,2} + 60*y_{6,0} + 100*y_{6,1} + 1000*y_{6,2} + 60*y_{7,0} + 100*y_{7,1} + 1000*y_{7,2} + 60*y_{8,0} + 100*y_{8,1} + 1000*y_{8,2} + 60*y_{9,0} + 100*y_{9,1} + 1000*y_{9,2} + 0.0
# SUBJECT TO
# balance_0: - chg_{0,0} - chg_{0,1} + 0.85 dchg_{0,0} + 0.85 dchg_{0,1}
#  - shed_now_0 + x_{0,0} + x_{0,1} + x_{0,2} + x_{0,3} + x_{0,4} + x_{0,5}
#  + x_{0,6} + x_{0,7} + x_{0,8} + y_{0,0} + y_{0,1} + y_{0,2} = 10744.7033902
#
# balance_1: - chg_{1,0} - chg_{1,1} + 0.85 dchg_{1,0} + 0.85 dchg_{1,1}
#  - shed_now_1 + x_{1,0} + x_{1,1} + x_{1,2} + x_{1,3} + x_{1,4} + x_{1,5}
#  + x_{1,6} + x_{1,7} + x_{1,8} + y_{1,0} + y_{1,1} + y_{1,2} = 10044.5610965
#
# balance_2: - chg_{2,0} - chg_{2,1} + 0.85 dchg_{2,0} + 0.85 dchg_{2,1}
#  - shed_now_2 + x_{2,0} + x_{2,1} + x_{2,2} + x_{2,3} + x_{2,4} + x_{2,5}
#  + x_{2,6} + x_{2,7} + x_{2,8} + y_{2,0} + y_{2,1} + y_{2,2} = 9560.52571543
#
# balance_3: - chg_{3,0} - chg_{3,1} + 0.85 dchg_{3,0} + 0.85 dchg_{3,1}
#  - shed_now_3 + x_{3,0} + x_{3,1} + x_{3,2} + x_{3,3} + x_{3,4} + x_{3,5}
#  + x_{3,6} + x_{3,7} + x_{3,8} + y_{3,0} + y_{3,1} + y_{3,2} = 9299.21276484
#
# balance_4: - chg_{4,0} - chg_{4,1} + 0.85 dchg_{4,0} + 0.85 dchg_{4,1}
#  - shed_now_4 + x_{4,0} + x_{4,1} + x_{4,2} + x_{4,3} + x_{4,4} + x_{4,5}
#  + x_{4,6} + x_{4,7} + x_{4,8} + y_{4,0} + y_{4,1} + y_{4,2} = 9273.85328018
#
# balance_5: - chg_{5,0} - chg_{5,1} + 0.85 dchg_{5,0} + 0.85 dchg_{5,1}
#  - shed_now_5 + x_{5,0} + x_{5,1} + x_{5,2} + x_{5,3} + x_{5,4} + x_{5,5}
#  + x_{5,6} + x_{5,7} + x_{5,8} + y_{5,0} + y_{5,1} + y_{5,2} = 9476.72915743
#
# balance_6: - chg_{6,0} - chg_{6,1} + 0.85 dchg_{6,0} + 0.85 dchg_{6,1}
#  - shed_now_6 + x_{6,0} + x_{6,1} + x_{6,2} + x_{6,3} + x_{6,4} + x_{6,5}
#  + x_{6,6} + x_{6,7} + x_{6,8} + y_{6,0} + y_{6,1} + y_{6,2} = 9927.6869498
#
# balance_7: - chg_{7,0} - chg_{7,1} + 0.85 dchg_{7,0} + 0.85 dchg_{7,1}
#  - shed_now_7 + x_{7,0} + x_{7,1} + x_{7,2} + x_{7,3} + x_{7,4} + x_{7,5}
#  + x_{7,6} + x_{7,7} + x_{7,8} + y_{7,0} + y_{7,1} + y_{7,2} = 10771.1654612
#
# balance_8: - chg_{8,0} - chg_{8,1} + 0.85 dchg_{8,0} + 0.85 dchg_{8,1}
#  - shed_now_8 + x_{8,0} + x_{8,1} + x_{8,2} + x_{8,3} + x_{8,4} + x_{8,5}
#  + x_{8,6} + x_{8,7} + x_{8,8} + y_{8,0} + y_{8,1} + y_{8,2} = 11738.133637
#
# balance_9: - chg_{9,0} - chg_{9,1} + 0.85 dchg_{9,0} + 0.85 dchg_{9,1}
#  - shed_now_9 + x_{9,0} + x_{9,1} + x_{9,2} + x_{9,3} + x_{9,4} + x_{9,5}
#  + x_{9,6} + x_{9,7} + x_{9,8} + y_{9,0} + y_{9,1} + y_{9,2} = 12707.3069854
#
# balance_10: - chg_{10,0} - chg_{10,1} + 0.85 dchg_{10,0} + 0.85 dchg_{10,1}
#  - shed_now_10 + x_{10,0} + x_{10,1} + x_{10,2} + x_{10,3} + x_{10,4}
#  + x_{10,5} + x_{10,6} + x_{10,7} + x_{10,8} + y_{10,0} + y_{10,1} + y_{10,2}
#  = 13783.4312038
#
# balance_11: - chg_{11,0} - chg_{11,1} + 0.85 dchg_{11,0} + 0.85 dchg_{11,1}
#  - shed_now_11 + x_{11,0} + x_{11,1} + x_{11,2} + x_{11,3} + x_{11,4}
#  + x_{11,5} + x_{11,6} + x_{11,7} + x_{11,8} + y_{11,0} + y_{11,1} + y_{11,2}
#  = 15032.6614697
#
# balance_12: - chg_{12,0} - chg_{12,1} + 0.85 dchg_{12,0} + 0.85 dchg_{12,1}
#  - shed_now_12 + x_{12,0} + x_{12,1} + x_{12,2} + x_{12,3} + x_{12,4}
#  + x_{12,5} + x_{12,6} + x_{12,7} + x_{12,8} + y_{12,0} + y_{12,1} + y_{12,2}
#  = 16059.1693052
#
# balance_13: - chg_{13,0} - chg_{13,1} + 0.85 dchg_{13,0} + 0.85 dchg_{13,1}
#  - shed_now_13 + x_{13,0} + x_{13,1} + x_{13,2} + x_{13,3} + x_{13,4}
#  + x_{13,5} + x_{13,6} + x_{13,7} + x_{13,8} + y_{13,0} + y_{13,1} + y_{13,2}
#  = 17104.4211075
#
# balance_14: - chg_{14,0} - chg_{14,1} + 0.85 dchg_{14,0} + 0.85 dchg_{14,1}
#  - shed_now_14 + x_{14,0} + x_{14,1} + x_{14,2} + x_{14,3} + x_{14,4}
#  + x_{14,5} + x_{14,6} + x_{14,7} + x_{14,8} + y_{14,0} + y_{14,1} + y_{14,2}
#  = 17826.6151271
#
# balance_15: - chg_{15,0} - chg_{15,1} + 0.85 dchg_{15,0} + 0.85 dchg_{15,1}
#  - shed_now_15 + x_{15,0} + x_{15,1} + x_{15,2} + x_{15,3} + x_{15,4}
#  + x_{15,5} + x_{15,6} + x_{15,7} + x_{15,8} + y_{15,0} + y_{15,1} + y_{15,2}
#  = 18441.8582766
#
# balance_16: - chg_{16,0} - chg_{16,1} + 0.85 dchg_{16,0} + 0.85 dchg_{16,1}
#  - shed_now_16 + x_{16,0} + x_{16,1} + x_{16,2} + x_{16,3} + x_{16,4}
#  + x_{16,5} + x_{16,6} + x_{16,7} + x_{16,8} + y_{16,0} + y_{16,1} + y_{16,2}
#  = 18932.5091754
#
# balance_17: - chg_{17,0} - chg_{17,1} + 0.85 dchg_{17,0} + 0.85 dchg_{17,1}
#  - shed_now_17 + x_{17,0} + x_{17,1} + x_{17,2} + x_{17,3} + x_{17,4}
#  + x_{17,5} + x_{17,6} + x_{17,7} + x_{17,8} + y_{17,0} + y_{17,1} + y_{17,2}
#  = 19166.2574687
#
# balance_18: - chg_{18,0} - chg_{18,1} + 0.85 dchg_{18,0} + 0.85 dchg_{18,1}
#  - shed_now_18 + x_{18,0} + x_{18,1} + x_{18,2} + x_{18,3} + x_{18,4}
#  + x_{18,5} + x_{18,6} + x_{18,7} + x_{18,8} + y_{18,0} + y_{18,1} + y_{18,2}
#  = 17899.3858222
#
# balance_19: - chg_{19,0} - chg_{19,1} + 0.85 dchg_{19,0} + 0.85 dchg_{19,1}
#  - shed_now_19 + x_{19,0} + x_{19,1} + x_{19,2} + x_{19,3} + x_{19,4}
#  + x_{19,5} + x_{19,6} + x_{19,7} + x_{19,8} + y_{19,0} + y_{19,1} + y_{19,2}
#  = 16524.4607193
#
# balance_20: - chg_{20,0} - chg_{20,1} + 0.85 dchg_{20,0} + 0.85 dchg_{20,1}
#  - shed_now_20 + x_{20,0} + x_{20,1} + x_{20,2} + x_{20,3} + x_{20,4}
#  + x_{20,5} + x_{20,6} + x_{20,7} + x_{20,8} + y_{20,0} + y_{20,1} + y_{20,2}
#  = 15613.7244443
#
# balance_21: - chg_{21,0} - chg_{21,1} + 0.85 dchg_{21,0} + 0.85 dchg_{21,1}
#  - shed_now_21 + x_{21,0} + x_{21,1} + x_{21,2} + x_{21,3} + x_{21,4}
#  + x_{21,5} + x_{21,6} + x_{21,7} + x_{21,8} + y_{21,0} + y_{21,1} + y_{21,2}
#  = 14570.6778145
#
# balance_22: - chg_{22,0} - chg_{22,1} + 0.85 dchg_{22,0} + 0.85 dchg_{22,1}
#  - shed_now_22 + x_{22,0} + x_{22,1} + x_{22,2} + x_{22,3} + x_{22,4}
#  + x_{22,5} + x_{22,6} + x_{22,7} + x_{22,8} + y_{22,0} + y_{22,1} + y_{22,2}
#  = 13416.2699695
#
# balance_23: - chg_{23,0} - chg_{23,1} + 0.85 dchg_{23,0} + 0.85 dchg_{23,1}
#  - shed_now_23 + x_{23,0} + x_{23,1} + x_{23,2} + x_{23,3} + x_{23,4}
#  + x_{23,5} + x_{23,6} + x_{23,7} + x_{23,8} + y_{23,0} + y_{23,1} + y_{23,2}
#  = 12265.1698833
#
# generation_capacity_0_0: x_{0,0} <= 5.292
#
# generation_capacity_1_0: x_{1,0} <= 5.292
#
# generation_capacity_2_0: x_{2,0} <= 5.292
#
# generation_capacity_3_0: x_{3,0} <= 5.292
#
# generation_capacity_4_0: x_{4,0} <= 5.292
#
# generation_capacity_5_0: x_{5,0} <= 5.292
#
# generation_capacity_6_0: x_{6,0} <= 5.292
#
# generation_capacity_7_0: x_{7,0} <= 5.292
#
# generation_capacity_8_0: x_{8,0} <= 5.292
#
# generation_capacity_9_0: x_{9,0} <= 5.292
#
# generation_capacity_10_0: x_{10,0} <= 5.292
#
# generation_capacity_11_0: x_{11,0} <= 5.292
#
# generation_capacity_12_0: x_{12,0} <= 5.292
#
# generation_capacity_13_0: x_{13,0} <= 5.292
#
# generation_capacity_14_0: x_{14,0} <= 5.292
#
# generation_capacity_15_0: x_{15,0} <= 5.292
#
# generation_capacity_16_0: x_{16,0} <= 5.292
#
# generation_capacity_17_0: x_{17,0} <= 5.292
#
# generation_capacity_18_0: x_{18,0} <= 5.292
#
# generation_capacity_19_0: x_{19,0} <= 5.292
#
# generation_capacity_20_0: x_{20,0} <= 5.292
#
# generation_capacity_21_0: x_{21,0} <= 5.292
#
# generation_capacity_22_0: x_{22,0} <= 5.292
#
# generation_capacity_23_0: x_{23,0} <= 5.292
#
# generation_capacity_0_1: x_{0,1} <= 6929.272
#
# generation_capacity_1_1: x_{1,1} <= 6929.272
#
# generation_capacity_2_1: x_{2,1} <= 6929.272
#
# generation_capacity_3_1: x_{3,1} <= 6929.272
#
# generation_capacity_4_1: x_{4,1} <= 6929.272
#
# generation_capacity_5_1: x_{5,1} <= 6929.272
#
# generation_capacity_6_1: x_{6,1} <= 6929.272
#
# generation_capacity_7_1: x_{7,1} <= 6929.272
#
# generation_capacity_8_1: x_{8,1} <= 6929.272
#
# generation_capacity_9_1: x_{9,1} <= 6929.272
#
# generation_capacity_10_1: x_{10,1} <= 6929.272
#
# generation_capacity_11_1: x_{11,1} <= 6929.272
#
# generation_capacity_12_1: x_{12,1} <= 6929.272
#
# generation_capacity_13_1: x_{13,1} <= 6929.272
#
# generation_capacity_14_1: x_{14,1} <= 6929.272
#
# generation_capacity_15_1: x_{15,1} <= 6929.272
#
# generation_capacity_16_1: x_{16,1} <= 6929.272
#
# generation_capacity_17_1: x_{17,1} <= 6929.272
#
# generation_capacity_18_1: x_{18,1} <= 6929.272
#
# generation_capacity_19_1: x_{19,1} <= 6929.272
#
# generation_capacity_20_1: x_{20,1} <= 6929.272
#
# generation_capacity_21_1: x_{21,1} <= 6929.272
#
# generation_capacity_22_1: x_{22,1} <= 6929.272
#
# generation_capacity_23_1: x_{23,1} <= 6929.272
#
# generation_capacity_0_2: x_{0,2} <= 3340.244
#
# generation_capacity_1_2: x_{1,2} <= 3340.244
#
# generation_capacity_2_2: x_{2,2} <= 3340.244
#
# generation_capacity_3_2: x_{3,2} <= 3340.244
#
# generation_capacity_4_2: x_{4,2} <= 3340.244
#
# generation_capacity_5_2: x_{5,2} <= 3340.244
#
# generation_capacity_6_2: x_{6,2} <= 3340.244
#
# generation_capacity_7_2: x_{7,2} <= 3340.244
#
# generation_capacity_8_2: x_{8,2} <= 3340.244
#
# generation_capacity_9_2: x_{9,2} <= 3340.244
#
# generation_capacity_10_2: x_{10,2} <= 3340.244
#
# generation_capacity_11_2: x_{11,2} <= 3340.244
#
# generation_capacity_12_2: x_{12,2} <= 3340.244
#
# generation_capacity_13_2: x_{13,2} <= 3340.244
#
# generation_capacity_14_2: x_{14,2} <= 3340.244
#
# generation_capacity_15_2: x_{15,2} <= 3340.244
#
# generation_capacity_16_2: x_{16,2} <= 3340.244
#
# generation_capacity_17_2: x_{17,2} <= 3340.244
#
# generation_capacity_18_2: x_{18,2} <= 3340.244
#
# generation_capacity_19_2: x_{19,2} <= 3340.244
#
# generation_capacity_20_2: x_{20,2} <= 3340.244
#
# generation_capacity_21_2: x_{21,2} <= 3340.244
#
# generation_capacity_22_2: x_{22,2} <= 3340.244
#
# generation_capacity_23_2: x_{23,2} <= 3340.244
#
# generation_capacity_0_3: x_{0,3} <= 132.6
#
# generation_capacity_1_3: x_{1,3} <= 132.6
#
# generation_capacity_2_3: x_{2,3} <= 132.6
#
# generation_capacity_3_3: x_{3,3} <= 132.6
#
# generation_capacity_4_3: x_{4,3} <= 132.6
#
# generation_capacity_5_3: x_{5,3} <= 132.6
#
# generation_capacity_6_3: x_{6,3} <= 132.6
#
# generation_capacity_7_3: x_{7,3} <= 132.6
#
# generation_capacity_8_3: x_{8,3} <= 132.6
#
# generation_capacity_9_3: x_{9,3} <= 132.6
#
# generation_capacity_10_3: x_{10,3} <= 132.6
#
# generation_capacity_11_3: x_{11,3} <= 132.6
#
# generation_capacity_12_3: x_{12,3} <= 132.6
#
# generation_capacity_13_3: x_{13,3} <= 132.6
#
# generation_capacity_14_3: x_{14,3} <= 132.6
#
# generation_capacity_15_3: x_{15,3} <= 132.6
#
# generation_capacity_16_3: x_{16,3} <= 132.6
#
# generation_capacity_17_3: x_{17,3} <= 132.6
#
# generation_capacity_18_3: x_{18,3} <= 132.6
#
# generation_capacity_19_3: x_{19,3} <= 132.6
#
# generation_capacity_20_3: x_{20,3} <= 132.6
#
# generation_capacity_21_3: x_{21,3} <= 132.6
#
# generation_capacity_22_3: x_{22,3} <= 132.6
#
# generation_capacity_23_3: x_{23,3} <= 132.6
#
# generation_capacity_0_4: x_{0,4} <= 39.923
#
# generation_capacity_1_4: x_{1,4} <= 39.923
#
# generation_capacity_2_4: x_{2,4} <= 39.923
#
# generation_capacity_3_4: x_{3,4} <= 39.923
#
# generation_capacity_4_4: x_{4,4} <= 39.923
#
# generation_capacity_5_4: x_{5,4} <= 39.923
#
# generation_capacity_6_4: x_{6,4} <= 39.923
#
# generation_capacity_7_4: x_{7,4} <= 39.923
#
# generation_capacity_8_4: x_{8,4} <= 39.923
#
# generation_capacity_9_4: x_{9,4} <= 39.923
#
# generation_capacity_10_4: x_{10,4} <= 39.923
#
# generation_capacity_11_4: x_{11,4} <= 39.923
#
# generation_capacity_12_4: x_{12,4} <= 39.923
#
# generation_capacity_13_4: x_{13,4} <= 39.923
#
# generation_capacity_14_4: x_{14,4} <= 39.923
#
# generation_capacity_15_4: x_{15,4} <= 39.923
#
# generation_capacity_16_4: x_{16,4} <= 39.923
#
# generation_capacity_17_4: x_{17,4} <= 39.923
#
# generation_capacity_18_4: x_{18,4} <= 39.923
#
# generation_capacity_19_4: x_{19,4} <= 39.923
#
# generation_capacity_20_4: x_{20,4} <= 39.923
#
# generation_capacity_21_4: x_{21,4} <= 39.923
#
# generation_capacity_22_4: x_{22,4} <= 39.923
#
# generation_capacity_23_4: x_{23,4} <= 39.923
#
# generation_capacity_0_5: x_{0,5} <= 0
#
# generation_capacity_1_5: x_{1,5} <= 0
#
# generation_capacity_2_5: x_{2,5} <= 0
#
# generation_capacity_3_5: x_{3,5} <= 0
#
# generation_capacity_4_5: x_{4,5} <= 10199.999976
#
# generation_capacity_5_5: x_{5,5} <= 10199.999976
#
# generation_capacity_6_5: x_{6,5} <= 10199.999976
#
# generation_capacity_7_5: x_{7,5} <= 10199.999976
#
# generation_capacity_8_5: x_{8,5} <= 10199.999976
#
# generation_capacity_9_5: x_{9,5} <= 10199.999976
#
# generation_capacity_10_5: x_{10,5} <= 10199.999976
#
# generation_capacity_11_5: x_{11,5} <= 10199.999976
#
# generation_capacity_12_5: x_{12,5} <= 10199.999976
#
# generation_capacity_13_5: x_{13,5} <= 10199.999976
#
# generation_capacity_14_5: x_{14,5} <= 10199.999976
#
# generation_capacity_15_5: x_{15,5} <= 10199.999976
#
# generation_capacity_16_5: x_{16,5} <= 10199.999976
#
# generation_capacity_17_5: x_{17,5} <= 10199.999976
#
# generation_capacity_18_5: x_{18,5} <= 10199.999976
#
# generation_capacity_19_5: x_{19,5} <= 10199.999976
#
# generation_capacity_20_5: x_{20,5} <= 0
#
# generation_capacity_21_5: x_{21,5} <= 0
#
# generation_capacity_22_5: x_{22,5} <= 0
#
# generation_capacity_23_5: x_{23,5} <= 0
#
# generation_capacity_0_6: x_{0,6} <= 9
#
# generation_capacity_1_6: x_{1,6} <= 9
#
# generation_capacity_2_6: x_{2,6} <= 9
#
# generation_capacity_3_6: x_{3,6} <= 9
#
# generation_capacity_4_6: x_{4,6} <= 9
#
# generation_capacity_5_6: x_{5,6} <= 9
#
# generation_capacity_6_6: x_{6,6} <= 9
#
# generation_capacity_7_6: x_{7,6} <= 9
#
# generation_capacity_8_6: x_{8,6} <= 9
#
# generation_capacity_9_6: x_{9,6} <= 9
#
# generation_capacity_10_6: x_{10,6} <= 9
#
# generation_capacity_11_6: x_{11,6} <= 9
#
# generation_capacity_12_6: x_{12,6} <= 9
#
# generation_capacity_13_6: x_{13,6} <= 9
#
# generation_capacity_14_6: x_{14,6} <= 9
#
# generation_capacity_15_6: x_{15,6} <= 9
#
# generation_capacity_16_6: x_{16,6} <= 9
#
# generation_capacity_17_6: x_{17,6} <= 9
#
# generation_capacity_18_6: x_{18,6} <= 9
#
# generation_capacity_19_6: x_{19,6} <= 9
#
# generation_capacity_20_6: x_{20,6} <= 9
#
# generation_capacity_21_6: x_{21,6} <= 9
#
# generation_capacity_22_6: x_{22,6} <= 9
#
# generation_capacity_23_6: x_{23,6} <= 9
#
# generation_capacity_0_7: x_{0,7} <= 1559.05032
#
# generation_capacity_1_7: x_{1,7} <= 1559.05032
#
# generation_capacity_2_7: x_{2,7} <= 1559.05032
#
# generation_capacity_3_7: x_{3,7} <= 1559.05032
#
# generation_capacity_4_7: x_{4,7} <= 1559.05032
#
# generation_capacity_5_7: x_{5,7} <= 1559.05032
#
# generation_capacity_6_7: x_{6,7} <= 1559.05032
#
# generation_capacity_7_7: x_{7,7} <= 1559.05032
#
# generation_capacity_8_7: x_{8,7} <= 1559.05032
#
# generation_capacity_9_7: x_{9,7} <= 1559.05032
#
# generation_capacity_10_7: x_{10,7} <= 1559.05032
#
# generation_capacity_11_7: x_{11,7} <= 1559.05032
#
# generation_capacity_12_7: x_{12,7} <= 1559.05032
#
# generation_capacity_13_7: x_{13,7} <= 1559.05032
#
# generation_capacity_14_7: x_{14,7} <= 1559.05032
#
# generation_capacity_15_7: x_{15,7} <= 1559.05032
#
# generation_capacity_16_7: x_{16,7} <= 1559.05032
#
# generation_capacity_17_7: x_{17,7} <= 1559.05032
#
# generation_capacity_18_7: x_{18,7} <= 1559.05032
#
# generation_capacity_19_7: x_{19,7} <= 1559.05032
#
# generation_capacity_20_7: x_{20,7} <= 1559.05032
#
# generation_capacity_21_7: x_{21,7} <= 1559.05032
#
# generation_capacity_22_7: x_{22,7} <= 1559.05032
#
# generation_capacity_23_7: x_{23,7} <= 1559.05032
#
# generation_capacity_0_8: x_{0,8} <= 0
#
# generation_capacity_1_8: x_{1,8} <= 0
#
# generation_capacity_2_8: x_{2,8} <= 0
#
# generation_capacity_3_8: x_{3,8} <= 0
#
# generation_capacity_4_8: x_{4,8} <= 0
#
# generation_capacity_5_8: x_{5,8} <= 0
#
# generation_capacity_6_8: x_{6,8} <= 0
#
# generation_capacity_7_8: x_{7,8} <= 0
#
# generation_capacity_8_8: x_{8,8} <= 0
#
# generation_capacity_9_8: x_{9,8} <= 0
#
# generation_capacity_10_8: x_{10,8} <= 0
#
# generation_capacity_11_8: x_{11,8} <= 0
#
# generation_capacity_12_8: x_{12,8} <= 0
#
# generation_capacity_13_8: x_{13,8} <= 0
#
# generation_capacity_14_8: x_{14,8} <= 0
#
# generation_capacity_15_8: x_{15,8} <= 0
#
# generation_capacity_16_8: x_{16,8} <= 0
#
# generation_capacity_17_8: x_{17,8} <= 0
#
# generation_capacity_18_8: x_{18,8} <= 0
#
# generation_capacity_19_8: x_{19,8} <= 0
#
# generation_capacity_20_8: x_{20,8} <= 0
#
# generation_capacity_21_8: x_{21,8} <= 0
#
# generation_capacity_22_8: x_{22,8} <= 0
#
# generation_capacity_23_8: x_{23,8} <= 0
#
# _C1: SOC_{0,0} - chg_{0,0} + dchg_{0,0} = 0
#
# _C2: SOC_{1,0} - chg_{0,0} - chg_{1,0} + dchg_{0,0} + dchg_{1,0} = 0
#
# _C3: SOC_{2,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} + dchg_{0,0} + dchg_{1,0}
#  + dchg_{2,0} = 0
#
# _C4: SOC_{3,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} + dchg_{0,0}
#  + dchg_{1,0} + dchg_{2,0} + dchg_{3,0} = 0
#
# _C5: SOC_{4,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  + dchg_{0,0} + dchg_{1,0} + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} = 0
#
# _C6: SOC_{5,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} + dchg_{0,0} + dchg_{1,0} + dchg_{2,0} + dchg_{3,0} + dchg_{4,0}
#  + dchg_{5,0} = 0
#
# _C7: SOC_{6,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} - chg_{6,0} + dchg_{0,0} + dchg_{1,0} + dchg_{2,0} + dchg_{3,0}
#  + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} = 0
#
# _C8: SOC_{7,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} - chg_{6,0} - chg_{7,0} + dchg_{0,0} + dchg_{1,0} + dchg_{2,0}
#  + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} = 0
#
# _C9: SOC_{8,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} + dchg_{0,0} + dchg_{1,0}
#  + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0}
#  + dchg_{8,0} = 0
#
# _C10: SOC_{9,0} - chg_{0,0} - chg_{1,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0}
#  + dchg_{1,0} + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0}
#  + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C11: SOC_{10,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{2,0} - chg_{3,0}
#  - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0}
#  + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{2,0} + dchg_{3,0}
#  + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0}
#  = 0
#
# _C12: SOC_{11,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0} - chg_{2,0}
#  - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0}
#  - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0}
#  + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0}
#  + dchg_{8,0} + dchg_{9,0} = 0
#
# _C13: SOC_{12,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{2,0} - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0}
#  - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0}
#  + dchg_{11,0} + dchg_{12,0} + dchg_{2,0} + dchg_{3,0} + dchg_{4,0}
#  + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C14: SOC_{13,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{2,0} - chg_{3,0} - chg_{4,0} - chg_{5,0}
#  - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0} + dchg_{1,0}
#  + dchg_{10,0} + dchg_{11,0} + dchg_{12,0} + dchg_{13,0} + dchg_{2,0}
#  + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0}
#  + dchg_{9,0} = 0
#
# _C15: SOC_{14,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{2,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0}
#  + dchg_{1,0} + dchg_{10,0} + dchg_{11,0} + dchg_{12,0} + dchg_{13,0}
#  + dchg_{14,0} + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0}
#  + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C16: SOC_{15,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{2,0} - chg_{3,0}
#  - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0}
#  + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0} + dchg_{12,0}
#  + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{2,0} + dchg_{3,0}
#  + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0}
#  = 0
#
# _C17: SOC_{16,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{2,0}
#  - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0}
#  - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0}
#  + dchg_{12,0} + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{16,0}
#  + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0}
#  + dchg_{8,0} + dchg_{9,0} = 0
#
# _C18: SOC_{17,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{2,0} - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0}
#  - chg_{8,0} - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0}
#  + dchg_{12,0} + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{16,0}
#  + dchg_{17,0} + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0}
#  + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C19: SOC_{18,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{18,0} - chg_{2,0} - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0}
#  - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0}
#  + dchg_{11,0} + dchg_{12,0} + dchg_{13,0} + dchg_{14,0} + dchg_{15,0}
#  + dchg_{16,0} + dchg_{17,0} + dchg_{18,0} + dchg_{2,0} + dchg_{3,0}
#  + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0}
#  = 0
#
# _C20: SOC_{19,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{18,0} - chg_{19,0} - chg_{2,0} - chg_{3,0} - chg_{4,0} - chg_{5,0}
#  - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0} + dchg_{1,0}
#  + dchg_{10,0} + dchg_{11,0} + dchg_{12,0} + dchg_{13,0} + dchg_{14,0}
#  + dchg_{15,0} + dchg_{16,0} + dchg_{17,0} + dchg_{18,0} + dchg_{19,0}
#  + dchg_{2,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0}
#  + dchg_{8,0} + dchg_{9,0} = 0
#
# _C21: SOC_{20,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{18,0} - chg_{19,0} - chg_{2,0} - chg_{20,0} - chg_{3,0} - chg_{4,0}
#  - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0} + dchg_{0,0}
#  + dchg_{1,0} + dchg_{10,0} + dchg_{11,0} + dchg_{12,0} + dchg_{13,0}
#  + dchg_{14,0} + dchg_{15,0} + dchg_{16,0} + dchg_{17,0} + dchg_{18,0}
#  + dchg_{19,0} + dchg_{2,0} + dchg_{20,0} + dchg_{3,0} + dchg_{4,0}
#  + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C22: SOC_{21,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{18,0} - chg_{19,0} - chg_{2,0} - chg_{20,0} - chg_{21,0} - chg_{3,0}
#  - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0} - chg_{9,0}
#  + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0} + dchg_{12,0}
#  + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{16,0} + dchg_{17,0}
#  + dchg_{18,0} + dchg_{19,0} + dchg_{2,0} + dchg_{20,0} + dchg_{21,0}
#  + dchg_{3,0} + dchg_{4,0} + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0}
#  + dchg_{9,0} = 0
#
# _C23: SOC_{22,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{18,0} - chg_{19,0} - chg_{2,0} - chg_{20,0} - chg_{21,0} - chg_{22,0}
#  - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0} - chg_{8,0}
#  - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0}
#  + dchg_{12,0} + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{16,0}
#  + dchg_{17,0} + dchg_{18,0} + dchg_{19,0} + dchg_{2,0} + dchg_{20,0}
#  + dchg_{21,0} + dchg_{22,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0}
#  + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C24: SOC_{23,0} - chg_{0,0} - chg_{1,0} - chg_{10,0} - chg_{11,0}
#  - chg_{12,0} - chg_{13,0} - chg_{14,0} - chg_{15,0} - chg_{16,0} - chg_{17,0}
#  - chg_{18,0} - chg_{19,0} - chg_{2,0} - chg_{20,0} - chg_{21,0} - chg_{22,0}
#  - chg_{23,0} - chg_{3,0} - chg_{4,0} - chg_{5,0} - chg_{6,0} - chg_{7,0}
#  - chg_{8,0} - chg_{9,0} + dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0}
#  + dchg_{12,0} + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{16,0}
#  + dchg_{17,0} + dchg_{18,0} + dchg_{19,0} + dchg_{2,0} + dchg_{20,0}
#  + dchg_{21,0} + dchg_{22,0} + dchg_{23,0} + dchg_{3,0} + dchg_{4,0}
#  + dchg_{5,0} + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} = 0
#
# _C25: SOC_{0,1} - chg_{0,1} + dchg_{0,1} = 0
#
# _C26: SOC_{1,1} - chg_{0,1} - chg_{1,1} + dchg_{0,1} + dchg_{1,1} = 0
#
# _C27: SOC_{2,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} + dchg_{0,1} + dchg_{1,1}
#  + dchg_{2,1} = 0
#
# _C28: SOC_{3,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} + dchg_{0,1}
#  + dchg_{1,1} + dchg_{2,1} + dchg_{3,1} = 0
#
# _C29: SOC_{4,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  + dchg_{0,1} + dchg_{1,1} + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} = 0
#
# _C30: SOC_{5,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} + dchg_{0,1} + dchg_{1,1} + dchg_{2,1} + dchg_{3,1} + dchg_{4,1}
#  + dchg_{5,1} = 0
#
# _C31: SOC_{6,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} - chg_{6,1} + dchg_{0,1} + dchg_{1,1} + dchg_{2,1} + dchg_{3,1}
#  + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} = 0
#
# _C32: SOC_{7,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} - chg_{6,1} - chg_{7,1} + dchg_{0,1} + dchg_{1,1} + dchg_{2,1}
#  + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} = 0
#
# _C33: SOC_{8,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} + dchg_{0,1} + dchg_{1,1}
#  + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1}
#  + dchg_{8,1} = 0
#
# _C34: SOC_{9,1} - chg_{0,1} - chg_{1,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1}
#  + dchg_{1,1} + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1}
#  + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C35: SOC_{10,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{2,1} - chg_{3,1}
#  - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1}
#  + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{2,1} + dchg_{3,1}
#  + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1}
#  = 0
#
# _C36: SOC_{11,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1} - chg_{2,1}
#  - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1}
#  - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1}
#  + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1}
#  + dchg_{8,1} + dchg_{9,1} = 0
#
# _C37: SOC_{12,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{2,1} - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1}
#  - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1}
#  + dchg_{11,1} + dchg_{12,1} + dchg_{2,1} + dchg_{3,1} + dchg_{4,1}
#  + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C38: SOC_{13,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{2,1} - chg_{3,1} - chg_{4,1} - chg_{5,1}
#  - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1} + dchg_{1,1}
#  + dchg_{10,1} + dchg_{11,1} + dchg_{12,1} + dchg_{13,1} + dchg_{2,1}
#  + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1}
#  + dchg_{9,1} = 0
#
# _C39: SOC_{14,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{2,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1}
#  + dchg_{1,1} + dchg_{10,1} + dchg_{11,1} + dchg_{12,1} + dchg_{13,1}
#  + dchg_{14,1} + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1}
#  + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C40: SOC_{15,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{2,1} - chg_{3,1}
#  - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1}
#  + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1} + dchg_{12,1}
#  + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{2,1} + dchg_{3,1}
#  + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1}
#  = 0
#
# _C41: SOC_{16,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{2,1}
#  - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1}
#  - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1}
#  + dchg_{12,1} + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{16,1}
#  + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1}
#  + dchg_{8,1} + dchg_{9,1} = 0
#
# _C42: SOC_{17,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{2,1} - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1}
#  - chg_{8,1} - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1}
#  + dchg_{12,1} + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{16,1}
#  + dchg_{17,1} + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1}
#  + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C43: SOC_{18,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{18,1} - chg_{2,1} - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1}
#  - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1}
#  + dchg_{11,1} + dchg_{12,1} + dchg_{13,1} + dchg_{14,1} + dchg_{15,1}
#  + dchg_{16,1} + dchg_{17,1} + dchg_{18,1} + dchg_{2,1} + dchg_{3,1}
#  + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1}
#  = 0
#
# _C44: SOC_{19,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{18,1} - chg_{19,1} - chg_{2,1} - chg_{3,1} - chg_{4,1} - chg_{5,1}
#  - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1} + dchg_{1,1}
#  + dchg_{10,1} + dchg_{11,1} + dchg_{12,1} + dchg_{13,1} + dchg_{14,1}
#  + dchg_{15,1} + dchg_{16,1} + dchg_{17,1} + dchg_{18,1} + dchg_{19,1}
#  + dchg_{2,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1}
#  + dchg_{8,1} + dchg_{9,1} = 0
#
# _C45: SOC_{20,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{18,1} - chg_{19,1} - chg_{2,1} - chg_{20,1} - chg_{3,1} - chg_{4,1}
#  - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1} + dchg_{0,1}
#  + dchg_{1,1} + dchg_{10,1} + dchg_{11,1} + dchg_{12,1} + dchg_{13,1}
#  + dchg_{14,1} + dchg_{15,1} + dchg_{16,1} + dchg_{17,1} + dchg_{18,1}
#  + dchg_{19,1} + dchg_{2,1} + dchg_{20,1} + dchg_{3,1} + dchg_{4,1}
#  + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C46: SOC_{21,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{18,1} - chg_{19,1} - chg_{2,1} - chg_{20,1} - chg_{21,1} - chg_{3,1}
#  - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1} - chg_{9,1}
#  + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1} + dchg_{12,1}
#  + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{16,1} + dchg_{17,1}
#  + dchg_{18,1} + dchg_{19,1} + dchg_{2,1} + dchg_{20,1} + dchg_{21,1}
#  + dchg_{3,1} + dchg_{4,1} + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1}
#  + dchg_{9,1} = 0
#
# _C47: SOC_{22,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{18,1} - chg_{19,1} - chg_{2,1} - chg_{20,1} - chg_{21,1} - chg_{22,1}
#  - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1} - chg_{8,1}
#  - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1}
#  + dchg_{12,1} + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{16,1}
#  + dchg_{17,1} + dchg_{18,1} + dchg_{19,1} + dchg_{2,1} + dchg_{20,1}
#  + dchg_{21,1} + dchg_{22,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1}
#  + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C48: SOC_{23,1} - chg_{0,1} - chg_{1,1} - chg_{10,1} - chg_{11,1}
#  - chg_{12,1} - chg_{13,1} - chg_{14,1} - chg_{15,1} - chg_{16,1} - chg_{17,1}
#  - chg_{18,1} - chg_{19,1} - chg_{2,1} - chg_{20,1} - chg_{21,1} - chg_{22,1}
#  - chg_{23,1} - chg_{3,1} - chg_{4,1} - chg_{5,1} - chg_{6,1} - chg_{7,1}
#  - chg_{8,1} - chg_{9,1} + dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1}
#  + dchg_{12,1} + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{16,1}
#  + dchg_{17,1} + dchg_{18,1} + dchg_{19,1} + dchg_{2,1} + dchg_{20,1}
#  + dchg_{21,1} + dchg_{22,1} + dchg_{23,1} + dchg_{3,1} + dchg_{4,1}
#  + dchg_{5,1} + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} = 0
#
# _C49: SOC_{0,0} = 0
#
# _C50: chg_{0,0} = 0
#
# _C51: dchg_{0,0} = 0
#
# _C52: SOC_{0,1} = 0
#
# _C53: chg_{0,1} = 0
#
# _C54: dchg_{0,1} = 0
#
# _C55: - SOC_{1,0} + dchg_{2,0} <= 0
#
# _C56: - SOC_{1,1} + dchg_{2,1} <= 0
#
# _C57: - SOC_{2,0} + dchg_{3,0} <= 0
#
# _C58: - SOC_{2,1} + dchg_{3,1} <= 0
#
# _C59: - SOC_{3,0} + dchg_{4,0} <= 0
#
# _C60: - SOC_{3,1} + dchg_{4,1} <= 0
#
# _C61: - SOC_{4,0} + dchg_{5,0} <= 0
#
# _C62: - SOC_{4,1} + dchg_{5,1} <= 0
#
# _C63: - SOC_{5,0} + dchg_{6,0} <= 0
#
# _C64: - SOC_{5,1} + dchg_{6,1} <= 0
#
# _C65: - SOC_{6,0} + dchg_{7,0} <= 0
#
# _C66: - SOC_{6,1} + dchg_{7,1} <= 0
#
# _C67: - SOC_{7,0} + dchg_{8,0} <= 0
#
# _C68: - SOC_{7,1} + dchg_{8,1} <= 0
#
# _C69: - SOC_{8,0} + dchg_{9,0} <= 0
#
# _C70: - SOC_{8,1} + dchg_{9,1} <= 0
#
# _C71: - SOC_{9,0} + dchg_{10,0} <= 0
#
# _C72: - SOC_{9,1} + dchg_{10,1} <= 0
#
# _C73: - SOC_{10,0} + dchg_{11,0} <= 0
#
# _C74: - SOC_{10,1} + dchg_{11,1} <= 0
#
# _C75: - SOC_{11,0} + dchg_{12,0} <= 0
#
# _C76: - SOC_{11,1} + dchg_{12,1} <= 0
#
# _C77: - SOC_{12,0} + dchg_{13,0} <= 0
#
# _C78: - SOC_{12,1} + dchg_{13,1} <= 0
#
# _C79: - SOC_{13,0} + dchg_{14,0} <= 0
#
# _C80: - SOC_{13,1} + dchg_{14,1} <= 0
#
# _C81: - SOC_{14,0} + dchg_{15,0} <= 0
#
# _C82: - SOC_{14,1} + dchg_{15,1} <= 0
#
# _C83: - SOC_{15,0} + dchg_{16,0} <= 0
#
# _C84: - SOC_{15,1} + dchg_{16,1} <= 0
#
# _C85: - SOC_{16,0} + dchg_{17,0} <= 0
#
# _C86: - SOC_{16,1} + dchg_{17,1} <= 0
#
# _C87: - SOC_{17,0} + dchg_{18,0} <= 0
#
# _C88: - SOC_{17,1} + dchg_{18,1} <= 0
#
# _C89: - SOC_{18,0} + dchg_{19,0} <= 0
#
# _C90: - SOC_{18,1} + dchg_{19,1} <= 0
#
# _C91: - SOC_{19,0} + dchg_{20,0} <= 0
#
# _C92: - SOC_{19,1} + dchg_{20,1} <= 0
#
# _C93: - SOC_{20,0} + dchg_{21,0} <= 0
#
# _C94: - SOC_{20,1} + dchg_{21,1} <= 0
#
# _C95: - SOC_{21,0} + dchg_{22,0} <= 0
#
# _C96: - SOC_{21,1} + dchg_{22,1} <= 0
#
# _C97: - SOC_{22,0} + dchg_{23,0} <= 0
#
# _C98: - SOC_{22,1} + dchg_{23,1} <= 0
#
# _C99: chg_{0,0} >= 0
#
# _C100: chg_{0,0} <= 0
#
# _C101: chg_{1,0} >= 0
#
# _C102: chg_{1,0} <= 0
#
# _C103: chg_{2,0} >= 0
#
# _C104: chg_{2,0} <= 0
#
# _C105: chg_{3,0} >= 0
#
# _C106: chg_{3,0} <= 0
#
# _C107: chg_{4,0} >= 0
#
# _C108: chg_{4,0} <= 0
#
# _C109: chg_{5,0} >= 0
#
# _C110: chg_{5,0} <= 0
#
# _C111: chg_{6,0} >= 0
#
# _C112: chg_{6,0} <= 0
#
# _C113: chg_{7,0} >= 0
#
# _C114: chg_{7,0} <= 0
#
# _C115: chg_{8,0} >= 0
#
# _C116: chg_{8,0} <= 0
#
# _C117: chg_{9,0} >= 0
#
# _C118: chg_{9,0} <= 0
#
# _C119: chg_{10,0} >= 0
#
# _C120: chg_{10,0} <= 0
#
# _C121: chg_{11,0} >= 0
#
# _C122: chg_{11,0} <= 0
#
# _C123: chg_{12,0} >= 0
#
# _C124: chg_{12,0} <= 0
#
# _C125: chg_{13,0} >= 0
#
# _C126: chg_{13,0} <= 0
#
# _C127: chg_{14,0} >= 0
#
# _C128: chg_{14,0} <= 0
#
# _C129: chg_{15,0} >= 0
#
# _C130: chg_{15,0} <= 0
#
# _C131: chg_{16,0} >= 0
#
# _C132: chg_{16,0} <= 0
#
# _C133: chg_{17,0} >= 0
#
# _C134: chg_{17,0} <= 0
#
# _C135: chg_{18,0} >= 0
#
# _C136: chg_{18,0} <= 0
#
# _C137: chg_{19,0} >= 0
#
# _C138: chg_{19,0} <= 0
#
# _C139: chg_{20,0} >= 0
#
# _C140: chg_{20,0} <= 0
#
# _C141: chg_{21,0} >= 0
#
# _C142: chg_{21,0} <= 0
#
# _C143: chg_{22,0} >= 0
#
# _C144: chg_{22,0} <= 0
#
# _C145: chg_{23,0} >= 0
#
# _C146: chg_{23,0} <= 0
#
# _C147: chg_{0,1} >= 0
#
# _C148: chg_{0,1} <= 8000
#
# _C149: chg_{1,1} >= 0
#
# _C150: chg_{1,1} <= 8000
#
# _C151: chg_{2,1} >= 0
#
# _C152: chg_{2,1} <= 8000
#
# _C153: chg_{3,1} >= 0
#
# _C154: chg_{3,1} <= 8000
#
# _C155: chg_{4,1} >= 0
#
# _C156: chg_{4,1} <= 8000
#
# _C157: chg_{5,1} >= 0
#
# _C158: chg_{5,1} <= 8000
#
# _C159: chg_{6,1} >= 0
#
# _C160: chg_{6,1} <= 8000
#
# _C161: chg_{7,1} >= 0
#
# _C162: chg_{7,1} <= 8000
#
# _C163: chg_{8,1} >= 0
#
# _C164: chg_{8,1} <= 8000
#
# _C165: chg_{9,1} >= 0
#
# _C166: chg_{9,1} <= 8000
#
# _C167: chg_{10,1} >= 0
#
# _C168: chg_{10,1} <= 8000
#
# _C169: chg_{11,1} >= 0
#
# _C170: chg_{11,1} <= 8000
#
# _C171: chg_{12,1} >= 0
#
# _C172: chg_{12,1} <= 8000
#
# _C173: chg_{13,1} >= 0
#
# _C174: chg_{13,1} <= 8000
#
# _C175: chg_{14,1} >= 0
#
# _C176: chg_{14,1} <= 8000
#
# _C177: chg_{15,1} >= 0
#
# _C178: chg_{15,1} <= 8000
#
# _C179: chg_{16,1} >= 0
#
# _C180: chg_{16,1} <= 8000
#
# _C181: chg_{17,1} >= 0
#
# _C182: chg_{17,1} <= 8000
#
# _C183: chg_{18,1} >= 0
#
# _C184: chg_{18,1} <= 8000
#
# _C185: chg_{19,1} >= 0
#
# _C186: chg_{19,1} <= 8000
#
# _C187: chg_{20,1} >= 0
#
# _C188: chg_{20,1} <= 8000
#
# _C189: chg_{21,1} >= 0
#
# _C190: chg_{21,1} <= 8000
#
# _C191: chg_{22,1} >= 0
#
# _C192: chg_{22,1} <= 8000
#
# _C193: chg_{23,1} >= 0
#
# _C194: chg_{23,1} <= 8000
#
# _C195: dchg_{0,0} >= 0
#
# _C196: dchg_{0,0} <= 0
#
# _C197: dchg_{1,0} >= 0
#
# _C198: dchg_{1,0} <= 0
#
# _C199: dchg_{2,0} >= 0
#
# _C200: dchg_{2,0} <= 0
#
# _C201: dchg_{3,0} >= 0
#
# _C202: dchg_{3,0} <= 0
#
# _C203: dchg_{4,0} >= 0
#
# _C204: dchg_{4,0} <= 0
#
# _C205: dchg_{5,0} >= 0
#
# _C206: dchg_{5,0} <= 0
#
# _C207: dchg_{6,0} >= 0
#
# _C208: dchg_{6,0} <= 0
#
# _C209: dchg_{7,0} >= 0
#
# _C210: dchg_{7,0} <= 0
#
# _C211: dchg_{8,0} >= 0
#
# _C212: dchg_{8,0} <= 0
#
# _C213: dchg_{9,0} >= 0
#
# _C214: dchg_{9,0} <= 0
#
# _C215: dchg_{10,0} >= 0
#
# _C216: dchg_{10,0} <= 0
#
# _C217: dchg_{11,0} >= 0
#
# _C218: dchg_{11,0} <= 0
#
# _C219: dchg_{12,0} >= 0
#
# _C220: dchg_{12,0} <= 0
#
# _C221: dchg_{13,0} >= 0
#
# _C222: dchg_{13,0} <= 0
#
# _C223: dchg_{14,0} >= 0
#
# _C224: dchg_{14,0} <= 0
#
# _C225: dchg_{15,0} >= 0
#
# _C226: dchg_{15,0} <= 0
#
# _C227: dchg_{16,0} >= 0
#
# _C228: dchg_{16,0} <= 0
#
# _C229: dchg_{17,0} >= 0
#
# _C230: dchg_{17,0} <= 0
#
# _C231: dchg_{18,0} >= 0
#
# _C232: dchg_{18,0} <= 0
#
# _C233: dchg_{19,0} >= 0
#
# _C234: dchg_{19,0} <= 0
#
# _C235: dchg_{20,0} >= 0
#
# _C236: dchg_{20,0} <= 0
#
# _C237: dchg_{21,0} >= 0
#
# _C238: dchg_{21,0} <= 0
#
# _C239: dchg_{22,0} >= 0
#
# _C240: dchg_{22,0} <= 0
#
# _C241: dchg_{23,0} >= 0
#
# _C242: dchg_{23,0} <= 0
#
# _C243: dchg_{0,1} >= 0
#
# _C244: dchg_{0,1} <= 8000
#
# _C245: dchg_{1,1} >= 0
#
# _C246: dchg_{1,1} <= 8000
#
# _C247: dchg_{2,1} >= 0
#
# _C248: dchg_{2,1} <= 8000
#
# _C249: dchg_{3,1} >= 0
#
# _C250: dchg_{3,1} <= 8000
#
# _C251: dchg_{4,1} >= 0
#
# _C252: dchg_{4,1} <= 8000
#
# _C253: dchg_{5,1} >= 0
#
# _C254: dchg_{5,1} <= 8000
#
# _C255: dchg_{6,1} >= 0
#
# _C256: dchg_{6,1} <= 8000
#
# _C257: dchg_{7,1} >= 0
#
# _C258: dchg_{7,1} <= 8000
#
# _C259: dchg_{8,1} >= 0
#
# _C260: dchg_{8,1} <= 8000
#
# _C261: dchg_{9,1} >= 0
#
# _C262: dchg_{9,1} <= 8000
#
# _C263: dchg_{10,1} >= 0
#
# _C264: dchg_{10,1} <= 8000
#
# _C265: dchg_{11,1} >= 0
#
# _C266: dchg_{11,1} <= 8000
#
# _C267: dchg_{12,1} >= 0
#
# _C268: dchg_{12,1} <= 8000
#
# _C269: dchg_{13,1} >= 0
#
# _C270: dchg_{13,1} <= 8000
#
# _C271: dchg_{14,1} >= 0
#
# _C272: dchg_{14,1} <= 8000
#
# _C273: dchg_{15,1} >= 0
#
# _C274: dchg_{15,1} <= 8000
#
# _C275: dchg_{16,1} >= 0
#
# _C276: dchg_{16,1} <= 8000
#
# _C277: dchg_{17,1} >= 0
#
# _C278: dchg_{17,1} <= 8000
#
# _C279: dchg_{18,1} >= 0
#
# _C280: dchg_{18,1} <= 8000
#
# _C281: dchg_{19,1} >= 0
#
# _C282: dchg_{19,1} <= 8000
#
# _C283: dchg_{20,1} >= 0
#
# _C284: dchg_{20,1} <= 8000
#
# _C285: dchg_{21,1} >= 0
#
# _C286: dchg_{21,1} <= 8000
#
# _C287: dchg_{22,1} >= 0
#
# _C288: dchg_{22,1} <= 8000
#
# _C289: dchg_{23,1} >= 0
#
# _C290: dchg_{23,1} <= 8000
#
# _C291: chg_{0,0} + chg_{1,0} + chg_{10,0} + chg_{11,0} + chg_{12,0}
#  + chg_{13,0} + chg_{14,0} + chg_{15,0} + chg_{16,0} + chg_{17,0} + chg_{18,0}
#  + chg_{19,0} + chg_{2,0} + chg_{20,0} + chg_{21,0} + chg_{22,0} + chg_{23,0}
#  + chg_{3,0} + chg_{4,0} + chg_{5,0} + chg_{6,0} + chg_{7,0} + chg_{8,0}
#  + chg_{9,0} <= 0
#
# _C292: chg_{0,1} + chg_{1,1} + chg_{10,1} + chg_{11,1} + chg_{12,1}
#  + chg_{13,1} + chg_{14,1} + chg_{15,1} + chg_{16,1} + chg_{17,1} + chg_{18,1}
#  + chg_{19,1} + chg_{2,1} + chg_{20,1} + chg_{21,1} + chg_{22,1} + chg_{23,1}
#  + chg_{3,1} + chg_{4,1} + chg_{5,1} + chg_{6,1} + chg_{7,1} + chg_{8,1}
#  + chg_{9,1} <= 8000
#
# _C293: dchg_{0,0} + dchg_{1,0} + dchg_{10,0} + dchg_{11,0} + dchg_{12,0}
#  + dchg_{13,0} + dchg_{14,0} + dchg_{15,0} + dchg_{16,0} + dchg_{17,0}
#  + dchg_{18,0} + dchg_{19,0} + dchg_{2,0} + dchg_{20,0} + dchg_{21,0}
#  + dchg_{22,0} + dchg_{23,0} + dchg_{3,0} + dchg_{4,0} + dchg_{5,0}
#  + dchg_{6,0} + dchg_{7,0} + dchg_{8,0} + dchg_{9,0} <= 0
#
# _C294: dchg_{0,1} + dchg_{1,1} + dchg_{10,1} + dchg_{11,1} + dchg_{12,1}
#  + dchg_{13,1} + dchg_{14,1} + dchg_{15,1} + dchg_{16,1} + dchg_{17,1}
#  + dchg_{18,1} + dchg_{19,1} + dchg_{2,1} + dchg_{20,1} + dchg_{21,1}
#  + dchg_{22,1} + dchg_{23,1} + dchg_{3,1} + dchg_{4,1} + dchg_{5,1}
#  + dchg_{6,1} + dchg_{7,1} + dchg_{8,1} + dchg_{9,1} <= 8000
#
# _C295: SOC_{0,0} >= 0
#
# _C296: SOC_{0,0} <= 0
#
# _C297: SOC_{1,0} >= 0
#
# _C298: SOC_{1,0} <= 0
#
# _C299: SOC_{2,0} >= 0
#
# _C300: SOC_{2,0} <= 0
#
# _C301: SOC_{3,0} >= 0
#
# _C302: SOC_{3,0} <= 0
#
# _C303: SOC_{4,0} >= 0
#
# _C304: SOC_{4,0} <= 0
#
# _C305: SOC_{5,0} >= 0
#
# _C306: SOC_{5,0} <= 0
#
# _C307: SOC_{6,0} >= 0
#
# _C308: SOC_{6,0} <= 0
#
# _C309: SOC_{7,0} >= 0
#
# _C310: SOC_{7,0} <= 0
#
# _C311: SOC_{8,0} >= 0
#
# _C312: SOC_{8,0} <= 0
#
# _C313: SOC_{9,0} >= 0
#
# _C314: SOC_{9,0} <= 0
#
# _C315: SOC_{10,0} >= 0
#
# _C316: SOC_{10,0} <= 0
#
# _C317: SOC_{11,0} >= 0
#
# _C318: SOC_{11,0} <= 0
#
# _C319: SOC_{12,0} >= 0
#
# _C320: SOC_{12,0} <= 0
#
# _C321: SOC_{13,0} >= 0
#
# _C322: SOC_{13,0} <= 0
#
# _C323: SOC_{14,0} >= 0
#
# _C324: SOC_{14,0} <= 0
#
# _C325: SOC_{15,0} >= 0
#
# _C326: SOC_{15,0} <= 0
#
# _C327: SOC_{16,0} >= 0
#
# _C328: SOC_{16,0} <= 0
#
# _C329: SOC_{17,0} >= 0
#
# _C330: SOC_{17,0} <= 0
#
# _C331: SOC_{18,0} >= 0
#
# _C332: SOC_{18,0} <= 0
#
# _C333: SOC_{19,0} >= 0
#
# _C334: SOC_{19,0} <= 0
#
# _C335: SOC_{20,0} >= 0
#
# _C336: SOC_{20,0} <= 0
#
# _C337: SOC_{21,0} >= 0
#
# _C338: SOC_{21,0} <= 0
#
# _C339: SOC_{22,0} >= 0
#
# _C340: SOC_{22,0} <= 0
#
# _C341: SOC_{23,0} >= 0
#
# _C342: SOC_{23,0} <= 0
#
# _C343: SOC_{0,1} >= 0
#
# _C344: SOC_{0,1} <= 8000
#
# _C345: SOC_{1,1} >= 0
#
# _C346: SOC_{1,1} <= 8000
#
# _C347: SOC_{2,1} >= 0
#
# _C348: SOC_{2,1} <= 8000
#
# _C349: SOC_{3,1} >= 0
#
# _C350: SOC_{3,1} <= 8000
#
# _C351: SOC_{4,1} >= 0
#
# _C352: SOC_{4,1} <= 8000
#
# _C353: SOC_{5,1} >= 0
#
# _C354: SOC_{5,1} <= 8000
#
# _C355: SOC_{6,1} >= 0
#
# _C356: SOC_{6,1} <= 8000
#
# _C357: SOC_{7,1} >= 0
#
# _C358: SOC_{7,1} <= 8000
#
# _C359: SOC_{8,1} >= 0
#
# _C360: SOC_{8,1} <= 8000
#
# _C361: SOC_{9,1} >= 0
#
# _C362: SOC_{9,1} <= 8000
#
# _C363: SOC_{10,1} >= 0
#
# _C364: SOC_{10,1} <= 8000
#
# _C365: SOC_{11,1} >= 0
#
# _C366: SOC_{11,1} <= 8000
#
# _C367: SOC_{12,1} >= 0
#
# _C368: SOC_{12,1} <= 8000
#
# _C369: SOC_{13,1} >= 0
#
# _C370: SOC_{13,1} <= 8000
#
# _C371: SOC_{14,1} >= 0
#
# _C372: SOC_{14,1} <= 8000
#
# _C373: SOC_{15,1} >= 0
#
# _C374: SOC_{15,1} <= 8000
#
# _C375: SOC_{16,1} >= 0
#
# _C376: SOC_{16,1} <= 8000
#
# _C377: SOC_{17,1} >= 0
#
# _C378: SOC_{17,1} <= 8000
#
# _C379: SOC_{18,1} >= 0
#
# _C380: SOC_{18,1} <= 8000
#
# _C381: SOC_{19,1} >= 0
#
# _C382: SOC_{19,1} <= 8000
#
# _C383: SOC_{20,1} >= 0
#
# _C384: SOC_{20,1} <= 8000
#
# _C385: SOC_{21,1} >= 0
#
# _C386: SOC_{21,1} <= 8000
#
# _C387: SOC_{22,1} >= 0
#
# _C388: SOC_{22,1} <= 8000
#
# _C389: SOC_{23,1} >= 0
#
# _C390: SOC_{23,1} <= 8000
#
# _C391: chg_{0,0} - 100000 z_chg_{0,0} <= 0
#
# _C392: dchg_{0,0} - 100000 z_dchg_{0,0} <= 0
#
# _C393: z_chg_{0,0} + z_dchg_{0,0} <= 1
#
# _C394: chg_{1,0} - 100000 z_chg_{1,0} <= 0
#
# _C395: dchg_{1,0} - 100000 z_dchg_{1,0} <= 0
#
# _C396: z_chg_{1,0} + z_dchg_{1,0} <= 1
#
# _C397: chg_{2,0} - 100000 z_chg_{2,0} <= 0
#
# _C398: dchg_{2,0} - 100000 z_dchg_{2,0} <= 0
#
# _C399: z_chg_{2,0} + z_dchg_{2,0} <= 1
#
# _C400: chg_{3,0} - 100000 z_chg_{3,0} <= 0
#
# _C401: dchg_{3,0} - 100000 z_dchg_{3,0} <= 0
#
# _C402: z_chg_{3,0} + z_dchg_{3,0} <= 1
#
# _C403: chg_{4,0} - 100000 z_chg_{4,0} <= 0
#
# _C404: dchg_{4,0} - 100000 z_dchg_{4,0} <= 0
#
# _C405: z_chg_{4,0} + z_dchg_{4,0} <= 1
#
# _C406: chg_{5,0} - 100000 z_chg_{5,0} <= 0
#
# _C407: dchg_{5,0} - 100000 z_dchg_{5,0} <= 0
#
# _C408: z_chg_{5,0} + z_dchg_{5,0} <= 1
#
# _C409: chg_{6,0} - 100000 z_chg_{6,0} <= 0
#
# _C410: dchg_{6,0} - 100000 z_dchg_{6,0} <= 0
#
# _C411: z_chg_{6,0} + z_dchg_{6,0} <= 1
#
# _C412: chg_{7,0} - 100000 z_chg_{7,0} <= 0
#
# _C413: dchg_{7,0} - 100000 z_dchg_{7,0} <= 0
#
# _C414: z_chg_{7,0} + z_dchg_{7,0} <= 1
#
# _C415: chg_{8,0} - 100000 z_chg_{8,0} <= 0
#
# _C416: dchg_{8,0} - 100000 z_dchg_{8,0} <= 0
#
# _C417: z_chg_{8,0} + z_dchg_{8,0} <= 1
#
# _C418: chg_{9,0} - 100000 z_chg_{9,0} <= 0
#
# _C419: dchg_{9,0} - 100000 z_dchg_{9,0} <= 0
#
# _C420: z_chg_{9,0} + z_dchg_{9,0} <= 1
#
# _C421: chg_{10,0} - 100000 z_chg_{10,0} <= 0
#
# _C422: dchg_{10,0} - 100000 z_dchg_{10,0} <= 0
#
# _C423: z_chg_{10,0} + z_dchg_{10,0} <= 1
#
# _C424: chg_{11,0} - 100000 z_chg_{11,0} <= 0
#
# _C425: dchg_{11,0} - 100000 z_dchg_{11,0} <= 0
#
# _C426: z_chg_{11,0} + z_dchg_{11,0} <= 1
#
# _C427: chg_{12,0} - 100000 z_chg_{12,0} <= 0
#
# _C428: dchg_{12,0} - 100000 z_dchg_{12,0} <= 0
#
# _C429: z_chg_{12,0} + z_dchg_{12,0} <= 1
#
# _C430: chg_{13,0} - 100000 z_chg_{13,0} <= 0
#
# _C431: dchg_{13,0} - 100000 z_dchg_{13,0} <= 0
#
# _C432: z_chg_{13,0} + z_dchg_{13,0} <= 1
#
# _C433: chg_{14,0} - 100000 z_chg_{14,0} <= 0
#
# _C434: dchg_{14,0} - 100000 z_dchg_{14,0} <= 0
#
# _C435: z_chg_{14,0} + z_dchg_{14,0} <= 1
#
# _C436: chg_{15,0} - 100000 z_chg_{15,0} <= 0
#
# ...
#  + y_{12,2} + y_{13,0} + y_{13,1} + y_{13,2} + y_{14,0} + y_{14,1} + y_{14,2}
#  + y_{15,0} + y_{15,1} + y_{15,2} + y_{16,0} + y_{16,1} + y_{16,2} + y_{17,0}
#  + y_{17,1} + y_{17,2} + y_{18,0} + y_{18,1} + y_{18,2} + y_{19,0} + y_{19,1}
#  + y_{19,2} + y_{2,0} + y_{2,1} + y_{2,2} + y_{20,0} + y_{20,1} + y_{20,2}
#  + y_{21,0} + y_{21,1} + y_{21,2} + y_{22,0} + y_{22,1} + y_{22,2} + y_{23,0}
#  + y_{23,1} + y_{23,2} + y_{3,0} + y_{3,1} + y_{3,2} + y_{4,0} + y_{4,1}
#  + y_{4,2} + y_{5,0} + y_{5,1} + y_{5,2} + y_{6,0} + y_{6,1} + y_{6,2}
#  + y_{7,0} + y_{7,1} + y_{7,2} + y_{8,0} + y_{8,1} + y_{8,2} + y_{9,0}
#  + y_{9,1} + y_{9,2} >= 0
#
# _C1038: x_{0,2} + x_{1,2} + x_{10,2} + x_{11,2} + x_{12,2} + x_{13,2}
#  + x_{14,2} + x_{15,2} + x_{16,2} + x_{17,2} + x_{18,2} + x_{19,2} + x_{2,2}
#  + x_{20,2} + x_{21,2} + x_{22,2} + x_{23,2} + x_{3,2} + x_{4,2} + x_{5,2}
#  + x_{6,2} + x_{7,2} + x_{8,2} + x_{9,2} <= 330180.490225
#
# _C1039: x_{0,1} = 0
#
# _C1040: x_{1,1} = 0
#
# _C1041: x_{2,1} = 0
#
# _C1042: x_{3,1} = 0
#
# _C1043: x_{4,1} = 0
#
# _C1044: x_{5,1} = 0
#
# _C1045: x_{6,1} = 0
#
# _C1046: x_{7,1} = 0
#
# _C1047: x_{8,1} = 0
#
# _C1048: x_{9,1} = 0
#
# _C1049: x_{10,1} = 0
#
# _C1050: x_{11,1} = 0
#
# _C1051: x_{12,1} = 0
#
# _C1052: x_{13,1} = 0
#
# _C1053: x_{14,1} = 0
#
# _C1054: x_{15,1} = 0
#
# _C1055: x_{16,1} = 0
#
# _C1056: x_{17,1} = 0
#
# _C1057: x_{18,1} = 0
#
# _C1058: x_{19,1} = 0
#
# _C1059: x_{20,1} = 0
#
# _C1060: x_{21,1} = 0
#
# _C1061: x_{22,1} = 0
#
# _C1062: x_{23,1} = 0
#
# nuclear_ramping_0: x_{0,2} = 3340.244
#
# nuclear_ramping_1: x_{1,2} = 3340.244
#
# nuclear_ramping_2: x_{2,2} = 3340.244
#
# nuclear_ramping_3: x_{3,2} = 3340.244
#
# nuclear_ramping_4: x_{4,2} = 3340.244
#
# nuclear_ramping_5: x_{5,2} = 3340.244
#
# nuclear_ramping_6: x_{6,2} = 3340.244
#
# nuclear_ramping_7: x_{7,2} = 3340.244
#
# nuclear_ramping_8: x_{8,2} = 3340.244
#
# nuclear_ramping_9: x_{9,2} = 3340.244
#
# nuclear_ramping_10: x_{10,2} = 3340.244
#
# nuclear_ramping_11: x_{11,2} = 3340.244
#
# nuclear_ramping_12: x_{12,2} = 3340.244
#
# nuclear_ramping_13: x_{13,2} = 3340.244
#
# nuclear_ramping_14: x_{14,2} = 3340.244
#
# nuclear_ramping_15: x_{15,2} = 3340.244
#
# nuclear_ramping_16: x_{16,2} = 3340.244
#
# nuclear_ramping_17: x_{17,2} = 3340.244
#
# nuclear_ramping_18: x_{18,2} = 3340.244
#
# nuclear_ramping_19: x_{19,2} = 3340.244
#
# nuclear_ramping_20: x_{20,2} = 3340.244
#
# nuclear_ramping_21: x_{21,2} = 3340.244
#
# nuclear_ramping_22: x_{22,2} = 3340.244
#
# nuclear_ramping_23: x_{23,2} = 3340.244
#
# VARIABLES
# SOC_{0,0} Continuous
# SOC_{0,1} Continuous
# SOC_{1,0} Continuous
# SOC_{1,1} Continuous
# SOC_{10,0} Continuous
# SOC_{10,1} Continuous
# SOC_{11,0} Continuous
# SOC_{11,1} Continuous
# SOC_{12,0} Continuous
# SOC_{12,1} Continuous
# SOC_{13,0} Continuous
# SOC_{13,1} Continuous
# SOC_{14,0} Continuous
# SOC_{14,1} Continuous
# SOC_{15,0} Continuous
# SOC_{15,1} Continuous
# SOC_{16,0} Continuous
# SOC_{16,1} Continuous
# SOC_{17,0} Continuous
# SOC_{17,1} Continuous
# SOC_{18,0} Continuous
# SOC_{18,1} Continuous
# SOC_{19,0} Continuous
# SOC_{19,1} Continuous
# SOC_{2,0} Continuous
# SOC_{2,1} Continuous
# SOC_{20,0} Continuous
# SOC_{20,1} Continuous
# SOC_{21,0} Continuous
# SOC_{21,1} Continuous
# SOC_{22,0} Continuous
# SOC_{22,1} Continuous
# SOC_{23,0} Continuous
# SOC_{23,1} Continuous
# SOC_{3,0} Continuous
# SOC_{3,1} Continuous
# SOC_{4,0} Continuous
# SOC_{4,1} Continuous
# SOC_{5,0} Continuous
# SOC_{5,1} Continuous
# SOC_{6,0} Continuous
# SOC_{6,1} Continuous
# SOC_{7,0} Continuous
# SOC_{7,1} Continuous
# SOC_{8,0} Continuous
# SOC_{8,1} Continuous
# SOC_{9,0} Continuous
# SOC_{9,1} Continuous
# chg_{0,0} Continuous
# chg_{0,1} Continuous
# chg_{1,0} Continuous
# chg_{1,1} Continuous
# chg_{10,0} Continuous
# chg_{10,1} Continuous
# chg_{11,0} Continuous
# chg_{11,1} Continuous
# chg_{12,0} Continuous
# chg_{12,1} Continuous
# chg_{13,0} Continuous
# chg_{13,1} Continuous
# chg_{14,0} Continuous
# chg_{14,1} Continuous
# chg_{15,0} Continuous
# chg_{15,1} Continuous
# chg_{16,0} Continuous
# chg_{16,1} Continuous
# chg_{17,0} Continuous
# chg_{17,1} Continuous
# chg_{18,0} Continuous
# chg_{18,1} Continuous
# chg_{19,0} Continuous
# chg_{19,1} Continuous
# chg_{2,0} Continuous
# chg_{2,1} Continuous
# chg_{20,0} Continuous
# chg_{20,1} Continuous
# chg_{21,0} Continuous
# chg_{21,1} Continuous
# chg_{22,0} Continuous
# chg_{22,1} Continuous
# chg_{23,0} Continuous
# chg_{23,1} Continuous
# chg_{3,0} Continuous
# chg_{3,1} Continuous
# chg_{4,0} Continuous
# chg_{4,1} Continuous
# chg_{5,0} Continuous
# chg_{5,1} Continuous
# chg_{6,0} Continuous
# chg_{6,1} Continuous
# chg_{7,0} Continuous
# chg_{7,1} Continuous
# chg_{8,0} Continuous
# chg_{8,1} Continuous
# chg_{9,0} Continuous
# chg_{9,1} Continuous
# dchg_{0,0} Continuous
# dchg_{0,1} Continuous
# dchg_{1,0} Continuous
# dchg_{1,1} Continuous
# dchg_{10,0} Continuous
# dchg_{10,1} Continuous
# dchg_{11,0} Continuous
# dchg_{11,1} Continuous
# dchg_{12,0} Continuous
# dchg_{12,1} Continuous
# dchg_{13,0} Continuous
# dchg_{13,1} Continuous
# dchg_{14,0} Continuous
# dchg_{14,1} Continuous
# dchg_{15,0} Continuous
# dchg_{15,1} Continuous
# dchg_{16,0} Continuous
# dchg_{16,1} Continuous
# dchg_{17,0} Continuous
# dchg_{17,1} Continuous
# dchg_{18,0} Continuous
# dchg_{18,1} Continuous
# dchg_{19,0} Continuous
# dchg_{19,1} Continuous
# dchg_{2,0} Continuous
# dchg_{2,1} Continuous
# dchg_{20,0} Continuous
# dchg_{20,1} Continuous
# dchg_{21,0} Continuous
# dchg_{21,1} Continuous
# dchg_{22,0} Continuous
# dchg_{22,1} Continuous
# dchg_{23,0} Continuous
# dchg_{23,1} Continuous
# dchg_{3,0} Continuous
# dchg_{3,1} Continuous
# dchg_{4,0} Continuous
# dchg_{4,1} Continuous
# dchg_{5,0} Continuous
# dchg_{5,1} Continuous
# dchg_{6,0} Continuous
# dchg_{6,1} Continuous
# dchg_{7,0} Continuous
# dchg_{7,1} Continuous
# dchg_{8,0} Continuous
# dchg_{8,1} Continuous
# dchg_{9,0} Continuous
# dchg_{9,1} Continuous
# shed_left_0 Continuous
# shed_left_1 Continuous
# shed_left_10 Continuous
# shed_left_11 Continuous
# shed_left_12 Continuous
# shed_left_13 Continuous
# shed_left_14 Continuous
# shed_left_15 Continuous
# shed_left_16 Continuous
# shed_left_17 Continuous
# shed_left_18 Continuous
# shed_left_19 Continuous
# shed_left_2 Continuous
# shed_left_20 Continuous
# shed_left_21 Continuous
# shed_left_22 Continuous
# shed_left_23 Continuous
# shed_left_3 Continuous
# shed_left_4 Continuous
# shed_left_5 Continuous
# shed_left_6 Continuous
# shed_left_7 Continuous
# shed_left_8 Continuous
# shed_left_9 Continuous
# shed_now_0 Continuous
# shed_now_1 Continuous
# shed_now_10 Continuous
# shed_now_11 Continuous
# shed_now_12 Continuous
# shed_now_13 Continuous
# shed_now_14 Continuous
# shed_now_15 Continuous
# shed_now_16 Continuous
# shed_now_17 Continuous
# shed_now_18 Continuous
# shed_now_19 Continuous
# shed_now_2 Continuous
# shed_now_20 Continuous
# shed_now_21 Continuous
# shed_now_22 Continuous
# shed_now_23 Continuous
# shed_now_3 Continuous
# shed_now_4 Continuous
# shed_now_5 Continuous
# shed_now_6 Continuous
# shed_now_7 Continuous
# shed_now_8 Continuous
# shed_now_9 Continuous
# x_{0,0} Continuous
# x_{0,1} Continuous
# x_{0,2} Continuous
# x_{0,3} Continuous
# x_{0,4} Continuous
# x_{0,5} Continuous
# x_{0,6} Continuous
# x_{0,7} Continuous
# x_{0,8} Continuous
# x_{1,0} Continuous
# x_{1,1} Continuous
# x_{1,2} Continuous
# x_{1,3} Continuous
# x_{1,4} Continuous
# x_{1,5} Continuous
# x_{1,6} Continuous
# x_{1,7} Continuous
# x_{1,8} Continuous
# x_{10,0} Continuous
# x_{10,1} Continuous
# x_{10,2} Continuous
# x_{10,3} Continuous
# x_{10,4} Continuous
# x_{10,5} Continuous
# x_{10,6} Continuous
# x_{10,7} Continuous
# x_{10,8} Continuous
# x_{11,0} Continuous
# x_{11,1} Continuous
# x_{11,2} Continuous
# x_{11,3} Continuous
# x_{11,4} Continuous
# x_{11,5} Continuous
# x_{11,6} Continuous
# x_{11,7} Continuous
# x_{11,8} Continuous
# x_{12,0} Continuous
# x_{12,1} Continuous
# x_{12,2} Continuous
# x_{12,3} Continuous
# x_{12,4} Continuous
# x_{12,5} Continuous
# x_{12,6} Continuous
# x_{12,7} Continuous
# x_{12,8} Continuous
# x_{13,0} Continuous
# x_{13,1} Continuous
# x_{13,2} Continuous
# x_{13,3} Continuous
# x_{13,4} Continuous
# x_{13,5} Continuous
# x_{13,6} Continuous
# x_{13,7} Continuous
# x_{13,8} Continuous
# x_{14,0} Continuous
# x_{14,1} Continuous
# x_{14,2} Continuous
# x_{14,3} Continuous
# x_{14,4} Continuous
# x_{14,5} Continuous
# x_{14,6} Continuous
# x_{14,7} Continuous
# x_{14,8} Continuous
# x_{15,0} Continuous
# x_{15,1} Continuous
# x_{15,2} Continuous
# x_{15,3} Continuous
# x_{15,4} Continuous
# x_{15,5} Continuous
# x_{15,6} Continuous
# x_{15,7} Continuous
# x_{15,8} Continuous
# x_{16,0} Continuous
# x_{16,1} Continuous
# x_{16,2} Continuous
# x_{16,3} Continuous
# x_{16,4} Continuous
# x_{16,5} Continuous
# x_{16,6} Continuous
# x_{16,7} Continuous
# x_{16,8} Continuous
# x_{17,0} Continuous
# x_{17,1} Continuous
# x_{17,2} Continuous
# x_{17,3} Continuous
# x_{17,4} Continuous
# x_{17,5} Continuous
# x_{17,6} Continuous
# x_{17,7} Continuous
# x_{17,8} Continuous
# x_{18,0} Continuous
# x_{18,1} Continuous
# x_{18,2} Continuous
# x_{18,3} Continuous
# x_{18,4} Continuous
# x_{18,5} Continuous
# x_{18,6} Continuous
# x_{18,7} Continuous
# x_{18,8} Continuous
# x_{19,0} Continuous
# x_{19,1} Continuous
# x_{19,2} Continuous
# x_{19,3} Continuous
# x_{19,4} Continuous
# x_{19,5} Continuous
# x_{19,6} Continuous
# x_{19,7} Continuous
# x_{19,8} Continuous
# x_{2,0} Continuous
# x_{2,1} Continuous
# x_{2,2} Continuous
# x_{2,3} Continuous
# x_{2,4} Continuous
# x_{2,5} Continuous
# x_{2,6} Continuous
# x_{2,7} Continuous
# x_{2,8} Continuous
# x_{20,0} Continuous
# x_{20,1} Continuous
# x_{20,2} Continuous
# x_{20,3} Continuous
# x_{20,4} Continuous
# x_{20,5} Continuous
# x_{20,6} Continuous
# x_{20,7} Continuous
# x_{20,8} Continuous
# x_{21,0} Continuous
# x_{21,1} Continuous
# x_{21,2} Continuous
# x_{21,3} Continuous
# x_{21,4} Continuous
# x_{21,5} Continuous
# x_{21,6} Continuous
# x_{21,7} Continuous
# x_{21,8} Continuous
# x_{22,0} Continuous
# x_{22,1} Continuous
# x_{22,2} Continuous
# x_{22,3} Continuous
# x_{22,4} Continuous
# x_{22,5} Continuous
# x_{22,6} Continuous
# x_{22,7} Continuous
# x_{22,8} Continuous
# x_{23,0} Continuous
# x_{23,1} Continuous
# x_{23,2} Continuous
# x_{23,3} Continuous
# x_{23,4} Continuous
# x_{23,5} Continuous
# x_{23,6} Continuous
# x_{23,7} Continuous
# x_{23,8} Continuous
# x_{3,0} Continuous
# x_{3,1} Continuous
# x_{3,2} Continuous
# x_{3,3} Continuous
# x_{3,4} Continuous
# x_{3,5} Continuous
# x_{3,6} Continuous
# x_{3,7} Continuous
# x_{3,8} Continuous
# x_{4,0} Continuous
# x_{4,1} Continuous
# x_{4,2} Continuous
# x_{4,3} Continuous
# x_{4,4} Continuous
# x_{4,5} Continuous
# x_{4,6} Continuous
# x_{4,7} Continuous
# x_{4,8} Continuous
# x_{5,0} Continuous
# x_{5,1} Continuous
# x_{5,2} Continuous
# x_{5,3} Continuous
# x_{5,4} Continuous
# x_{5,5} Continuous
# x_{5,6} Continuous
# x_{5,7} Continuous
# x_{5,8} Continuous
# x_{6,0} Continuous
# x_{6,1} Continuous
# x_{6,2} Continuous
# x_{6,3} Continuous
# x_{6,4} Continuous
# x_{6,5} Continuous
# x_{6,6} Continuous
# x_{6,7} Continuous
# x_{6,8} Continuous
# x_{7,0} Continuous
# x_{7,1} Continuous
# x_{7,2} Continuous
# x_{7,3} Continuous
# x_{7,4} Continuous
# x_{7,5} Continuous
# x_{7,6} Continuous
# x_{7,7} Continuous
# x_{7,8} Continuous
# x_{8,0} Continuous
# x_{8,1} Continuous
# x_{8,2} Continuous
# x_{8,3} Continuous
# x_{8,4} Continuous
# x_{8,5} Continuous
# x_{8,6} Continuous
# x_{8,7} Continuous
# x_{8,8} Continuous
# x_{9,0} Continuous
# x_{9,1} Continuous
# x_{9,2} Continuous
# x_{9,3} Continuous
# x_{9,4} Continuous
# x_{9,5} Continuous
# x_{9,6} Continuous
# x_{9,7} Continuous
# x_{9,8} Continuous
# y_{0,0} Continuous
# y_{0,1} Continuous
# y_{0,2} Continuous
# y_{1,0} Continuous
# y_{1,1} Continuous
# y_{1,2} Continuous
# y_{10,0} Continuous
# y_{10,1} Continuous
# y_{10,2} Continuous
# y_{11,0} Continuous
# y_{11,1} Continuous
# y_{11,2} Continuous
# y_{12,0} Continuous
# y_{12,1} Continuous
# y_{12,2} Continuous
# y_{13,0} Continuous
# y_{13,1} Continuous
# y_{13,2} Continuous
# y_{14,0} Continuous
# y_{14,1} Continuous
# y_{14,2} Continuous
# y_{15,0} Continuous
# y_{15,1} Continuous
# y_{15,2} Continuous
# y_{16,0} Continuous
# y_{16,1} Continuous
# y_{16,2} Continuous
# y_{17,0} Continuous
# y_{17,1} Continuous
# y_{17,2} Continuous
# y_{18,0} Continuous
# y_{18,1} Continuous
# y_{18,2} Continuous
# y_{19,0} Continuous
# y_{19,1} Continuous
# y_{19,2} Continuous
# y_{2,0} Continuous
# y_{2,1} Continuous
# y_{2,2} Continuous
# y_{20,0} Continuous
# y_{20,1} Continuous
# y_{20,2} Continuous
# y_{21,0} Continuous
# y_{21,1} Continuous
# y_{21,2} Continuous
# y_{22,0} Continuous
# y_{22,1} Continuous
# y_{22,2} Continuous
# y_{23,0} Continuous
# y_{23,1} Continuous
# y_{23,2} Continuous
# y_{3,0} Continuous
# y_{3,1} Continuous
# y_{3,2} Continuous
# y_{4,0} Continuous
# y_{4,1} Continuous
# y_{4,2} Continuous
# y_{5,0} Continuous
# y_{5,1} Continuous
# y_{5,2} Continuous
# y_{6,0} Continuous
# y_{6,1} Continuous
# y_{6,2} Continuous
# y_{7,0} Continuous
# y_{7,1} Continuous
# y_{7,2} Continuous
# y_{8,0} Continuous
# y_{8,1} Continuous
# y_{8,2} Continuous
# y_{9,0} Continuous
# y_{9,1} Continuous
# y_{9,2} Continuous
# 0 <= z_chg_{0,0} <= 1 Integer
# 0 <= z_chg_{0,1} <= 1 Integer
# 0 <= z_chg_{1,0} <= 1 Integer
# 0 <= z_chg_{1,1} <= 1 Integer
# 0 <= z_chg_{10,0} <= 1 Integer
# 0 <= z_chg_{10,1} <= 1 Integer
# 0 <= z_chg_{11,0} <= 1 Integer
# 0 <= z_chg_{11,1} <= 1 Integer
# 0 <= z_chg_{12,0} <= 1 Integer
# 0 <= z_chg_{12,1} <= 1 Integer
# 0 <= z_chg_{13,0} <= 1 Integer
# 0 <= z_chg_{13,1} <= 1 Integer
# 0 <= z_chg_{14,0} <= 1 Integer
# 0 <= z_chg_{14,1} <= 1 Integer
# 0 <= z_chg_{15,0} <= 1 Integer
# 0 <= z_chg_{15,1} <= 1 Integer
# 0 <= z_chg_{16,0} <= 1 Integer
# 0 <= z_chg_{16,1} <= 1 Integer
# 0 <= z_chg_{17,0} <= 1 Integer
# 0 <= z_chg_{17,1} <= 1 Integer
# 0 <= z_chg_{18,0} <= 1 Integer
# 0 <= z_chg_{18,1} <= 1 Integer
# 0 <= z_chg_{19,0} <= 1 Integer
# 0 <= z_chg_{19,1} <= 1 Integer
# 0 <= z_chg_{2,0} <= 1 Integer
# 0 <= z_chg_{2,1} <= 1 Integer
# 0 <= z_chg_{20,0} <= 1 Integer
# 0 <= z_chg_{20,1} <= 1 Integer
# 0 <= z_chg_{21,0} <= 1 Integer
# 0 <= z_chg_{21,1} <= 1 Integer
# 0 <= z_chg_{22,0} <= 1 Integer
# 0 <= z_chg_{22,1} <= 1 Integer
# 0 <= z_chg_{23,0} <= 1 Integer
# 0 <= z_chg_{23,1} <= 1 Integer
# 0 <= z_chg_{3,0} <= 1 Integer
# 0 <= z_chg_{3,1} <= 1 Integer
# 0 <= z_chg_{4,0} <= 1 Integer
# 0 <= z_chg_{4,1} <= 1 Integer
# 0 <= z_chg_{5,0} <= 1 Integer
# 0 <= z_chg_{5,1} <= 1 Integer
# 0 <= z_chg_{6,0} <= 1 Integer
# 0 <= z_chg_{6,1} <= 1 Integer
# 0 <= z_chg_{7,0} <= 1 Integer
# 0 <= z_chg_{7,1} <= 1 Integer
# 0 <= z_chg_{8,0} <= 1 Integer
# 0 <= z_chg_{8,1} <= 1 Integer
# 0 <= z_chg_{9,0} <= 1 Integer
# 0 <= z_chg_{9,1} <= 1 Integer
# 0 <= z_dchg_0 <= 1 Integer
# 0 <= z_dchg_1 <= 1 Integer
# 0 <= z_dchg_10 <= 1 Integer
# 0 <= z_dchg_11 <= 1 Integer
# 0 <= z_dchg_12 <= 1 Integer
# 0 <= z_dchg_13 <= 1 Integer
# 0 <= z_dchg_14 <= 1 Integer
# 0 <= z_dchg_15 <= 1 Integer
# 0 <= z_dchg_16 <= 1 Integer
# 0 <= z_dchg_17 <= 1 Integer
# 0 <= z_dchg_18 <= 1 Integer
# 0 <= z_dchg_19 <= 1 Integer
# 0 <= z_dchg_2 <= 1 Integer
# 0 <= z_dchg_20 <= 1 Integer
# 0 <= z_dchg_21 <= 1 Integer
# 0 <= z_dchg_22 <= 1 Integer
# 0 <= z_dchg_23 <= 1 Integer
# 0 <= z_dchg_3 <= 1 Integer
# 0 <= z_dchg_4 <= 1 Integer
# 0 <= z_dchg_5 <= 1 Integer
# 0 <= z_dchg_6 <= 1 Integer
# 0 <= z_dchg_7 <= 1 Integer
# 0 <= z_dchg_8 <= 1 Integer
# 0 <= z_dchg_9 <= 1 Integer
# 0 <= z_dchg_{0,0} <= 1 Integer
# 0 <= z_dchg_{0,1} <= 1 Integer
# 0 <= z_dchg_{1,0} <= 1 Integer
# 0 <= z_dchg_{1,1} <= 1 Integer
# 0 <= z_dchg_{10,0} <= 1 Integer
# 0 <= z_dchg_{10,1} <= 1 Integer
# 0 <= z_dchg_{11,0} <= 1 Integer
# 0 <= z_dchg_{11,1} <= 1 Integer
# 0 <= z_dchg_{12,0} <= 1 Integer
# 0 <= z_dchg_{12,1} <= 1 Integer
# 0 <= z_dchg_{13,0} <= 1 Integer
# 0 <= z_dchg_{13,1} <= 1 Integer
# 0 <= z_dchg_{14,0} <= 1 Integer
# 0 <= z_dchg_{14,1} <= 1 Integer
# 0 <= z_dchg_{15,0} <= 1 Integer
# 0 <= z_dchg_{15,1} <= 1 Integer
# 0 <= z_dchg_{16,0} <= 1 Integer
# 0 <= z_dchg_{16,1} <= 1 Integer
# 0 <= z_dchg_{17,0} <= 1 Integer
# 0 <= z_dchg_{17,1} <= 1 Integer
# 0 <= z_dchg_{18,0} <= 1 Integer
# 0 <= z_dchg_{18,1} <= 1 Integer
# 0 <= z_dchg_{19,0} <= 1 Integer
# 0 <= z_dchg_{19,1} <= 1 Integer
# 0 <= z_dchg_{2,0} <= 1 Integer
# 0 <= z_dchg_{2,1} <= 1 Integer
# 0 <= z_dchg_{20,0} <= 1 Integer
# 0 <= z_dchg_{20,1} <= 1 Integer
# 0 <= z_dchg_{21,0} <= 1 Integer
# 0 <= z_dchg_{21,1} <= 1 Integer
# 0 <= z_dchg_{22,0} <= 1 Integer
# 0 <= z_dchg_{22,1} <= 1 Integer
# 0 <= z_dchg_{23,0} <= 1 Integer
# 0 <= z_dchg_{23,1} <= 1 Integer
# 0 <= z_dchg_{3,0} <= 1 Integer
# 0 <= z_dchg_{3,1} <= 1 Integer
# 0 <= z_dchg_{4,0} <= 1 Integer
# 0 <= z_dchg_{4,1} <= 1 Integer
# 0 <= z_dchg_{5,0} <= 1 Integer
# 0 <= z_dchg_{5,1} <= 1 Integer
# 0 <= z_dchg_{6,0} <= 1 Integer
# 0 <= z_dchg_{6,1} <= 1 Integer
# 0 <= z_dchg_{7,0} <= 1 Integer
# 0 <= z_dchg_{7,1} <= 1 Integer
# 0 <= z_dchg_{8,0} <= 1 Integer
# 0 <= z_dchg_{8,1} <= 1 Integer
# 0 <= z_dchg_{9,0} <= 1 Integer
# 0 <= z_dchg_{9,1} <= 1 Integer

# %%
#for constraint in dispatch_model.constraints.values():
#    print(f"{constraint.name}: Shadow price = {constraint.pi}")

time_array = np.array(range(0,24))

balance_shadow_prices = np.zeros(24)
for time in time_array:
  balance_shadow_prices[time] = dispatch_model.constraints[f'balance_{time}'].pi

dfer(balance_shadow_prices)
# Out:
#           0
# 0   100.000
# 1   100.000
# 2   100.000
# 3    70.000
# 4     0.000
# 5     0.000
# 6     0.000
# 7     0.000
# 8     0.000
# 9     0.000
# 10    0.000
# 11    0.000
# 12  100.000
# 13  100.000
# 14  100.000
# 15  100.000
# 16  100.000
# 17  100.000
# 18  100.000
# 19  100.000
# 20 1000.000
# 21 1000.000
# 22  100.000
# 23  100.000
